# %%
from pyspark.context import SparkContext

# %%
sc=SparkContext.getOrCreate()

# %%
#Load the CSV file into a RDD
irisData = sc.textFile("/FileStore/tables/Stores-4.csv")
irisData.persist()
# Out:
# Out[9]: /FileStore/tables/Stores-4.csv MapPartitionsRDD[159] at textFile at NativeMethodAccessorImpl.java:0

# %%
#Remove the first line (contains headers)
dataLines = irisData.filter(lambda x: "Store_Sales" not in x)
dataLines.count()
# Out:
# Out[10]: 896

# %%
#Convert the RDD into a Dense Vector. As a part of this exercise
import math
from pyspark.ml.linalg import Vectors, VectorUDT
#from pyspark.ml.linalg import Vectors

# %%
# Change labels to numeric ones

def transformToNumeric( inputStr) :
    attList=inputStr.split(",")
    
    #Set default to setosa
    irisValue=1.0
    if attList[4] == "versicolor":
        irisValue=2.0
    if attList[4] == "virginica":
        irisValue=3.0
       
    #Filter out columns not wanted at this stage
    values= Vectors.dense([ irisValue, \
                     float(attList[0]),  \
                     float(attList[1]),  \
                     float(attList[2]),  \
                     float(attList[3])  \
                     ])
    return values

# %%
#Change to a Vector
irisVectors = dataLines.map(transformToNumeric)
irisVectors.collect()
# Out:
# Out[13]: [DenseVector([1.0, 1.0, 1659.0, 1961.0, 530.0]),
#  DenseVector([1.0, 2.0, 1461.0, 1752.0, 210.0]),
#  DenseVector([1.0, 3.0, 1340.0, 1609.0, 720.0]),
#  DenseVector([1.0, 4.0, 1451.0, 1748.0, 620.0]),
#  DenseVector([1.0, 5.0, 1770.0, 2111.0, 450.0]),
#  DenseVector([1.0, 6.0, 1442.0, 1733.0, 760.0]),
#  DenseVector([1.0, 7.0, 1542.0, 1858.0, 1030.0]),
#  DenseVector([1.0, 8.0, 1261.0, 1507.0, 1020.0]),
#  DenseVector([1.0, 9.0, 1090.0, 1321.0, 680.0]),
#  DenseVector([1.0, 10.0, 1030.0, 1235.0, 1130.0]),
#  DenseVector([1.0, 11.0, 1187.0, 1439.0, 1090.0]),
#  DenseVector([1.0, 12.0, 1751.0, 2098.0, 720.0]),
#  DenseVector([1.0, 13.0, 1746.0, 2064.0, 1050.0]),
#  DenseVector([1.0, 14.0, 1615.0, 1931.0, 1160.0]),
#  DenseVector([1.0, 15.0, 1469.0, 1756.0, 770.0]),
#  DenseVector([1.0, 16.0, 1644.0, 1950.0, 790.0]),
#  DenseVector([1.0, 17.0, 1578.0, 1907.0, 1440.0]),
#  DenseVector([1.0, 18.0, 1703.0, 2045.0, 670.0]),
#  DenseVector([1.0, 19.0, 1438.0, 1731.0, 1030.0]),
#  DenseVector([1.0, 20.0, 1940.0, 2340.0, 980.0]),
#  DenseVector([1.0, 21.0, 1421.0, 1700.0, 370.0]),
#  DenseVector([1.0, 22.0, 1458.0, 1746.0, 690.0]),
#  DenseVector([1.0, 23.0, 1719.0, 2065.0, 950.0]),
#  DenseVector([1.0, 24.0, 1449.0, 1752.0, 620.0]),
#  DenseVector([1.0, 25.0, 1234.0, 1488.0, 840.0]),
#  DenseVector([1.0, 26.0, 1732.0, 2073.0, 820.0]),
#  DenseVector([1.0, 27.0, 1475.0, 1777.0, 1100.0]),
#  DenseVector([1.0, 28.0, 1390.0, 1648.0, 980.0]),
#  DenseVector([1.0, 29.0, 1642.0, 1943.0, 710.0]),
#  DenseVector([1.0, 30.0, 1715.0, 2071.0, 650.0]),
#  DenseVector([1.0, 31.0, 1439.0, 1746.0, 990.0]),
#  DenseVector([1.0, 32.0, 1250.0, 1508.0, 990.0]),
#  DenseVector([1.0, 33.0, 1331.0, 1608.0, 880.0]),
#  DenseVector([1.0, 34.0, 1784.0, 2163.0, 620.0]),
#  DenseVector([1.0, 35.0, 1375.0, 1648.0, 1020.0]),
#  DenseVector([1.0, 36.0, 1871.0, 2230.0, 700.0]),
#  DenseVector([1.0, 37.0, 1442.0, 1744.0, 610.0]),
#  DenseVector([1.0, 38.0, 1174.0, 1411.0, 1080.0]),
#  DenseVector([1.0, 39.0, 1839.0, 2204.0, 1010.0]),
#  DenseVector([1.0, 40.0, 1270.0, 1516.0, 10.0]),
#  DenseVector([1.0, 41.0, 1435.0, 1725.0, 1250.0]),
#  DenseVector([1.0, 42.0, 965.0, 1152.0, 600.0]),
#  DenseVector([1.0, 43.0, 1665.0, 2001.0, 730.0]),
#  DenseVector([1.0, 44.0, 1780.0, 2117.0, 780.0]),
#  DenseVector([1.0, 45.0, 1009.0, 1194.0, 520.0]),
#  DenseVector([1.0, 46.0, 1227.0, 1471.0, 870.0]),
#  DenseVector([1.0, 47.0, 1769.0, 2087.0, 690.0]),
#  DenseVector([1.0, 48.0, 1660.0, 1982.0, 910.0]),
#  DenseVector([1.0, 49.0, 1472.0, 1776.0, 1260.0]),
#  DenseVector([1.0, 50.0, 1408.0, 1688.0, 1040.0]),
#  DenseVector([1.0, 51.0, 1514.0, 1820.0, 910.0]),
#  DenseVector([1.0, 52.0, 1565.0, 1880.0, 1300.0]),
#  DenseVector([1.0, 53.0, 1074.0, 1288.0, 320.0]),
#  DenseVector([1.0, 54.0, 1864.0, 2240.0, 530.0]),
#  DenseVector([1.0, 55.0, 1570.0, 1898.0, 980.0]),
#  DenseVector([1.0, 56.0, 1417.0, 1701.0, 740.0]),
#  DenseVector([1.0, 57.0, 1734.0, 2060.0, 1240.0]),
#  DenseVector([1.0, 58.0, 1470.0, 1763.0, 1080.0]),
#  DenseVector([1.0, 59.0, 1761.0, 2104.0, 1080.0]),
#  DenseVector([1.0, 60.0, 1756.0, 2070.0, 460.0]),
#  DenseVector([1.0, 61.0, 1704.0, 2045.0, 300.0]),
#  DenseVector([1.0, 62.0, 2011.0, 2391.0, 530.0]),
#  DenseVector([1.0, 63.0, 1472.0, 1748.0, 600.0]),
#  DenseVector([1.0, 64.0, 1310.0, 1561.0, 860.0]),
#  DenseVector([1.0, 65.0, 1544.0, 1821.0, 590.0]),
#  DenseVector([1.0, 66.0, 1707.0, 2052.0, 920.0]),
#  DenseVector([1.0, 67.0, 1881.0, 2262.0, 570.0]),
#  DenseVector([1.0, 68.0, 1416.0, 1681.0, 290.0]),
#  DenseVector([1.0, 69.0, 1631.0, 1941.0, 650.0]),
#  DenseVector([1.0, 70.0, 1318.0, 1576.0, 710.0]),
#  DenseVector([1.0, 71.0, 1692.0, 2019.0, 850.0]),
#  DenseVector([1.0, 72.0, 1152.0, 1380.0, 530.0]),
#  DenseVector([1.0, 73.0, 891.0, 1073.0, 630.0]),
#  DenseVector([1.0, 74.0, 1468.0, 1749.0, 700.0]),
#  DenseVector([1.0, 75.0, 1539.0, 1833.0, 650.0]),
#  DenseVector([1.0, 76.0, 1635.0, 1956.0, 720.0]),
#  DenseVector([1.0, 77.0, 1267.0, 1520.0, 450.0]),
#  DenseVector([1.0, 78.0, 1250.0, 1475.0, 1390.0]),
#  DenseVector([1.0, 79.0, 1720.0, 2044.0, 960.0]),
#  DenseVector([1.0, 80.0, 1462.0, 1761.0, 600.0]),
#  DenseVector([1.0, 81.0, 1431.0, 1711.0, 620.0]),
#  DenseVector([1.0, 82.0, 1539.0, 1858.0, 1020.0]),
#  DenseVector([1.0, 83.0, 1441.0, 1723.0, 330.0]),
#  DenseVector([1.0, 84.0, 1572.0, 1884.0, 1410.0]),
#  DenseVector([1.0, 85.0, 1287.0, 1525.0, 1200.0]),
#  DenseVector([1.0, 86.0, 1468.0, 1760.0, 280.0]),
#  DenseVector([1.0, 87.0, 1931.0, 2342.0, 940.0]),
#  DenseVector([1.0, 88.0, 1252.0, 1506.0, 850.0]),
#  DenseVector([1.0, 89.0, 1238.0, 1468.0, 960.0]),
#  DenseVector([1.0, 90.0, 1479.0, 1758.0, 420.0]),
#  DenseVector([1.0, 91.0, 1590.0, 1912.0, 830.0]),
#  DenseVector([1.0, 92.0, 2169.0, 2617.0, 600.0]),
#  DenseVector([1.0, 93.0, 1838.0, 2205.0, 400.0]),
#  DenseVector([1.0, 94.0, 1385.0, 1655.0, 760.0]),
#  DenseVector([1.0, 95.0, 1921.0, 2305.0, 1470.0]),
#  DenseVector([1.0, 96.0, 1975.0, 2385.0, 500.0]),
#  DenseVector([1.0, 97.0, 1853.0, 2235.0, 1120.0]),
#  DenseVector([1.0, 98.0, 1816.0, 2171.0, 1160.0]),
#  DenseVector([1.0, 99.0, 1785.0, 2147.0, 820.0]),
#  DenseVector([1.0, 100.0, 1579.0, 1899.0, 1140.0]),
#  DenseVector([1.0, 101.0, 1096.0, 1321.0, 900.0]),
#  DenseVector([1.0, 102.0, 1919.0, 2294.0, 760.0]),
#  DenseVector([1.0, 103.0, 1262.0, 1500.0, 1170.0]),
#  DenseVector([1.0, 104.0, 1374.0, 1655.0, 1080.0]),
#  DenseVector([1.0, 105.0, 1309.0, 1587.0, 1000.0]),
#  DenseVector([1.0, 106.0, 1207.0, 1434.0, 690.0]),
#  DenseVector([1.0, 107.0, 1692.0, 2031.0, 810.0]),
#  DenseVector([1.0, 108.0, 1929.0, 2311.0, 630.0]),
#  DenseVector([1.0, 109.0, 1573.0, 1878.0, 650.0]),
#  DenseVector([1.0, 110.0, 1415.0, 1700.0, 920.0]),
#  DenseVector([1.0, 111.0, 1162.0, 1382.0, 1260.0]),
#  DenseVector([1.0, 112.0, 1485.0, 1787.0, 800.0]),
#  DenseVector([1.0, 113.0, 1897.0, 2248.0, 1330.0]),
#  DenseVector([1.0, 114.0, 1607.0, 1927.0, 940.0]),
#  DenseVector([1.0, 115.0, 1909.0, 2287.0, 1210.0]),
#  DenseVector([1.0, 116.0, 1274.0, 1503.0, 660.0]),
#  DenseVector([1.0, 117.0, 1157.0, 1379.0, 770.0]),
#  DenseVector([1.0, 118.0, 1712.0, 2046.0, 460.0]),
#  DenseVector([1.0, 119.0, 1500.0, 1798.0, 860.0]),
#  DenseVector([1.0, 120.0, 1682.0, 2017.0, 780.0]),
#  DenseVector([1.0, 121.0, 1441.0, 1727.0, 890.0]),
#  DenseVector([1.0, 122.0, 1525.0, 1835.0, 900.0]),
#  DenseVector([1.0, 123.0, 1408.0, 1669.0, 530.0]),
#  DenseVector([1.0, 124.0, 1947.0, 2333.0, 790.0]),
#  DenseVector([1.0, 125.0, 1164.0, 1390.0, 370.0]),
#  DenseVector([1.0, 126.0, 1787.0, 2137.0, 610.0]),
#  DenseVector([1.0, 127.0, 1871.0, 2241.0, 500.0]),
#  DenseVector([1.0, 128.0, 1718.0, 2051.0, 750.0]),
#  DenseVector([1.0, 129.0, 1365.0, 1636.0, 980.0]),
#  DenseVector([1.0, 130.0, 1368.0, 1654.0, 530.0]),
#  DenseVector([1.0, 131.0, 1342.0, 1595.0, 910.0]),
#  DenseVector([1.0, 132.0, 1076.0, 1270.0, 620.0]),
#  DenseVector([1.0, 133.0, 1396.0, 1672.0, 1170.0]),
#  DenseVector([1.0, 134.0, 1713.0, 2071.0, 900.0]),
#  DenseVector([1.0, 135.0, 1370.0, 1638.0, 980.0]),
#  DenseVector([1.0, 136.0, 1667.0, 1993.0, 740.0]),
#  DenseVector([1.0, 137.0, 1638.0, 1972.0, 810.0]),
#  DenseVector([1.0, 138.0, 1581.0, 1905.0, 810.0]),
#  DenseVector([1.0, 139.0, 1795.0, 2187.0, 300.0]),
#  DenseVector([1.0, 140.0, 1179.0, 1412.0, 790.0]),
#  DenseVector([1.0, 141.0, 1978.0, 2374.0, 800.0]),
#  DenseVector([1.0, 142.0, 1688.0, 2042.0, 760.0]),
#  DenseVector([1.0, 143.0, 1214.0, 1456.0, 530.0]),
#  DenseVector([1.0, 144.0, 1504.0, 1805.0, 540.0]),
#  DenseVector([1.0, 145.0, 1498.0, 1770.0, 620.0]),
#  DenseVector([1.0, 146.0, 1462.0, 1762.0, 1010.0]),
#  DenseVector([1.0, 147.0, 1442.0, 1750.0, 130.0]),
#  DenseVector([1.0, 148.0, 1250.0, 1486.0, 730.0]),
#  DenseVector([1.0, 149.0, 1229.0, 1480.0, 830.0]),
#  DenseVector([1.0, 150.0, 1936.0, 2300.0, 1060.0]),
#  DenseVector([1.0, 151.0, 1369.0, 1629.0, 770.0]),
#  DenseVector([1.0, 152.0, 1662.0, 1986.0, 70.0]),
#  DenseVector([1.0, 153.0, 1548.0, 1855.0, 670.0]),
#  DenseVector([1.0, 154.0, 1649.0, 1963.0, 490.0]),
#  DenseVector([1.0, 155.0, 1393.0, 1663.0, 670.0]),
#  DenseVector([1.0, 156.0, 1450.0, 1734.0, 380.0]),
#  DenseVector([1.0, 157.0, 1613.0, 1921.0, 1200.0]),
#  DenseVector([1.0, 158.0, 1408.0, 1696.0, 350.0]),
#  DenseVector([1.0, 159.0, 775.0, 932.0, 1090.0]),
#  DenseVector([1.0, 160.0, 1275.0, 1534.0, 1230.0]),
#  DenseVector([1.0, 161.0, 1740.0, 2078.0, 680.0]),
#  DenseVector([1.0, 162.0, 1372.0, 1657.0, 580.0]),
#  DenseVector([1.0, 163.0, 1414.0, 1723.0, 680.0]),
#  DenseVector([1.0, 164.0, 2044.0, 2474.0, 340.0]),
#  DenseVector([1.0, 165.0, 1823.0, 2176.0, 700.0]),
#  DenseVector([1.0, 166.0, 955.0, 1133.0, 580.0]),
#  DenseVector([1.0, 167.0, 1465.0, 1763.0, 680.0]),
#  DenseVector([1.0, 168.0, 1331.0, 1606.0, 630.0]),
#  DenseVector([1.0, 169.0, 1232.0, 1487.0, 860.0]),
#  DenseVector([1.0, 170.0, 1481.0, 1765.0, 490.0]),
#  DenseVector([1.0, 171.0, 1343.0, 1599.0, 870.0]),
#  DenseVector([1.0, 172.0, 1539.0, 1837.0, 990.0]),
#  DenseVector([1.0, 173.0, 1007.0, 1207.0, 670.0]),
#  DenseVector([1.0, 174.0, 1762.0, 2145.0, 490.0]),
#  DenseVector([1.0, 175.0, 1527.0, 1832.0, 580.0]),
#  DenseVector([1.0, 176.0, 1356.0, 1619.0, 700.0]),
#  DenseVector([1.0, 177.0, 1536.0, 1848.0, 670.0]),
#  DenseVector([1.0, 178.0, 1605.0, 1902.0, 390.0]),
#  DenseVector([1.0, 179.0, 1704.0, 2032.0, 590.0]),
#  DenseVector([1.0, 180.0, 1626.0, 1941.0, 1350.0]),
#  DenseVector([1.0, 181.0, 1612.0, 1939.0, 840.0]),
#  DenseVector([1.0, 182.0, 1174.0, 1396.0, 1100.0]),
#  DenseVector([1.0, 183.0, 1923.0, 2339.0, 950.0]),
#  DenseVector([1.0, 184.0, 1702.0, 2053.0, 950.0]),
#  DenseVector([1.0, 185.0, 1398.0, 1692.0, 650.0]),
#  DenseVector([1.0, 186.0, 1437.0, 1717.0, 230.0]),
#  DenseVector([1.0, 187.0, 1524.0, 1796.0, 1060.0]),
#  DenseVector([1.0, 188.0, 1660.0, 1985.0, 1180.0]),
#  DenseVector([1.0, 189.0, 1302.0, 1569.0, 710.0]),
#  DenseVector([1.0, 190.0, 1666.0, 2000.0, 480.0]),
#  DenseVector([1.0, 191.0, 1391.0, 1649.0, 810.0]),
#  DenseVector([1.0, 192.0, 1778.0, 2148.0, 1140.0]),
#  DenseVector([1.0, 193.0, 1462.0, 1770.0, 1070.0]),
#  DenseVector([1.0, 194.0, 1751.0, 2115.0, 790.0]),
#  DenseVector([1.0, 195.0, 1652.0, 1982.0, 690.0]),
#  DenseVector([1.0, 196.0, 1841.0, 2215.0, 610.0]),
#  DenseVector([1.0, 197.0, 1496.0, 1791.0, 1240.0]),
#  DenseVector([1.0, 198.0, 1504.0, 1827.0, 840.0]),
#  DenseVector([1.0, 199.0, 1524.0, 1808.0, 460.0]),
#  DenseVector([1.0, 200.0, 1148.0, 1371.0, 940.0]),
#  DenseVector([1.0, 201.0, 1468.0, 1744.0, 590.0]),
#  DenseVector([1.0, 202.0, 1310.0, 1558.0, 890.0]),
#  DenseVector([1.0, 203.0, 1321.0, 1579.0, 770.0]),
#  DenseVector([1.0, 204.0, 992.0, 1192.0, 900.0]),
#  DenseVector([1.0, 205.0, 1540.0, 1857.0, 1020.0]),
#  DenseVector([1.0, 206.0, 1807.0, 2149.0, 910.0]),
#  DenseVector([1.0, 207.0, 1526.0, 1853.0, 660.0]),
#  DenseVector([1.0, 208.0, 1406.0, 1677.0, 480.0]),
#  DenseVector([1.0, 209.0, 1703.0, 2055.0, 1080.0]),
#  DenseVector([1.0, 210.0, 1575.0, 1872.0, 690.0]),
#  DenseVector([1.0, 211.0, 1309.0, 1572.0, 510.0]),
#  DenseVector([1.0, 212.0, 1488.0, 1807.0, 1030.0]),
#  DenseVector([1.0, 213.0, 1658.0, 1988.0, 370.0]),
#  DenseVector([1.0, 214.0, 1863.0, 2245.0, 640.0]),
#  DenseVector([1.0, 215.0, 1458.0, 1725.0, 750.0]),
#  DenseVector([1.0, 216.0, 1604.0, 1909.0, 370.0]),
#  DenseVector([1.0, 217.0, 1575.0, 1899.0, 840.0]),
#  DenseVector([1.0, 218.0, 1525.0, 1829.0, 840.0]),
#  DenseVector([1.0, 219.0, 1451.0, 1737.0, 890.0]),
#  DenseVector([1.0, 220.0, 1390.0, 1687.0, 620.0]),
#  DenseVector([1.0, 221.0, 1442.0, 1742.0, 310.0]),
#  DenseVector([1.0, 222.0, 1620.0, 1922.0, 550.0]),
#  DenseVector([1.0, 223.0, 1251.0, 1527.0, 380.0]),
#  DenseVector([1.0, 224.0, 1318.0, 1606.0, 1200.0]),
#  DenseVector([1.0, 225.0, 1647.0, 1962.0, 800.0]),
#  DenseVector([1.0, 226.0, 1829.0, 2175.0, 870.0]),
#  DenseVector([1.0, 227.0, 1852.0, 2227.0, 1220.0]),
#  DenseVector([1.0, 228.0, 1699.0, 2053.0, 1080.0]),
#  DenseVector([1.0, 229.0, 1325.0, 1595.0, 540.0]),
#  DenseVector([1.0, 230.0, 1350.0, 1634.0, 880.0]),
#  DenseVector([1.0, 231.0, 1347.0, 1628.0, 120.0]),
#  DenseVector([1.0, 232.0, 1397.0, 1661.0, 1410.0]),
#  DenseVector([1.0, 233.0, 1245.0, 1499.0, 570.0]),
#  DenseVector([1.0, 234.0, 1366.0, 1649.0, 940.0]),
#  DenseVector([1.0, 235.0, 1378.0, 1658.0, 760.0]),
#  DenseVector([1.0, 236.0, 1767.0, 2110.0, 1200.0]),
#  DenseVector([1.0, 237.0, 1184.0, 1434.0, 670.0]),
#  DenseVector([1.0, 238.0, 1257.0, 1505.0, 950.0]),
#  DenseVector([1.0, 239.0, 1863.0, 2247.0, 480.0]),
#  DenseVector([1.0, 240.0, 1881.0, 2244.0, 920.0]),
#  DenseVector([1.0, 241.0, 1329.0, 1609.0, 1150.0]),
#  DenseVector([1.0, 242.0, 1539.0, 1848.0, 750.0]),
#  DenseVector([1.0, 243.0, 1557.0, 1861.0, 370.0]),
#  DenseVector([1.0, 244.0, 2007.0, 2397.0, 610.0]),
#  DenseVector([1.0, 245.0, 1185.0, 1418.0, 1150.0]),
#  DenseVector([1.0, 246.0, 1657.0, 2003.0, 1070.0]),
#  DenseVector([1.0, 247.0, 1294.0, 1539.0, 790.0]),
#  DenseVector([1.0, 248.0, 1296.0, 1559.0, 1070.0]),
#  DenseVector([1.0, 249.0, 1733.0, 2097.0, 730.0]),
#  DenseVector([1.0, 250.0, 1641.0, 1976.0, 620.0]),
#  DenseVector([1.0, 251.0, 1373.0, 1648.0, 530.0]),
#  DenseVector([1.0, 252.0, 1550.0, 1845.0, 700.0]),
#  DenseVector([1.0, 253.0, 1583.0, 1907.0, 680.0]),
#  DenseVector([1.0, 254.0, 1428.0, 1719.0, 1060.0]),
#  DenseVector([1.0, 255.0, 1604.0, 1925.0, 670.0]),
#  DenseVector([1.0, 256.0, 1439.0, 1735.0, 400.0]),
#  DenseVector([1.0, 257.0, 1648.0, 2003.0, 910.0]),
#  DenseVector([1.0, 258.0, 1025.0, 1231.0, 760.0]),
#  DenseVector([1.0, 259.0, 2001.0, 2394.0, 540.0]),
#  DenseVector([1.0, 260.0, 1145.0, 1370.0, 350.0]),
#  DenseVector([1.0, 261.0, 1174.0, 1426.0, 980.0]),
#  DenseVector([1.0, 262.0, 913.0, 1106.0, 860.0]),
#  DenseVector([1.0, 263.0, 1199.0, 1433.0, 1020.0]),
#  DenseVector([1.0, 264.0, 1875.0, 2254.0, 1120.0]),
#  DenseVector([1.0, 265.0, 1153.0, 1397.0, 1020.0]),
#  DenseVector([1.0, 266.0, 1240.0, 1492.0, 940.0]),
#  DenseVector([1.0, 267.0, 1381.0, 1660.0, 970.0]),
#  DenseVector([1.0, 268.0, 1701.0, 2030.0, 830.0]),
#  DenseVector([1.0, 269.0, 1206.0, 1456.0, 920.0]),
#  DenseVector([1.0, 270.0, 1476.0, 1777.0, 660.0]),
#  DenseVector([1.0, 271.0, 1189.0, 1439.0, 780.0]),
#  DenseVector([1.0, 272.0, 1837.0, 2220.0, 340.0]),
#  DenseVector([1.0, 273.0, 1319.0, 1571.0, 1190.0]),
#  DenseVector([1.0, 274.0, 1617.0, 1901.0, 490.0]),
#  DenseVector([1.0, 275.0, 1631.0, 1967.0, 1090.0]),
#  DenseVector([1.0, 276.0, 1517.0, 1805.0, 1040.0]),
#  DenseVector([1.0, 277.0, 1764.0, 2109.0, 1210.0]),
#  DenseVector([1.0, 278.0, 1572.0, 1869.0, 1030.0]),
#  DenseVector([1.0, 279.0, 1855.0, 2197.0, 1170.0]),
#  DenseVector([1.0, 280.0, 1327.0, 1571.0, 730.0]),
#  DenseVector([1.0, 281.0, 1270.0, 1515.0, 720.0]),
#  DenseVector([1.0, 282.0, 1734.0, 2073.0, 500.0]),
#  DenseVector([1.0, 283.0, 1533.0, 1848.0, 1070.0]),
#  DenseVector([1.0, 284.0, 1390.0, 1646.0, 800.0]),
#  DenseVector([1.0, 285.0, 1856.0, 2216.0, 1020.0]),
#  DenseVector([1.0, 286.0, 1000.0, 1215.0, 1070.0]),
#  DenseVector([1.0, 287.0, 1313.0, 1586.0, 420.0]),
#  DenseVector([1.0, 288.0, 1494.0, 1799.0, 510.0]),
#  DenseVector([1.0, 289.0, 1386.0, 1674.0, 1210.0]),
#  DenseVector([1.0, 290.0, 1979.0, 2364.0, 660.0]),
#  DenseVector([1.0, 291.0, 1057.0, 1264.0, 360.0]),
#  DenseVector([1.0, 292.0, 902.0, 1093.0, 1210.0]),
#  DenseVector([1.0, 293.0, 1347.0, 1622.0, 560.0]),
#  DenseVector([1.0, 294.0, 1314.0, 1576.0, 360.0]),
#  DenseVector([1.0, 295.0, 1513.0, 1803.0, 970.0]),
#  DenseVector([1.0, 296.0, 1305.0, 1548.0, 480.0]),
#  DenseVector([1.0, 297.0, 1180.0, 1436.0, 690.0]),
#  DenseVector([1.0, 298.0, 1142.0, 1352.0, 710.0]),
#  DenseVector([1.0, 299.0, 1471.0, 1768.0, 780.0]),
#  DenseVector([1.0, 300.0, 1075.0, 1288.0, 630.0]),
#  DenseVector([1.0, 301.0, 1578.0, 1885.0, 220.0]),
#  DenseVector([1.0, 302.0, 1585.0, 1916.0, 1110.0]),
#  DenseVector([1.0, 303.0, 1391.0, 1648.0, 720.0]),
#  DenseVector([1.0, 304.0, 1577.0, 1892.0, 560.0]),
#  DenseVector([1.0, 305.0, 1092.0, 1314.0, 600.0]),
#  DenseVector([1.0, 306.0, 1375.0, 1681.0, 440.0]),
#  DenseVector([1.0, 307.0, 1523.0, 1813.0, 520.0]),
#  DenseVector([1.0, 308.0, 1373.0, 1654.0, 410.0]),
#  DenseVector([1.0, 309.0, 1550.0, 1871.0, 590.0]),
#  DenseVector([1.0, 310.0, 1614.0, 1946.0, 740.0]),
#  DenseVector([1.0, 311.0, 1566.0, 1889.0, 610.0]),
#  DenseVector([1.0, 312.0, 2019.0, 2396.0, 540.0]),
#  DenseVector([1.0, 313.0, 1494.0, 1806.0, 1450.0]),
#  DenseVector([1.0, 314.0, 1659.0, 2008.0, 620.0]),
#  DenseVector([1.0, 315.0, 1766.0, 2131.0, 340.0]),
#  DenseVector([1.0, 316.0, 1293.0, 1554.0, 970.0]),
#  DenseVector([1.0, 317.0, 1375.0, 1659.0, 1080.0]),
#  DenseVector([1.0, 318.0, 1236.0, 1484.0, 560.0]),
#  DenseVector([1.0, 319.0, 1332.0, 1586.0, 630.0]),
#  DenseVector([1.0, 320.0, 1513.0, 1825.0, 980.0]),
#  DenseVector([1.0, 321.0, 1208.0, 1459.0, 930.0]),
#  DenseVector([1.0, 322.0, 1190.0, 1429.0, 470.0]),
#  DenseVector([1.0, 323.0, 1448.0, 1734.0, 680.0]),
#  DenseVector([1.0, 324.0, 1771.0, 2147.0, 430.0]),
#  DenseVector([1.0, 325.0, 1365.0, 1645.0, 830.0]),
#  DenseVector([1.0, 326.0, 1510.0, 1810.0, 950.0]),
#  DenseVector([1.0, 327.0, 1458.0, 1736.0, 870.0]),
#  DenseVector([1.0, 328.0, 1808.0, 2157.0, 730.0]),
#  DenseVector([1.0, 329.0, 1615.0, 1954.0, 760.0]),
#  DenseVector([1.0, 330.0, 1640.0, 1948.0, 960.0]),
#  DenseVector([1.0, 331.0, 1060.0, 1273.0, 860.0]),
#  DenseVector([1.0, 332.0, 1633.0, 1968.0, 330.0]),
#  DenseVector([1.0, 333.0, 1222.0, 1473.0, 630.0]),
#  DenseVector([1.0, 334.0, 1619.0, 1957.0, 1280.0]),
#  DenseVector([1.0, 335.0, 1624.0, 1973.0, 1440.0]),
#  DenseVector([1.0, 336.0, 1887.0, 2278.0, 570.0]),
#  DenseVector([1.0, 337.0, 1320.0, 1583.0, 540.0]),
#  DenseVector([1.0, 338.0, 1450.0, 1750.0, 480.0]),
#  DenseVector([1.0, 339.0, 1455.0, 1764.0, 390.0]),
#  DenseVector([1.0, 340.0, 966.0, 1172.0, 900.0]),
#  DenseVector([1.0, 341.0, 1922.0, 2290.0, 290.0]),
#  DenseVector([1.0, 342.0, 1678.0, 1999.0, 740.0]),
#  DenseVector([1.0, 343.0, 1638.0, 1952.0, 690.0]),
#  DenseVector([1.0, 344.0, 1145.0, 1375.0, 950.0]),
#  DenseVector([1.0, 345.0, 2004.0, 2390.0, 930.0]),
#  DenseVector([1.0, 346.0, 1954.0, 2378.0, 810.0]),
#  DenseVector([1.0, 347.0, 1577.0, 1879.0, 760.0]),
#  DenseVector([1.0, 348.0, 1766.0, 2138.0, 580.0]),
#  DenseVector([1.0, 349.0, 1362.0, 1634.0, 770.0]),
#  DenseVector([1.0, 350.0, 1886.0, 2228.0, 1530.0]),
#  DenseVector([1.0, 351.0, 1291.0, 1546.0, 420.0]),
#  DenseVector([1.0, 352.0, 1584.0, 1897.0, 1210.0]),
#  DenseVector([1.0, 353.0, 1397.0, 1686.0, 850.0]),
#  DenseVector([1.0, 354.0, 1445.0, 1709.0, 1340.0]),
#  DenseVector([1.0, 355.0, 1433.0, 1707.0, 1160.0]),
#  DenseVector([1.0, 356.0, 1269.0, 1511.0, 500.0]),
#  DenseVector([1.0, 357.0, 1798.0, 2134.0, 820.0]),
#  DenseVector([1.0, 358.0, 1514.0, 1822.0, 670.0]),
#  DenseVector([1.0, 359.0, 1015.0, 1216.0, 460.0]),
#  DenseVector([1.0, 360.0, 1495.0, 1799.0, 950.0]),
#  DenseVector([1.0, 361.0, 1759.0, 2095.0, 980.0]),
#  DenseVector([1.0, 362.0, 1219.0, 1468.0, 850.0]),
#  DenseVector([1.0, 363.0, 1571.0, 1877.0, 580.0]),
#  DenseVector([1.0, 364.0, 1404.0, 1670.0, 620.0]),
#  DenseVector([1.0, 365.0, 1124.0, 1369.0, 650.0]),
#  DenseVector([1.0, 366.0, 1514.0, 1837.0, 1130.0]),
#  DenseVector([1.0, 367.0, 1207.0, 1476.0, 720.0]),
#  DenseVector([1.0, 368.0, 1484.0, 1774.0, 940.0]),
#  DenseVector([1.0, 369.0, 1398.0, 1678.0, 920.0]),
#  DenseVector([1.0, 370.0, 1769.0, 2112.0, 660.0]),
#  DenseVector([1.0, 371.0, 1111.0, 1322.0, 610.0]),
#  DenseVector([1.0, 372.0, 1078.0, 1305.0, 1190.0]),
#  DenseVector([1.0, 373.0, 1876.0, 2254.0, 1340.0]),
#  DenseVector([1.0, 374.0, 1909.0, 2306.0, 820.0]),
#  DenseVector([1.0, 375.0, 1940.0, 2343.0, 1130.0]),
#  DenseVector([1.0, 376.0, 1391.0, 1683.0, 890.0]),
#  DenseVector([1.0, 377.0, 1496.0, 1774.0, 810.0]),
#  DenseVector([1.0, 378.0, 1412.0, 1699.0, 680.0]),
#  DenseVector([1.0, 379.0, 1121.0, 1345.0, 320.0]),
#  DenseVector([1.0, 380.0, 1691.0, 2026.0, 700.0]),
#  DenseVector([1.0, 381.0, 1599.0, 1946.0, 940.0]),
#  DenseVector([1.0, 382.0, 1208.0, 1467.0, 910.0]),
#  DenseVector([1.0, 383.0, 1454.0, 1737.0, 870.0]),
#  DenseVector([1.0, 384.0, 1555.0, 1881.0, 1260.0]),
#  DenseVector([1.0, 385.0, 1554.0, 1852.0, 440.0]),
#  DenseVector([1.0, 386.0, 1491.0, 1800.0, 980.0]),
#  DenseVector([1.0, 387.0, 1415.0, 1697.0, 1200.0]),
#  DenseVector([1.0, 388.0, 1487.0, 1801.0, 890.0]),
#  DenseVector([1.0, 389.0, 1339.0, 1589.0, 1050.0]),
#  DenseVector([1.0, 390.0, 1320.0, 1562.0, 610.0]),
#  DenseVector([1.0, 391.0, 1509.0, 1799.0, 960.0]),
#  DenseVector([1.0, 392.0, 1406.0, 1680.0, 860.0]),
#  DenseVector([1.0, 393.0, 1264.0, 1502.0, 800.0]),
#  DenseVector([1.0, 394.0, 1905.0, 2280.0, 1060.0]),
#  DenseVector([1.0, 395.0, 1209.0, 1464.0, 600.0]),
#  DenseVector([1.0, 396.0, 1546.0, 1829.0, 380.0]),
#  DenseVector([1.0, 397.0, 1689.0, 2044.0, 1140.0]),
#  DenseVector([1.0, 398.0, 1153.0, 1381.0, 730.0]),
#  DenseVector([1.0, 399.0, 2063.0, 2493.0, 810.0]),
#  DenseVector([1.0, 400.0, 1848.0, 2254.0, 1000.0]),
#  DenseVector([1.0, 401.0, 1718.0, 2056.0, 1220.0]),
#  DenseVector([1.0, 402.0, 1480.0, 1773.0, 360.0]),
#  DenseVector([1.0, 403.0, 1439.0, 1724.0, 900.0]),
#  DenseVector([1.0, 404.0, 1576.0, 1896.0, 750.0]),
#  DenseVector([1.0, 405.0, 1948.0, 2374.0, 930.0]),
#  DenseVector([1.0, 406.0, 1613.0, 1893.0, 1180.0]),
#  DenseVector([1.0, 407.0, 896.0, 1059.0, 870.0]),
#  DenseVector([1.0, 408.0, 1625.0, 1943.0, 680.0]),
#  DenseVector([1.0, 409.0, 1303.0, 1587.0, 1310.0]),
#  DenseVector([1.0, 410.0, 1340.0, 1605.0, 1000.0]),
#  DenseVector([1.0, 411.0, 1410.0, 1704.0, 1130.0]),
#  DenseVector([1.0, 412.0, 1432.0, 1719.0, 990.0]),
#  DenseVector([1.0, 413.0, 1891.0, 2280.0, 360.0]),
#  DenseVector([1.0, 414.0, 1322.0, 1583.0, 720.0]),
#  DenseVector([1.0, 415.0, 1378.0, 1670.0, 950.0]),
#  DenseVector([1.0, 416.0, 1462.0, 1732.0, 840.0]),
#  DenseVector([1.0, 417.0, 1440.0, 1733.0, 1120.0]),
#  DenseVector([1.0, 418.0, 1421.0, 1724.0, 920.0]),
#  DenseVector([1.0, 419.0, 1280.0, 1530.0, 1240.0]),
#  DenseVector([1.0, 420.0, 1431.0, 1710.0, 840.0]),
#  DenseVector([1.0, 421.0, 1161.0, 1404.0, 430.0]),
#  DenseVector([1.0, 422.0, 1175.0, 1405.0, 810.0]),
#  DenseVector([1.0, 423.0, 1395.0, 1662.0, 920.0]),
#  DenseVector([1.0, 424.0, 1443.0, 1755.0, 880.0]),
#  DenseVector([1.0, 425.0, 1247.0, 1523.0, 1350.0]),
#  DenseVector([1.0, 426.0, 1788.0, 2133.0, 1000.0]),
#  DenseVector([1.0, 427.0, 1138.0, 1375.0, 1220.0]),
#  DenseVector([1.0, 428.0, 1709.0, 2042.0, 430.0]),
#  DenseVector([1.0, 429.0, 1777.0, 2145.0, 520.0]),
#  DenseVector([1.0, 430.0, 1612.0, 1918.0, 580.0]),
#  DenseVector([1.0, 431.0, 1618.0, 1943.0, 460.0]),
#  DenseVector([1.0, 432.0, 1311.0, 1571.0, 470.0]),
#  DenseVector([1.0, 433.0, 1365.0, 1638.0, 680.0]),
#  DenseVector([1.0, 434.0, 1249.0, 1503.0, 950.0]),
#  DenseVector([1.0, 435.0, 1373.0, 1635.0, 840.0]),
#  DenseVector([1.0, 436.0, 1536.0, 1836.0, 990.0]),
#  DenseVector([1.0, 437.0, 1744.0, 2101.0, 520.0]),
#  DenseVector([1.0, 438.0, 1513.0, 1820.0, 520.0]),
#  DenseVector([1.0, 439.0, 1297.0, 1561.0, 1070.0]),
#  DenseVector([1.0, 440.0, 1908.0, 2304.0, 990.0]),
#  DenseVector([1.0, 441.0, 1721.0, 2076.0, 710.0]),
#  DenseVector([1.0, 442.0, 1243.0, 1491.0, 430.0]),
#  DenseVector([1.0, 443.0, 1472.0, 1766.0, 1290.0]),
#  DenseVector([1.0, 444.0, 1307.0, 1570.0, 1080.0]),
#  DenseVector([1.0, 445.0, 1628.0, 1959.0, 890.0]),
#  DenseVector([1.0, 446.0, 1556.0, 1869.0, 1000.0]),
#  DenseVector([1.0, 447.0, 1179.0, 1428.0, 1290.0]),
#  DenseVector([1.0, 448.0, 1768.0, 2123.0, 860.0]),
#  DenseVector([1.0, 449.0, 1378.0, 1656.0, 1010.0]),
#  DenseVector([1.0, 450.0, 1685.0, 2015.0, 1160.0]),
#  DenseVector([1.0, 451.0, 1474.0, 1759.0, 880.0]),
#  DenseVector([1.0, 452.0, 1794.0, 2137.0, 670.0]),
#  DenseVector([1.0, 453.0, 1086.0, 1291.0, 930.0]),
#  DenseVector([1.0, 454.0, 1808.0, 2154.0, 990.0]),
#  DenseVector([1.0, 455.0, 1501.0, 1790.0, 450.0]),
#  DenseVector([1.0, 456.0, 1353.0, 1598.0, 690.0]),
#  DenseVector([1.0, 457.0, 1455.0, 1757.0, 650.0]),
#  DenseVector([1.0, 458.0, 1165.0, 1411.0, 1020.0]),
#  DenseVector([1.0, 459.0, 1332.0, 1610.0, 880.0]),
#  DenseVector([1.0, 460.0, 1396.0, 1668.0, 760.0]),
#  DenseVector([1.0, 461.0, 1513.0, 1821.0, 690.0]),
#  DenseVector([1.0, 462.0, 1618.0, 1940.0, 630.0]),
#  DenseVector([1.0, 463.0, 1845.0, 2233.0, 370.0]),
#  DenseVector([1.0, 464.0, 1172.0, 1411.0, 460.0]),
#  DenseVector([1.0, 465.0, 1436.0, 1737.0, 770.0]),
#  DenseVector([1.0, 466.0, 1738.0, 2065.0, 750.0]),
#  DenseVector([1.0, 467.0, 2229.0, 2667.0, 660.0]),
#  DenseVector([1.0, 468.0, 1490.0, 1783.0, 730.0]),
#  DenseVector([1.0, 469.0, 1060.0, 1279.0, 670.0]),
#  DenseVector([1.0, 470.0, 2015.0, 2436.0, 680.0]),
#  DenseVector([1.0, 471.0, 1611.0, 1919.0, 960.0]),
#  DenseVector([1.0, 472.0, 1187.0, 1417.0, 1230.0]),
#  DenseVector([1.0, 473.0, 1430.0, 1690.0, 800.0]),
#  DenseVector([1.0, 474.0, 1543.0, 1840.0, 450.0]),
#  DenseVector([1.0, 475.0, 1836.0, 2195.0, 940.0]),
#  DenseVector([1.0, 476.0, 1463.0, 1764.0, 1060.0]),
#  DenseVector([1.0, 477.0, 1213.0, 1462.0, 560.0]),
#  DenseVector([1.0, 478.0, 1244.0, 1480.0, 860.0]),
#  DenseVector([1.0, 479.0, 1745.0, 2108.0, 730.0]),
#  DenseVector([1.0, 480.0, 933.0, 1121.0, 940.0]),
#  DenseVector([1.0, 481.0, 1764.0, 2132.0, 920.0]),
#  DenseVector([1.0, 482.0, 1675.0, 2002.0, 1050.0]),
#  DenseVector([1.0, 483.0, 1688.0, 2046.0, 380.0]),
#  DenseVector([1.0, 484.0, 1842.0, 2204.0, 930.0]),
#  DenseVector([1.0, 485.0, 1316.0, 1597.0, 980.0]),
#  DenseVector([1.0, 486.0, 1440.0, 1719.0, 580.0]),
#  DenseVector([1.0, 487.0, 1760.0, 2111.0, 680.0]),
#  DenseVector([1.0, 488.0, 1323.0, 1571.0, 850.0]),
#  DenseVector([1.0, 489.0, 1230.0, 1466.0, 730.0]),
#  DenseVector([1.0, 490.0, 1540.0, 1838.0, 570.0]),
#  DenseVector([1.0, 491.0, 1167.0, 1388.0, 620.0]),
#  DenseVector([1.0, 492.0, 1429.0, 1695.0, 890.0]),
#  DenseVector([1.0, 493.0, 1491.0, 1770.0, 800.0]),
#  DenseVector([1.0, 494.0, 1313.0, 1574.0, 920.0]),
#  DenseVector([1.0, 495.0, 1609.0, 1943.0, 920.0]),
#  DenseVector([1.0, 496.0, 1109.0, 1342.0, 760.0]),
#  DenseVector([1.0, 497.0, 1207.0, 1440.0, 500.0]),
#  DenseVector([1.0, 498.0, 902.0, 1087.0, 680.0]),
#  DenseVector([1.0, 499.0, 1191.0, 1422.0, 770.0]),
#  DenseVector([1.0, 500.0, 1335.0, 1601.0, 460.0]),
#  DenseVector([1.0, 501.0, 1382.0, 1660.0, 1070.0]),
#  DenseVector([1.0, 502.0, 1588.0, 1906.0, 450.0]),
#  DenseVector([1.0, 503.0, 1918.0, 2284.0, 310.0]),
#  DenseVector([1.0, 504.0, 1484.0, 1774.0, 880.0]),
#  DenseVector([1.0, 505.0, 1334.0, 1607.0, 370.0]),
#  DenseVector([1.0, 506.0, 1556.0, 1846.0, 760.0]),
#  DenseVector([1.0, 507.0, 1784.0, 2142.0, 950.0]),
#  DenseVector([1.0, 508.0, 1244.0, 1477.0, 890.0]),
#  DenseVector([1.0, 509.0, 1496.0, 1787.0, 800.0]),
#  DenseVector([1.0, 510.0, 1719.0, 2058.0, 700.0]),
#  DenseVector([1.0, 511.0, 1678.0, 2022.0, 1050.0]),
#  DenseVector([1.0, 512.0, 1247.0, 1490.0, 330.0]),
#  DenseVector([1.0, 513.0, 1191.0, 1421.0, 980.0]),
#  DenseVector([1.0, 514.0, 1832.0, 2208.0, 1090.0]),
#  DenseVector([1.0, 515.0, 1271.0, 1523.0, 1140.0]),
#  DenseVector([1.0, 516.0, 1735.0, 2084.0, 820.0]),
#  DenseVector([1.0, 517.0, 1627.0, 1948.0, 890.0]),
#  DenseVector([1.0, 518.0, 1351.0, 1616.0, 650.0]),
#  DenseVector([1.0, 519.0, 1520.0, 1817.0, 850.0]),
#  DenseVector([1.0, 520.0, 1490.0, 1788.0, 360.0]),
#  DenseVector([1.0, 521.0, 1777.0, 2117.0, 780.0]),
#  DenseVector([1.0, 522.0, 1688.0, 2037.0, 590.0]),
#  DenseVector([1.0, 523.0, 1537.0, 1836.0, 670.0]),
#  DenseVector([1.0, 524.0, 1622.0, 1968.0, 340.0]),
#  DenseVector([1.0, 525.0, 1148.0, 1384.0, 730.0]),
#  DenseVector([1.0, 526.0, 1001.0, 1194.0, 1210.0]),
#  DenseVector([1.0, 527.0, 1857.0, 2236.0, 1280.0]),
#  DenseVector([1.0, 528.0, 1552.0, 1869.0, 710.0]),
#  DenseVector([1.0, 529.0, 1700.0, 2064.0, 940.0]),
#  DenseVector([1.0, 530.0, 1554.0, 1844.0, 670.0]),
#  DenseVector([1.0, 531.0, 1482.0, 1777.0, 800.0]),
#  DenseVector([1.0, 532.0, 1275.0, 1517.0, 790.0]),
#  DenseVector([1.0, 533.0, 1642.0, 1981.0, 720.0]),
#  DenseVector([1.0, 534.0, 1381.0, 1633.0, 1270.0]),
#  DenseVector([1.0, 535.0, 1381.0, 1634.0, 930.0]),
#  DenseVector([1.0, 536.0, 1057.0, 1262.0, 1490.0]),
#  DenseVector([1.0, 537.0, 1192.0, 1445.0, 810.0]),
#  DenseVector([1.0, 538.0, 1601.0, 1920.0, 600.0]),
#  DenseVector([1.0, 539.0, 1622.0, 1968.0, 210.0]),
#  DenseVector([1.0, 540.0, 1607.0, 1909.0, 460.0]),
#  DenseVector([1.0, 541.0, 2214.0, 2647.0, 740.0]),
#  DenseVector([1.0, 542.0, 1633.0, 1936.0, 1320.0]),
#  DenseVector([1.0, 543.0, 1546.0, 1845.0, 760.0]),
#  DenseVector([1.0, 544.0, 1475.0, 1753.0, 920.0]),
#  DenseVector([1.0, 545.0, 1270.0, 1519.0, 920.0]),
#  DenseVector([1.0, 546.0, 1185.0, 1420.0, 880.0]),
#  DenseVector([1.0, 547.0, 1614.0, 1938.0, 1110.0]),
#  DenseVector([1.0, 548.0, 1141.0, 1353.0, 1370.0]),
#  DenseVector([1.0, 549.0, 1244.0, 1481.0, 410.0]),
#  DenseVector([1.0, 550.0, 869.0, 1050.0, 850.0]),
#  DenseVector([1.0, 551.0, 2049.0, 2465.0, 720.0]),
#  DenseVector([1.0, 552.0, 1883.0, 2262.0, 570.0]),
#  DenseVector([1.0, 553.0, 1526.0, 1842.0, 690.0]),
#  DenseVector([1.0, 554.0, 1165.0, 1390.0, 1220.0]),
#  DenseVector([1.0, 555.0, 1832.0, 2185.0, 840.0]),
#  DenseVector([1.0, 556.0, 1723.0, 2072.0, 560.0]),
#  DenseVector([1.0, 557.0, 932.0, 1138.0, 820.0]),
#  DenseVector([1.0, 558.0, 1137.0, 1374.0, 700.0]),
#  DenseVector([1.0, 559.0, 1231.0, 1472.0, 810.0]),
#  DenseVector([1.0, 560.0, 1237.0, 1512.0, 1070.0]),
#  DenseVector([1.0, 561.0, 1371.0, 1650.0, 540.0]),
#  DenseVector([1.0, 562.0, 1767.0, 2158.0, 530.0]),
#  DenseVector([1.0, 563.0, 1748.0, 2092.0, 580.0]),
#  DenseVector([1.0, 564.0, 1212.0, 1440.0, 500.0]),
#  DenseVector([1.0, 565.0, 1466.0, 1743.0, 1200.0]),
#  DenseVector([1.0, 566.0, 1152.0, 1386.0, 980.0]),
#  DenseVector([1.0, 567.0, 1439.0, 1703.0, 1000.0]),
#  DenseVector([1.0, 568.0, 2026.0, 2400.0, 720.0]),
#  DenseVector([1.0, 569.0, 1772.0, 2146.0, 1030.0]),
#  DenseVector([1.0, 570.0, 1511.0, 1822.0, 420.0]),
#  DenseVector([1.0, 571.0, 1199.0, 1461.0, 1070.0]),
#  DenseVector([1.0, 572.0, 1834.0, 2184.0, 830.0]),
#  DenseVector([1.0, 573.0, 1143.0, 1375.0, 940.0]),
#  DenseVector([1.0, 574.0, 1494.0, 1794.0, 550.0]),
#  DenseVector([1.0, 575.0, 1770.0, 2131.0, 1140.0]),
#  DenseVector([1.0, 576.0, 1455.0, 1747.0, 750.0]),
#  DenseVector([1.0, 577.0, 1141.0, 1372.0, 620.0]),
#  DenseVector([1.0, 578.0, 1586.0, 1886.0, 660.0]),
#  DenseVector([1.0, 579.0, 1701.0, 2034.0, 660.0]),
#  DenseVector([1.0, 580.0, 1860.0, 2246.0, 410.0]),
#  DenseVector([1.0, 581.0, 1167.0, 1406.0, 440.0]),
#  DenseVector([1.0, 582.0, 1424.0, 1716.0, 630.0]),
#  DenseVector([1.0, 583.0, 1710.0, 2053.0, 730.0]),
#  DenseVector([1.0, 584.0, 1408.0, 1708.0, 220.0]),
#  DenseVector([1.0, 585.0, 1517.0, 1831.0, 610.0]),
#  DenseVector([1.0, 586.0, 1227.0, 1476.0, 720.0]),
#  DenseVector([1.0, 587.0, 1609.0, 1930.0, 740.0]),
#  DenseVector([1.0, 588.0, 1553.0, 1831.0, 740.0]),
#  DenseVector([1.0, 589.0, 1814.0, 2174.0, 770.0]),
#  DenseVector([1.0, 590.0, 1240.0, 1493.0, 590.0]),
#  DenseVector([1.0, 591.0, 1206.0, 1437.0, 1330.0]),
#  DenseVector([1.0, 592.0, 1847.0, 2186.0, 910.0]),
#  DenseVector([1.0, 593.0, 1009.0, 1202.0, 330.0]),
#  DenseVector([1.0, 594.0, 1624.0, 1946.0, 870.0]),
#  DenseVector([1.0, 595.0, 1612.0, 1931.0, 790.0]),
#  DenseVector([1.0, 596.0, 1498.0, 1805.0, 1270.0]),
#  DenseVector([1.0, 597.0, 946.0, 1125.0, 590.0]),
#  DenseVector([1.0, 598.0, 1563.0, 1872.0, 1080.0]),
#  DenseVector([1.0, 599.0, 1664.0, 2016.0, 830.0]),
#  DenseVector([1.0, 600.0, 1619.0, 1947.0, 910.0]),
#  DenseVector([1.0, 601.0, 1433.0, 1722.0, 830.0]),
#  DenseVector([1.0, 602.0, 1241.0, 1489.0, 1380.0]),
#  DenseVector([1.0, 603.0, 1429.0, 1720.0, 1180.0]),
#  DenseVector([1.0, 604.0, 1241.0, 1488.0, 770.0]),
#  DenseVector([1.0, 605.0, 1078.0, 1306.0, 680.0]),
#  DenseVector([1.0, 606.0, 1690.0, 2065.0, 910.0]),
#  DenseVector([1.0, 607.0, 1289.0, 1536.0, 540.0]),
#  DenseVector([1.0, 608.0, 1581.0, 1894.0, 760.0]),
#  DenseVector([1.0, 609.0, 1608.0, 1945.0, 760.0]),
#  DenseVector([1.0, 610.0, 1344.0, 1608.0, 730.0]),
#  DenseVector([1.0, 611.0, 1513.0, 1804.0, 430.0]),
#  DenseVector([1.0, 612.0, 1529.0, 1839.0, 1000.0]),
#  DenseVector([1.0, 613.0, 1677.0, 2014.0, 660.0]),
#  DenseVector([1.0, 614.0, 1015.0, 1229.0, 930.0]),
#  DenseVector([1.0, 615.0, 1438.0, 1751.0, 760.0]),
#  DenseVector([1.0, 616.0, 1426.0, 1718.0, 370.0]),
#  DenseVector([1.0, 617.0, 1412.0, 1701.0, 630.0]),
#  DenseVector([1.0, 618.0, 1622.0, 1944.0, 360.0]),
#  DenseVector([1.0, 619.0, 1503.0, 1791.0, 630.0]),
#  DenseVector([1.0, 620.0, 1501.0, 1789.0, 670.0]),
#  DenseVector([1.0, 621.0, 1971.0, 2342.0, 690.0]),
#  DenseVector([1.0, 622.0, 1383.0, 1687.0, 830.0]),
#  DenseVector([1.0, 623.0, 1371.0, 1635.0, 720.0]),
#  DenseVector([1.0, 624.0, 1508.0, 1823.0, 520.0]),
#  DenseVector([1.0, 625.0, 1057.0, 1284.0, 750.0]),
#  DenseVector([1.0, 626.0, 1411.0, 1680.0, 1070.0]),
#  DenseVector([1.0, 627.0, 1466.0, 1746.0, 590.0]),
#  DenseVector([1.0, 628.0, 1545.0, 1888.0, 600.0]),
#  DenseVector([1.0, 629.0, 2044.0, 2408.0, 380.0]),
#  DenseVector([1.0, 630.0, 1887.0, 2264.0, 830.0]),
#  DenseVector([1.0, 631.0, 1505.0, 1836.0, 940.0]),
#  DenseVector([1.0, 632.0, 1422.0, 1722.0, 560.0]),
#  DenseVector([1.0, 633.0, 1564.0, 1869.0, 1030.0]),
#  DenseVector([1.0, 634.0, 1510.0, 1810.0, 730.0]),
#  DenseVector([1.0, 635.0, 1568.0, 1920.0, 890.0]),
#  DenseVector([1.0, 636.0, 1933.0, 2338.0, 1140.0]),
#  DenseVector([1.0, 637.0, 1501.0, 1822.0, 590.0]),
#  DenseVector([1.0, 638.0, 1593.0, 1911.0, 580.0]),
#  DenseVector([1.0, 639.0, 1812.0, 2189.0, 310.0]),
#  DenseVector([1.0, 640.0, 1580.0, 1895.0, 720.0]),
#  DenseVector([1.0, 641.0, 1440.0, 1749.0, 490.0]),
#  DenseVector([1.0, 642.0, 1100.0, 1331.0, 1010.0]),
#  DenseVector([1.0, 643.0, 1534.0, 1841.0, 680.0]),
#  DenseVector([1.0, 644.0, 1299.0, 1555.0, 1020.0]),
#  DenseVector([1.0, 645.0, 1767.0, 2121.0, 1050.0]),
#  DenseVector([1.0, 646.0, 1368.0, 1649.0, 740.0]),
#  DenseVector([1.0, 647.0, 1393.0, 1670.0, 410.0]),
#  DenseVector([1.0, 648.0, 1327.0, 1590.0, 770.0]),
#  DenseVector([1.0, 649.0, 1514.0, 1794.0, 1400.0]),
#  DenseVector([1.0, 650.0, 1989.0, 2414.0, 860.0]),
#  DenseVector([1.0, 651.0, 1334.0, 1584.0, 840.0]),
#  DenseVector([1.0, 652.0, 1533.0, 1817.0, 950.0]),
#  DenseVector([1.0, 653.0, 1809.0, 2145.0, 940.0]),
#  DenseVector([1.0, 654.0, 1607.0, 1933.0, 930.0]),
#  DenseVector([1.0, 655.0, 1165.0, 1387.0, 1060.0]),
#  DenseVector([1.0, 656.0, 1193.0, 1430.0, 560.0]),
#  DenseVector([1.0, 657.0, 1709.0, 2065.0, 670.0]),
#  DenseVector([1.0, 658.0, 1525.0, 1839.0, 540.0]),
#  DenseVector([1.0, 659.0, 1348.0, 1623.0, 1010.0]),
#  DenseVector([1.0, 660.0, 1132.0, 1366.0, 1340.0]),
#  DenseVector([1.0, 661.0, 1667.0, 2020.0, 980.0]),
#  DenseVector([1.0, 662.0, 1427.0, 1720.0, 630.0]),
#  DenseVector([1.0, 663.0, 1211.0, 1447.0, 1110.0]),
#  DenseVector([1.0, 664.0, 1717.0, 2048.0, 700.0]),
#  DenseVector([1.0, 665.0, 1766.0, 2111.0, 580.0]),
#  DenseVector([1.0, 666.0, 1086.0, 1299.0, 1050.0]),
#  DenseVector([1.0, 667.0, 1410.0, 1692.0, 790.0]),
#  DenseVector([1.0, 668.0, 1476.0, 1760.0, 600.0]),
#  DenseVector([1.0, 669.0, 1068.0, 1278.0, 440.0]),
#  DenseVector([1.0, 670.0, 1485.0, 1785.0, 1340.0]),
#  DenseVector([1.0, 671.0, 1461.0, 1739.0, 1250.0]),
#  DenseVector([1.0, 672.0, 1685.0, 2010.0, 990.0]),
#  DenseVector([1.0, 673.0, 1624.0, 1958.0, 290.0]),
#  DenseVector([1.0, 674.0, 1658.0, 2000.0, 350.0]),
#  DenseVector([1.0, 675.0, 1427.0, 1677.0, 210.0]),
#  DenseVector([1.0, 676.0, 1755.0, 2072.0, 810.0]),
#  DenseVector([1.0, 677.0, 1211.0, 1472.0, 790.0]),
#  DenseVector([1.0, 678.0, 1591.0, 1896.0, 780.0]),
#  DenseVector([1.0, 679.0, 1797.0, 2126.0, 730.0]),
#  DenseVector([1.0, 680.0, 1519.0, 1823.0, 1040.0]),
#  DenseVector([1.0, 681.0, 1637.0, 1958.0, 760.0]),
#  DenseVector([1.0, 682.0, 1451.0, 1750.0, 570.0]),
#  DenseVector([1.0, 683.0, 1203.0, 1446.0, 620.0]),
#  DenseVector([1.0, 684.0, 1884.0, 2262.0, 310.0]),
#  DenseVector([1.0, 685.0, 1540.0, 1820.0, 310.0]),
#  DenseVector([1.0, 686.0, 1121.0, 1332.0, 790.0]),
#  DenseVector([1.0, 687.0, 1307.0, 1562.0, 490.0]),
#  DenseVector([1.0, 688.0, 1475.0, 1775.0, 230.0]),
#  DenseVector([1.0, 689.0, 1160.0, 1401.0, 900.0]),
#  DenseVector([1.0, 690.0, 1078.0, 1276.0, 640.0]),
#  DenseVector([1.0, 691.0, 1191.0, 1436.0, 840.0]),
#  DenseVector([1.0, 692.0, 1317.0, 1569.0, 780.0]),
#  DenseVector([1.0, 693.0, 1548.0, 1858.0, 480.0]),
#  DenseVector([1.0, 694.0, 1560.0, 1883.0, 1040.0]),
#  DenseVector([1.0, 695.0, 1297.0, 1529.0, 870.0]),
#  DenseVector([1.0, 696.0, 1645.0, 1958.0, 530.0]),
#  DenseVector([1.0, 697.0, 1225.0, 1455.0, 750.0]),
#  DenseVector([1.0, 698.0, 1421.0, 1704.0, 840.0]),
#  DenseVector([1.0, 699.0, 1655.0, 1956.0, 800.0]),
#  DenseVector([1.0, 700.0, 1615.0, 1928.0, 660.0]),
#  DenseVector([1.0, 701.0, 1872.0, 2262.0, 560.0]),
#  DenseVector([1.0, 702.0, 1317.0, 1581.0, 910.0]),
#  DenseVector([1.0, 703.0, 1434.0, 1729.0, 480.0]),
#  DenseVector([1.0, 704.0, 1791.0, 2167.0, 700.0]),
#  DenseVector([1.0, 705.0, 932.0, 1120.0, 660.0]),
#  DenseVector([1.0, 706.0, 1609.0, 1924.0, 1170.0]),
#  DenseVector([1.0, 707.0, 1495.0, 1793.0, 1020.0]),
#  DenseVector([1.0, 708.0, 1769.0, 2153.0, 580.0]),
#  DenseVector([1.0, 709.0, 1693.0, 2032.0, 610.0]),
#  DenseVector([1.0, 710.0, 1247.0, 1497.0, 590.0]),
#  DenseVector([1.0, 711.0, 1502.0, 1815.0, 190.0]),
#  DenseVector([1.0, 712.0, 1360.0, 1612.0, 490.0]),
#  DenseVector([1.0, 713.0, 1542.0, 1844.0, 680.0]),
#  DenseVector([1.0, 714.0, 1631.0, 1947.0, 670.0]),
#  DenseVector([1.0, 715.0, 1246.0, 1482.0, 1070.0]),
#  DenseVector([1.0, 716.0, 1990.0, 2384.0, 1110.0]),
#  DenseVector([1.0, 717.0, 967.0, 1154.0, 560.0]),
#  DenseVector([1.0, 718.0, 1582.0, 1894.0, 1100.0]),
#  DenseVector([1.0, 719.0, 1430.0, 1743.0, 970.0]),
#  DenseVector([1.0, 720.0, 1827.0, 2160.0, 930.0]),
#  DenseVector([1.0, 721.0, 1118.0, 1338.0, 1040.0]),
#  DenseVector([1.0, 722.0, 1766.0, 2109.0, 1120.0]),
#  DenseVector([1.0, 723.0, 1799.0, 2173.0, 910.0]),
#  DenseVector([1.0, 724.0, 1167.0, 1411.0, 440.0]),
#  DenseVector([1.0, 725.0, 1493.0, 1795.0, 530.0]),
#  DenseVector([1.0, 726.0, 1445.0, 1734.0, 900.0]),
#  DenseVector([1.0, 727.0, 1033.0, 1237.0, 740.0]),
#  DenseVector([1.0, 728.0, 1440.0, 1711.0, 1020.0]),
#  DenseVector([1.0, 729.0, 1487.0, 1773.0, 970.0]),
#  DenseVector([1.0, 730.0, 1854.0, 2205.0, 890.0]),
#  DenseVector([1.0, 731.0, 1748.0, 2086.0, 550.0]),
#  DenseVector([1.0, 732.0, 1937.0, 2310.0, 520.0]),
#  DenseVector([1.0, 733.0, 1641.0, 1999.0, 950.0]),
#  DenseVector([1.0, 734.0, 1659.0, 1999.0, 650.0]),
#  DenseVector([1.0, 735.0, 1743.0, 2061.0, 860.0]),
#  DenseVector([1.0, 736.0, 1449.0, 1733.0, 320.0]),
#  DenseVector([1.0, 737.0, 1098.0, 1309.0, 860.0]),
#  DenseVector([1.0, 738.0, 1121.0, 1351.0, 900.0]),
#  DenseVector([1.0, 739.0, 1526.0, 1858.0, 550.0]),
#  DenseVector([1.0, 740.0, 1358.0, 1645.0, 770.0]),
#  DenseVector([1.0, 741.0, 1336.0, 1616.0, 710.0]),
#  DenseVector([1.0, 742.0, 1502.0, 1802.0, 840.0]),
#  DenseVector([1.0, 743.0, 1534.0, 1858.0, 860.0]),
#  DenseVector([1.0, 744.0, 1418.0, 1699.0, 870.0]),
#  DenseVector([1.0, 745.0, 854.0, 1018.0, 660.0]),
#  DenseVector([1.0, 746.0, 1450.0, 1728.0, 930.0]),
#  DenseVector([1.0, 747.0, 1474.0, 1776.0, 1020.0]),
#  DenseVector([1.0, 748.0, 1524.0, 1819.0, 1190.0]),
#  DenseVector([1.0, 749.0, 1361.0, 1638.0, 1140.0]),
#  DenseVector([1.0, 750.0, 1398.0, 1683.0, 490.0]),
#  DenseVector([1.0, 751.0, 1085.0, 1308.0, 1170.0]),
#  DenseVector([1.0, 752.0, 1660.0, 1979.0, 480.0]),
#  DenseVector([1.0, 753.0, 1648.0, 2017.0, 930.0]),
#  DenseVector([1.0, 754.0, 1453.0, 1749.0, 890.0]),
#  DenseVector([1.0, 755.0, 1323.0, 1591.0, 680.0]),
#  DenseVector([1.0, 756.0, 1385.0, 1643.0, 740.0]),
#  DenseVector([1.0, 757.0, 1250.0, 1506.0, 990.0]),
#  DenseVector([1.0, 758.0, 1389.0, 1683.0, 680.0]),
#  DenseVector([1.0, 759.0, 1486.0, 1758.0, 820.0]),
#  DenseVector([1.0, 760.0, 1655.0, 1993.0, 440.0]),
#  DenseVector([1.0, 761.0, 1645.0, 1963.0, 900.0]),
#  DenseVector([1.0, 762.0, 1464.0, 1771.0, 1080.0]),
#  DenseVector([1.0, 763.0, 1197.0, 1428.0, 830.0]),
#  DenseVector([1.0, 764.0, 1878.0, 2264.0, 310.0]),
#  DenseVector([1.0, 765.0, 1150.0, 1378.0, 730.0]),
#  DenseVector([1.0, 766.0, 1562.0, 1881.0, 740.0]),
#  DenseVector([1.0, 767.0, 1596.0, 1939.0, 960.0]),
#  DenseVector([1.0, 768.0, 1119.0, 1345.0, 790.0]),
#  DenseVector([1.0, 769.0, 1116.0, 1347.0, 700.0]),
#  DenseVector([1.0, 770.0, 1934.0, 2349.0, 750.0]),
#  DenseVector([1.0, 771.0, 1299.0, 1540.0, 590.0]),
#  DenseVector([1.0, 772.0, 1417.0, 1689.0, 570.0]),
#  DenseVector([1.0, 773.0, 1235.0, 1503.0, 660.0]),
#  DenseVector([1.0, 774.0, 1497.0, 1815.0, 700.0]),
#  DenseVector([1.0, 775.0, 1430.0, 1704.0, 1070.0]),
#  DenseVector([1.0, 776.0, 1537.0, 1877.0, 660.0]),
#  DenseVector([1.0, 777.0, 1444.0, 1742.0, 840.0]),
#  DenseVector([1.0, 778.0, 1477.0, 1798.0, 850.0]),
#  DenseVector([1.0, 779.0, 1041.0, 1246.0, 600.0]),
#  DenseVector([1.0, 780.0, 1226.0, 1472.0, 710.0]),
#  DenseVector([1.0, 781.0, 1489.0, 1783.0, 450.0]),
#  DenseVector([1.0, 782.0, 1549.0, 1871.0, 740.0]),
#  DenseVector([1.0, 783.0, 1073.0, 1280.0, 1240.0]),
#  DenseVector([1.0, 784.0, 1473.0, 1785.0, 570.0]),
#  DenseVector([1.0, 785.0, 2013.0, 2396.0, 580.0]),
#  DenseVector([1.0, 786.0, 1975.0, 2368.0, 450.0]),
#  DenseVector([1.0, 787.0, 1561.0, 1877.0, 790.0]),
#  DenseVector([1.0, 788.0, 1427.0, 1723.0, 1040.0]),
#  DenseVector([1.0, 789.0, 1441.0, 1747.0, 670.0]),
#  DenseVector([1.0, 790.0, 1275.0, 1548.0, 370.0]),
#  DenseVector([1.0, 791.0, 1574.0, 1876.0, 620.0]),
#  DenseVector([1.0, 792.0, 1511.0, 1791.0, 1010.0]),
#  DenseVector([1.0, 793.0, 1428.0, 1713.0, 550.0]),
#  DenseVector([1.0, 794.0, 1388.0, 1672.0, 800.0]),
#  DenseVector([1.0, 795.0, 1057.0, 1280.0, 610.0]),
#  DenseVector([1.0, 796.0, 1440.0, 1747.0, 1090.0]),
#  DenseVector([1.0, 797.0, 1349.0, 1610.0, 700.0]),
#  DenseVector([1.0, 798.0, 1536.0, 1808.0, 830.0]),
#  DenseVector([1.0, 799.0, 2019.0, 2420.0, 850.0]),
#  DenseVector([1.0, 800.0, 1236.0, 1508.0, 1260.0]),
#  DenseVector([1.0, 801.0, 1436.0, 1715.0, 1030.0]),
#  DenseVector([1.0, 802.0, 1862.0, 2248.0, 1160.0]),
#  DenseVector([1.0, 803.0, 1200.0, 1442.0, 880.0]),
#  DenseVector([1.0, 804.0, 1360.0, 1650.0, 420.0]),
#  DenseVector([1.0, 805.0, 1722.0, 2078.0, 770.0]),
#  DenseVector([1.0, 806.0, 1577.0, 1902.0, 910.0]),
#  DenseVector([1.0, 807.0, 1850.0, 2214.0, 1110.0]),
#  DenseVector([1.0, 808.0, 1447.0, 1730.0, 510.0]),
#  DenseVector([1.0, 809.0, 1496.0, 1800.0, 780.0]),
#  DenseVector([1.0, 810.0, 1679.0, 2008.0, 790.0]),
#  DenseVector([1.0, 811.0, 994.0, 1194.0, 1090.0]),
#  DenseVector([1.0, 812.0, 1354.0, 1635.0, 1270.0]),
#  DenseVector([1.0, 813.0, 1597.0, 1918.0, 1260.0]),
#  DenseVector([1.0, 814.0, 1873.0, 2252.0, 330.0]),
#  DenseVector([1.0, 815.0, 1218.0, 1459.0, 540.0]),
#  DenseVector([1.0, 816.0, 1458.0, 1746.0, 720.0]),
#  DenseVector([1.0, 817.0, 1546.0, 1860.0, 670.0]),
#  DenseVector([1.0, 818.0, 1608.0, 1962.0, 770.0]),
#  DenseVector([1.0, 819.0, 1822.0, 2160.0, 860.0]),
#  DenseVector([1.0, 820.0, 1716.0, 2038.0, 410.0]),
#  DenseVector([1.0, 821.0, 1072.0, 1296.0, 900.0]),
#  DenseVector([1.0, 822.0, 1330.0, 1604.0, 480.0]),
#  DenseVector([1.0, 823.0, 1588.0, 1892.0, 540.0]),
#  DenseVector([1.0, 824.0, 1425.0, 1733.0, 760.0]),
#  DenseVector([1.0, 825.0, 1778.0, 2133.0, 280.0]),
#  DenseVector([1.0, 826.0, 1363.0, 1630.0, 1120.0]),
#  DenseVector([1.0, 827.0, 1609.0, 1928.0, 160.0]),
#  DenseVector([1.0, 828.0, 1671.0, 2024.0, 620.0]),
#  DenseVector([1.0, 829.0, 1379.0, 1636.0, 440.0]),
#  DenseVector([1.0, 830.0, 1218.0, 1452.0, 870.0]),
#  DenseVector([1.0, 831.0, 1724.0, 2101.0, 900.0]),
#  DenseVector([1.0, 832.0, 986.0, 1179.0, 710.0]),
#  DenseVector([1.0, 833.0, 1330.0, 1606.0, 590.0]),
#  DenseVector([1.0, 834.0, 1437.0, 1725.0, 910.0]),
#  DenseVector([1.0, 835.0, 1327.0, 1609.0, 1320.0]),
#  DenseVector([1.0, 836.0, 1651.0, 2009.0, 1000.0]),
#  DenseVector([1.0, 837.0, 1211.0, 1462.0, 670.0]),
#  DenseVector([1.0, 838.0, 1916.0, 2277.0, 610.0]),
#  DenseVector([1.0, 839.0, 1638.0, 1937.0, 1050.0]),
#  DenseVector([1.0, 840.0, 1172.0, 1413.0, 480.0]),
#  DenseVector([1.0, 841.0, 1350.0, 1606.0, 770.0]),
#  DenseVector([1.0, 842.0, 1528.0, 1843.0, 340.0]),
#  DenseVector([1.0, 843.0, 1305.0, 1557.0, 580.0]),
#  DenseVector([1.0, 844.0, 1463.0, 1751.0, 900.0]),
#  DenseVector([1.0, 845.0, 1409.0, 1727.0, 700.0]),
#  DenseVector([1.0, 846.0, 1419.0, 1743.0, 860.0]),
#  DenseVector([1.0, 847.0, 1535.0, 1819.0, 540.0]),
#  DenseVector([1.0, 848.0, 1474.0, 1745.0, 970.0]),
#  DenseVector([1.0, 849.0, 919.0, 1099.0, 1560.0]),
#  DenseVector([1.0, 850.0, 2067.0, 2492.0, 790.0]),
#  DenseVector([1.0, 851.0, 1977.0, 2362.0, 1020.0]),
#  DenseVector([1.0, 852.0, 1293.0, 1558.0, 790.0]),
#  DenseVector([1.0, 853.0, 1477.0, 1790.0, 880.0]),
#  DenseVector([1.0, 854.0, 1582.0, 1906.0, 550.0]),
#  DenseVector([1.0, 855.0, 1481.0, 1789.0, 550.0]),
#  DenseVector([1.0, 856.0, 1214.0, 1455.0, 950.0]),
#  DenseVector([1.0, 857.0, 1206.0, 1460.0, 810.0]),
#  DenseVector([1.0, 858.0, 1653.0, 1982.0, 390.0]),
#  DenseVector([1.0, 859.0, 1152.0, 1393.0, 860.0]),
#  DenseVector([1.0, 860.0, 1458.0, 1757.0, 850.0]),
#  DenseVector([1.0, 861.0, 1249.0, 1510.0, 660.0]),
#  DenseVector([1.0, 862.0, 1939.0, 2333.0, 830.0]),
#  DenseVector([1.0, 863.0, 1591.0, 1919.0, 640.0]),
#  DenseVector([1.0, 864.0, 1180.0, 1397.0, 750.0]),
#  DenseVector([1.0, 865.0, 1846.0, 2195.0, 1170.0]),
#  DenseVector([1.0, 866.0, 780.0, 951.0, 790.0]),
#  DenseVector([1.0, 867.0, 1565.0, 1854.0, 900.0]),
#  DenseVector([1.0, 868.0, 1648.0, 1959.0, 370.0]),
#  DenseVector([1.0, 869.0, 1775.0, 2104.0, 980.0]),
#  DenseVector([1.0, 870.0, 1439.0, 1732.0, 1170.0]),
#  DenseVector([1.0, 871.0, 1487.0, 1776.0, 800.0]),
#  DenseVector([1.0, 872.0, 1800.0, 2158.0, 1100.0]),
#  DenseVector([1.0, 873.0, 1690.0, 2024.0, 1070.0]),
#  DenseVector([1.0, 874.0, 1209.0, 1452.0, 830.0]),
#  DenseVector([1.0, 875.0, 1859.0, 2222.0, 1210.0]),
#  DenseVector([1.0, 876.0, 1691.0, 2023.0, 540.0]),
#  DenseVector([1.0, 877.0, 1259.0, 1493.0, 100.0]),
#  DenseVector([1.0, 878.0, 1771.0, 2138.0, 820.0]),
#  DenseVector([1.0, 879.0, 1205.0, 1468.0, 1210.0]),
#  DenseVector([1.0, 880.0, 1792.0, 2131.0, 810.0]),
#  DenseVector([1.0, 881.0, 1263.0, 1516.0, 780.0]),
#  DenseVector([1.0, 882.0, 1344.0, 1605.0, 1160.0]),
#  DenseVector([1.0, 883.0, 1819.0, 2187.0, 590.0]),
#  DenseVector([1.0, 884.0, 1357.0, 1625.0, 1140.0]),
#  DenseVector([1.0, 885.0, 1396.0, 1673.0, 690.0]),
#  DenseVector([1.0, 886.0, 1118.0, 1337.0, 560.0]),
#  DenseVector([1.0, 887.0, 1655.0, 1986.0, 1150.0]),
#  DenseVector([1.0, 888.0, 1156.0, 1398.0, 140.0]),
#  DenseVector([1.0, 889.0, 1451.0, 1734.0, 670.0]),
#  DenseVector([1.0, 890.0, 1539.0, 1829.0, 650.0]),
#  DenseVector([1.0, 891.0, 1549.0, 1851.0, 1220.0]),
#  DenseVector([1.0, 892.0, 1582.0, 1910.0, 1080.0]),
#  DenseVector([1.0, 893.0, 1387.0, 1663.0, 850.0]),
#  DenseVector([1.0, 894.0, 1200.0, 1436.0, 1060.0]),
#  DenseVector([1.0, 895.0, 1299.0, 1560.0, 770.0]),
#  DenseVector([1.0, 896.0, 1174.0, 1429.0, 1110.0])]

# %%
#Transform to a Data Frame for input to Machine Learing
#Drop columns that are not required (low correlation)

from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)

def transformToLabeledPoint(inStr) :
    attList=inStr.split(",")
    lp = ( attList[4], Vectors.dense([attList[0],attList[2],attList[3]]))
    return lp

# %%
irisLp = dataLines.map(transformToLabeledPoint)
irisDF = sqlContext.createDataFrame(irisLp,["label", "features"])
irisDF.select("label","features").show(10)
# Out:
# +-----+--------------------+
# |label|            features|
# +-----+--------------------+
# |66490|  [1.0,1961.0,530.0]|
# |39820|  [2.0,1752.0,210.0]|
# |54010|  [3.0,1609.0,720.0]|
# |53730|  [4.0,1748.0,620.0]|
# |46620|  [5.0,2111.0,450.0]|
# |45260|  [6.0,1733.0,760.0]|
# |72240| [7.0,1858.0,1030.0]|
# |37720| [8.0,1507.0,1020.0]|
# |46310|  [9.0,1321.0,680.0]|
# |44150|[10.0,1235.0,1130.0]|
# +-----+--------------------+
# only showing top 10 rows

# %%
#Indexing needed as pre-req for Decision Trees
from pyspark.ml.feature import StringIndexer
stringIndexer = StringIndexer(inputCol="label", outputCol="indexed")
si_model = stringIndexer.fit(irisDF)
td = si_model.transform(irisDF)
td.collect()
# Out:
# Out[17]: [Row(label='66490', features=DenseVector([1.0, 1961.0, 530.0]), indexed=566.0),
#  Row(label='39820', features=DenseVector([2.0, 1752.0, 210.0]), indexed=197.0),
#  Row(label='54010', features=DenseVector([3.0, 1609.0, 720.0]), indexed=399.0),
#  Row(label='53730', features=DenseVector([4.0, 1748.0, 620.0]), indexed=393.0),
#  Row(label='46620', features=DenseVector([5.0, 2111.0, 450.0]), indexed=283.0),
#  Row(label='45260', features=DenseVector([6.0, 1733.0, 760.0]), indexed=264.0),
#  Row(label='72240', features=DenseVector([7.0, 1858.0, 1030.0]), indexed=639.0),
#  Row(label='37720', features=DenseVector([8.0, 1507.0, 1020.0]), indexed=169.0),
#  Row(label='46310', features=DenseVector([9.0, 1321.0, 680.0]), indexed=281.0),
#  Row(label='44150', features=DenseVector([10.0, 1235.0, 1130.0]), indexed=250.0),
#  Row(label='71280', features=DenseVector([11.0, 1439.0, 1090.0]), indexed=627.0),
#  Row(label='57620', features=DenseVector([12.0, 2098.0, 720.0]), indexed=455.0),
#  Row(label='60470', features=DenseVector([13.0, 2064.0, 1050.0]), indexed=40.0),
#  Row(label='59130', features=DenseVector([14.0, 1931.0, 1160.0]), indexed=35.0),
#  Row(label='66360', features=DenseVector([15.0, 1756.0, 770.0]), indexed=565.0),
#  Row(label='78870', features=DenseVector([16.0, 1950.0, 790.0]), indexed=69.0),
#  Row(label='77250', features=DenseVector([17.0, 1907.0, 1440.0]), indexed=698.0),
#  Row(label='38170', features=DenseVector([18.0, 2045.0, 670.0]), indexed=175.0),
#  Row(label='63540', features=DenseVector([19.0, 1731.0, 1030.0]), indexed=1.0),
#  Row(label='40190', features=DenseVector([20.0, 2340.0, 980.0]), indexed=200.0),
#  Row(label='43460', features=DenseVector([21.0, 1700.0, 370.0]), indexed=240.0),
#  Row(label='68890', features=DenseVector([22.0, 1746.0, 690.0]), indexed=53.0),
#  Row(label='52780', features=DenseVector([23.0, 2065.0, 950.0]), indexed=24.0),
#  Row(label='50680', features=DenseVector([24.0, 1752.0, 620.0]), indexed=343.0),
#  Row(label='41880', features=DenseVector([25.0, 1488.0, 840.0]), indexed=221.0),
#  Row(label='70050', features=DenseVector([26.0, 2073.0, 820.0]), indexed=611.0),
#  Row(label='25820', features=DenseVector([27.0, 1777.0, 1100.0]), indexed=100.0),
#  Row(label='60530', features=DenseVector([28.0, 1648.0, 980.0]), indexed=41.0),
#  Row(label='78100', features=DenseVector([29.0, 1943.0, 710.0]), indexed=67.0),
#  Row(label='84860', features=DenseVector([30.0, 2071.0, 650.0]), indexed=758.0),
#  Row(label='80140', features=DenseVector([31.0, 1746.0, 990.0]), indexed=722.0),
#  Row(label='14920', features=DenseVector([32.0, 1508.0, 990.0]), indexed=85.0),
#  Row(label='60460', features=DenseVector([33.0, 1608.0, 880.0]), indexed=488.0),
#  Row(label='74560', features=DenseVector([34.0, 2163.0, 620.0]), indexed=670.0),
#  Row(label='72430', features=DenseVector([35.0, 1648.0, 1020.0]), indexed=644.0),
#  Row(label='45460', features=DenseVector([36.0, 2230.0, 700.0]), indexed=265.0),
#  Row(label='41570', features=DenseVector([37.0, 1744.0, 610.0]), indexed=215.0),
#  Row(label='62870', features=DenseVector([38.0, 1411.0, 1080.0]), indexed=515.0),
#  Row(label='55170', features=DenseVector([39.0, 2204.0, 1010.0]), indexed=416.0),
#  Row(label='45480', features=DenseVector([40.0, 1516.0, 10.0]), indexed=266.0),
#  Row(label='49550', features=DenseVector([41.0, 1725.0, 1250.0]), indexed=328.0),
#  Row(label='48140', features=DenseVector([42.0, 1152.0, 600.0]), indexed=307.0),
#  Row(label='67640', features=DenseVector([43.0, 2001.0, 730.0]), indexed=583.0),
#  Row(label='39730', features=DenseVector([44.0, 2117.0, 780.0]), indexed=7.0),
#  Row(label='35800', features=DenseVector([45.0, 1194.0, 520.0]), indexed=150.0),
#  Row(label='49270', features=DenseVector([46.0, 1471.0, 870.0]), indexed=321.0),
#  Row(label='66510', features=DenseVector([47.0, 2087.0, 690.0]), indexed=567.0),
#  Row(label='62530', features=DenseVector([48.0, 1982.0, 910.0]), indexed=511.0),
#  Row(label='59980', features=DenseVector([49.0, 1776.0, 1260.0]), indexed=484.0),
#  Row(label='76350', features=DenseVector([50.0, 1688.0, 1040.0]), indexed=689.0),
#  Row(label='81820', features=DenseVector([51.0, 1820.0, 910.0]), indexed=737.0),
#  Row(label='57830', features=DenseVector([52.0, 1880.0, 1300.0]), indexed=458.0),
#  Row(label='70450', features=DenseVector([53.0, 1288.0, 320.0]), indexed=617.0),
#  Row(label='67000', features=DenseVector([54.0, 2240.0, 530.0]), indexed=569.0),
#  Row(label='64090', features=DenseVector([55.0, 1898.0, 980.0]), indexed=530.0),
#  Row(label='48670', features=DenseVector([56.0, 1701.0, 740.0]), indexed=315.0),
#  Row(label='66210', features=DenseVector([57.0, 2060.0, 1240.0]), indexed=562.0),
#  Row(label='83660', features=DenseVector([58.0, 1763.0, 1080.0]), indexed=751.0),
#  Row(label='70770', features=DenseVector([59.0, 2104.0, 1080.0]), indexed=621.0),
#  Row(label='53870', features=DenseVector([60.0, 2070.0, 460.0]), indexed=396.0),
#  Row(label='71300', features=DenseVector([61.0, 2045.0, 300.0]), indexed=629.0),
#  Row(label='46100', features=DenseVector([62.0, 2391.0, 530.0]), indexed=277.0),
#  Row(label='49100', features=DenseVector([63.0, 1748.0, 600.0]), indexed=319.0),
#  Row(label='65920', features=DenseVector([64.0, 1561.0, 860.0]), indexed=555.0),
#  Row(label='58660', features=DenseVector([65.0, 1821.0, 590.0]), indexed=33.0),
#  Row(label='69130', features=DenseVector([66.0, 2052.0, 920.0]), indexed=54.0),
#  Row(label='49080', features=DenseVector([67.0, 2262.0, 570.0]), indexed=318.0),
#  Row(label='72710', features=DenseVector([68.0, 1681.0, 290.0]), indexed=647.0),
#  Row(label='33430', features=DenseVector([69.0, 1941.0, 650.0]), indexed=127.0),
#  Row(label='42430', features=DenseVector([70.0, 1576.0, 710.0]), indexed=226.0),
#  Row(label='56650', features=DenseVector([71.0, 2019.0, 850.0]), indexed=436.0),
#  Row(label='33580', features=DenseVector([72.0, 1380.0, 530.0]), indexed=129.0),
#  Row(label='67370', features=DenseVector([73.0, 1073.0, 630.0]), indexed=578.0),
#  Row(label='71780', features=DenseVector([74.0, 1749.0, 700.0]), indexed=633.0),
#  Row(label='84840', features=DenseVector([75.0, 1833.0, 650.0]), indexed=757.0),
#  Row(label='82070', features=DenseVector([76.0, 1956.0, 720.0]), indexed=741.0),
#  Row(label='26770', features=DenseVector([77.0, 1520.0, 450.0]), indexed=103.0),
#  Row(label='65560', features=DenseVector([78.0, 1475.0, 1390.0]), indexed=550.0),
#  Row(label='38660', features=DenseVector([79.0, 2044.0, 960.0]), indexed=182.0),
#  Row(label='65660', features=DenseVector([80.0, 1761.0, 600.0]), indexed=48.0),
#  Row(label='40700', features=DenseVector([81.0, 1711.0, 620.0]), indexed=206.0),
#  Row(label='88910', features=DenseVector([82.0, 1858.0, 1020.0]), indexed=785.0),
#  Row(label='57860', features=DenseVector([83.0, 1723.0, 330.0]), indexed=459.0),
#  Row(label='42670', features=DenseVector([84.0, 1884.0, 1410.0]), indexed=229.0),
#  Row(label='90180', features=DenseVector([85.0, 1525.0, 1200.0]), indexed=791.0),
#  Row(label='51280', features=DenseVector([86.0, 1760.0, 280.0]), indexed=359.0),
#  Row(label='97260', features=DenseVector([87.0, 2342.0, 940.0]), indexed=811.0),
#  Row(label='39650', features=DenseVector([88.0, 1506.0, 850.0]), indexed=193.0),
#  Row(label='45720', features=DenseVector([89.0, 1468.0, 960.0]), indexed=269.0),
#  Row(label='42060', features=DenseVector([90.0, 1758.0, 420.0]), indexed=224.0),
#  Row(label='65350', features=DenseVector([91.0, 1912.0, 830.0]), indexed=546.0),
#  Row(label='67080', features=DenseVector([92.0, 2617.0, 600.0]), indexed=571.0),
#  Row(label='54030', features=DenseVector([93.0, 2205.0, 400.0]), indexed=400.0),
#  Row(label='56360', features=DenseVector([94.0, 1655.0, 760.0]), indexed=430.0),
#  Row(label='77120', features=DenseVector([95.0, 2305.0, 1470.0]), indexed=65.0),
#  Row(label='50810', features=DenseVector([96.0, 2385.0, 500.0]), indexed=348.0),
#  Row(label='60960', features=DenseVector([97.0, 2235.0, 1120.0]), indexed=493.0),
#  Row(label='61180', features=DenseVector([98.0, 2171.0, 1160.0]), indexed=498.0),
#  Row(label='63660', features=DenseVector([99.0, 2147.0, 820.0]), indexed=47.0),
#  Row(label='41190', features=DenseVector([100.0, 1899.0, 1140.0]), indexed=212.0),
#  Row(label='78420', features=DenseVector([101.0, 1321.0, 900.0]), indexed=709.0),
#  Row(label='65580', features=DenseVector([102.0, 2294.0, 760.0]), indexed=551.0),
#  Row(label='89080', features=DenseVector([103.0, 1500.0, 1170.0]), indexed=786.0),
#  Row(label='94170', features=DenseVector([104.0, 1655.0, 1080.0]), indexed=804.0),
#  Row(label='50950', features=DenseVector([105.0, 1587.0, 1000.0]), indexed=353.0),
#  Row(label='65180', features=DenseVector([106.0, 1434.0, 690.0]), indexed=543.0),
#  Row(label='69310', features=DenseVector([107.0, 2031.0, 810.0]), indexed=601.0),
#  Row(label='79210', features=DenseVector([108.0, 2311.0, 630.0]), indexed=715.0),
#  Row(label='23740', features=DenseVector([109.0, 1878.0, 650.0]), indexed=96.0),
#  Row(label='36330', features=DenseVector([110.0, 1700.0, 920.0]), indexed=157.0),
#  Row(label='51700', features=DenseVector([111.0, 1382.0, 1260.0]), indexed=366.0),
#  Row(label='62950', features=DenseVector([112.0, 1787.0, 800.0]), indexed=516.0),
#  Row(label='56010', features=DenseVector([113.0, 2248.0, 1330.0]), indexed=426.0),
#  Row(label='45080', features=DenseVector([114.0, 1927.0, 940.0]), indexed=13.0),
#  Row(label='46830', features=DenseVector([115.0, 2287.0, 1210.0]), indexed=287.0),
#  Row(label='64750', features=DenseVector([116.0, 1503.0, 660.0]), indexed=536.0),
#  Row(label='80780', features=DenseVector([117.0, 1379.0, 770.0]), indexed=729.0),
#  Row(label='31180', features=DenseVector([118.0, 2046.0, 460.0]), indexed=2.0),
#  Row(label='56710', features=DenseVector([119.0, 1798.0, 860.0]), indexed=31.0),
#  Row(label='49390', features=DenseVector([120.0, 2017.0, 780.0]), indexed=325.0),
#  Row(label='66000', features=DenseVector([121.0, 1727.0, 890.0]), indexed=50.0),
#  Row(label='32770', features=DenseVector([122.0, 1835.0, 900.0]), indexed=123.0),
#  Row(label='46580', features=DenseVector([123.0, 1669.0, 530.0]), indexed=15.0),
#  Row(label='79780', features=DenseVector([124.0, 2333.0, 790.0]), indexed=71.0),
#  Row(label='35510', features=DenseVector([125.0, 1390.0, 370.0]), indexed=146.0),
#  Row(label='80970', features=DenseVector([126.0, 2137.0, 610.0]), indexed=732.0),
#  Row(label='61150', features=DenseVector([127.0, 2241.0, 500.0]), indexed=497.0),
#  Row(label='49210', features=DenseVector([128.0, 2051.0, 750.0]), indexed=320.0),
#  Row(label='79950', features=DenseVector([129.0, 1636.0, 980.0]), indexed=721.0),
#  Row(label='68740', features=DenseVector([130.0, 1654.0, 530.0]), indexed=593.0),
#  Row(label='57480', features=DenseVector([131.0, 1595.0, 910.0]), indexed=452.0),
#  Row(label='72630', features=DenseVector([132.0, 1270.0, 620.0]), indexed=646.0),
#  Row(label='50070', features=DenseVector([133.0, 1672.0, 1170.0]), indexed=337.0),
#  Row(label='40490', features=DenseVector([134.0, 2071.0, 900.0]), indexed=204.0),
#  Row(label='51850', features=DenseVector([135.0, 1638.0, 980.0]), indexed=368.0),
#  Row(label='42840', features=DenseVector([136.0, 1993.0, 740.0]), indexed=231.0),
#  Row(label='60940', features=DenseVector([137.0, 1972.0, 810.0]), indexed=492.0),
#  Row(label='62280', features=DenseVector([138.0, 1905.0, 810.0]), indexed=508.0),
#  Row(label='76530', features=DenseVector([139.0, 2187.0, 300.0]), indexed=63.0),
#  Row(label='85130', features=DenseVector([140.0, 1412.0, 790.0]), indexed=760.0),
#  Row(label='48590', features=DenseVector([141.0, 2374.0, 800.0]), indexed=313.0),
#  Row(label='73080', features=DenseVector([142.0, 2042.0, 760.0]), indexed=651.0),
#  Row(label='48950', features=DenseVector([143.0, 1456.0, 530.0]), indexed=16.0),
#  Row(label='48560', features=DenseVector([144.0, 1805.0, 540.0]), indexed=312.0),
#  Row(label='59380', features=DenseVector([145.0, 1770.0, 620.0]), indexed=475.0),
#  Row(label='51190', features=DenseVector([146.0, 1762.0, 1010.0]), indexed=356.0),
#  Row(label='58920', features=DenseVector([147.0, 1750.0, 130.0]), indexed=471.0),
#  Row(label='50360', features=DenseVector([148.0, 1486.0, 730.0]), indexed=340.0),
#  Row(label='38070', features=DenseVector([149.0, 1480.0, 830.0]), indexed=173.0),
#  Row(label='49170', features=DenseVector([150.0, 2300.0, 1060.0]), indexed=18.0),
#  Row(label='39740', features=DenseVector([151.0, 1629.0, 770.0]), indexed=195.0),
#  Row(label='63730', features=DenseVector([152.0, 1986.0, 70.0]), indexed=525.0),
#  Row(label='85330', features=DenseVector([153.0, 1855.0, 670.0]), indexed=762.0),
#  Row(label='27410', features=DenseVector([154.0, 1963.0, 490.0]), indexed=105.0),
#  Row(label='37320', features=DenseVector([155.0, 1663.0, 670.0]), indexed=166.0),
#  Row(label='71120', features=DenseVector([156.0, 1734.0, 380.0]), indexed=625.0),
#  Row(label='72800', features=DenseVector([157.0, 1921.0, 1200.0]), indexed=649.0),
#  Row(label='34410', features=DenseVector([158.0, 1696.0, 350.0]), indexed=137.0),
#  Row(label='42530', features=DenseVector([159.0, 932.0, 1090.0]), indexed=227.0),
#  Row(label='54300', features=DenseVector([160.0, 1534.0, 1230.0]), indexed=402.0),
#  Row(label='50780', features=DenseVector([161.0, 2078.0, 680.0]), indexed=347.0),
#  Row(label='45020', features=DenseVector([162.0, 1657.0, 580.0]), indexed=262.0),
#  Row(label='69600', features=DenseVector([163.0, 1723.0, 680.0]), indexed=55.0),
#  Row(label='80340', features=DenseVector([164.0, 2474.0, 340.0]), indexed=723.0),
#  Row(label='37810', features=DenseVector([165.0, 2176.0, 700.0]), indexed=170.0),
#  Row(label='46140', features=DenseVector([166.0, 1133.0, 580.0]), indexed=278.0),
#  Row(label='99570', features=DenseVector([167.0, 1763.0, 680.0]), indexed=815.0),
#  Row(label='38650', features=DenseVector([168.0, 1606.0, 630.0]), indexed=181.0),
#  Row(label='49800', features=DenseVector([169.0, 1487.0, 860.0]), indexed=333.0),
#  Row(label='69910', features=DenseVector([170.0, 1765.0, 490.0]), indexed=608.0),
#  Row(label='44910', features=DenseVector([171.0, 1599.0, 870.0]), indexed=260.0),
#  Row(label='78470', features=DenseVector([172.0, 1837.0, 990.0]), indexed=711.0),
#  Row(label='47460', features=DenseVector([173.0, 1207.0, 670.0]), indexed=297.0),
#  Row(label='33460', features=DenseVector([174.0, 2145.0, 490.0]), indexed=128.0),
#  Row(label='44090', features=DenseVector([175.0, 1832.0, 580.0]), indexed=249.0),
#  Row(label='42620', features=DenseVector([176.0, 1619.0, 700.0]), indexed=228.0),
#  Row(label='69450', features=DenseVector([177.0, 1848.0, 670.0]), indexed=605.0),
#  Row(label='73120', features=DenseVector([178.0, 1902.0, 390.0]), indexed=652.0),
#  Row(label='48300', features=DenseVector([179.0, 2032.0, 590.0]), indexed=309.0),
#  Row(label='58090', features=DenseVector([180.0, 1941.0, 1350.0]), indexed=462.0),
#  Row(label='74250', features=DenseVector([181.0, 1939.0, 840.0]), indexed=665.0),
#  Row(label='40930', features=DenseVector([182.0, 1396.0, 1100.0]), indexed=209.0),
#  Row(label='70930', features=DenseVector([183.0, 2339.0, 950.0]), indexed=623.0),
#  Row(label='64670', features=DenseVector([184.0, 2053.0, 950.0]), indexed=534.0),
#  Row(label='77420', features=DenseVector([185.0, 1692.0, 650.0]), indexed=700.0),
#  Row(label='32330', features=DenseVector([186.0, 1717.0, 230.0]), indexed=120.0),
#  Row(label='41080', features=DenseVector([187.0, 1796.0, 1060.0]), indexed=8.0),
#  Row(label='42860', features=DenseVector([188.0, 1985.0, 1180.0]), indexed=10.0),
#  Row(label='68450', features=DenseVector([189.0, 1569.0, 710.0]), indexed=591.0),
#  Row(label='39730', features=DenseVector([190.0, 2000.0, 480.0]), indexed=7.0),
#  Row(label='83750', features=DenseVector([191.0, 1649.0, 810.0]), indexed=753.0),
#  Row(label='69940', features=DenseVector([192.0, 2148.0, 1140.0]), indexed=57.0),
#  Row(label='67710', features=DenseVector([193.0, 1770.0, 1070.0]), indexed=584.0),
#  Row(label='67360', features=DenseVector([194.0, 2115.0, 790.0]), indexed=577.0),
#  Row(label='52460', features=DenseVector([195.0, 1982.0, 690.0]), indexed=382.0),
#  Row(label='88760', features=DenseVector([196.0, 2215.0, 610.0]), indexed=784.0),
#  Row(label='67030', features=DenseVector([197.0, 1791.0, 1240.0]), indexed=570.0),
#  Row(label='78230', features=DenseVector([198.0, 1827.0, 840.0]), indexed=708.0),
#  Row(label='62270', features=DenseVector([199.0, 1808.0, 460.0]), indexed=507.0),
#  Row(label='49760', features=DenseVector([200.0, 1371.0, 940.0]), indexed=332.0),
#  Row(label='73660', features=DenseVector([201.0, 1744.0, 590.0]), indexed=658.0),
#  Row(label='72320', features=DenseVector([202.0, 1558.0, 890.0]), indexed=641.0),
#  Row(label='68890', features=DenseVector([203.0, 1579.0, 770.0]), indexed=53.0),
#  Row(label='34180', features=DenseVector([204.0, 1192.0, 900.0]), indexed=134.0),
#  Row(label='58260', features=DenseVector([205.0, 1857.0, 1020.0]), indexed=464.0),
#  Row(label='38120', features=DenseVector([206.0, 2149.0, 910.0]), indexed=174.0),
#  Row(label='49070', features=DenseVector([207.0, 1853.0, 660.0]), indexed=317.0),
#  Row(label='61660', features=DenseVector([208.0, 1677.0, 480.0]), indexed=502.0),
#  Row(label='37830', features=DenseVector([209.0, 2055.0, 1080.0]), indexed=4.0),
#  Row(label='52270', features=DenseVector([210.0, 1872.0, 690.0]), indexed=377.0),
#  Row(label='52280', features=DenseVector([211.0, 1572.0, 510.0]), indexed=378.0),
#  Row(label='70810', features=DenseVector([212.0, 1807.0, 1030.0]), indexed=58.0),
#  Row(label='71530', features=DenseVector([213.0, 1988.0, 370.0]), indexed=631.0),
#  Row(label='77260', features=DenseVector([214.0, 2245.0, 640.0]), indexed=699.0),
#  Row(label='75550', features=DenseVector([215.0, 1725.0, 750.0]), indexed=679.0),
#  Row(label='33730', features=DenseVector([216.0, 1909.0, 370.0]), indexed=130.0),
#  Row(label='66270', features=DenseVector([217.0, 1899.0, 840.0]), indexed=563.0),
#  Row(label='55820', features=DenseVector([218.0, 1829.0, 840.0]), indexed=422.0),
#  Row(label='68430', features=DenseVector([219.0, 1737.0, 890.0]), indexed=590.0),
#  Row(label='73990', features=DenseVector([220.0, 1687.0, 620.0]), indexed=662.0),
#  Row(label='62800', features=DenseVector([221.0, 1742.0, 310.0]), indexed=514.0),
#  Row(label='33740', features=DenseVector([222.0, 1922.0, 550.0]), indexed=131.0),
#  Row(label='63830', features=DenseVector([223.0, 1527.0, 380.0]), indexed=526.0),
#  Row(label='24410', features=DenseVector([224.0, 1606.0, 1200.0]), indexed=97.0),
#  Row(label='70020', features=DenseVector([225.0, 1962.0, 800.0]), indexed=610.0),
#  Row(label='92240', features=DenseVector([226.0, 2175.0, 870.0]), indexed=796.0),
#  Row(label='68230', features=DenseVector([227.0, 2227.0, 1220.0]), indexed=585.0),
#  Row(label='81870', features=DenseVector([228.0, 2053.0, 1080.0]), indexed=73.0),
#  Row(label='73860', features=DenseVector([229.0, 1595.0, 540.0]), indexed=661.0),
#  Row(label='77120', features=DenseVector([230.0, 1634.0, 880.0]), indexed=65.0),
#  Row(label='72350', features=DenseVector([231.0, 1628.0, 120.0]), indexed=642.0),
#  Row(label='49160', features=DenseVector([232.0, 1661.0, 1410.0]), indexed=17.0),
#  Row(label='45650', features=DenseVector([233.0, 1499.0, 570.0]), indexed=268.0),
#  Row(label='52780', features=DenseVector([234.0, 1649.0, 940.0]), indexed=24.0),
#  Row(label='90960', features=DenseVector([235.0, 1658.0, 760.0]), indexed=793.0),
#  Row(label='64950', features=DenseVector([236.0, 2110.0, 1200.0]), indexed=539.0),
#  Row(label='47230', features=DenseVector([237.0, 1434.0, 670.0]), indexed=293.0),
#  Row(label='83250', features=DenseVector([238.0, 1505.0, 950.0]), indexed=749.0),
#  Row(label='51950', features=DenseVector([239.0, 2247.0, 480.0]), indexed=370.0),
#  Row(label='66030', features=DenseVector([240.0, 2244.0, 920.0]), indexed=558.0),
#  Row(label='68590', features=DenseVector([241.0, 1609.0, 1150.0]), indexed=592.0),
#  Row(label='47140', features=DenseVector([242.0, 1848.0, 750.0]), indexed=292.0),
#  Row(label='69940', features=DenseVector([243.0, 1861.0, 370.0]), indexed=57.0),
#  Row(label='65890', features=DenseVector([244.0, 2397.0, 610.0]), indexed=49.0),
#  Row(label='89310', features=DenseVector([245.0, 1418.0, 1150.0]), indexed=787.0),
#  Row(label='58540', features=DenseVector([246.0, 2003.0, 1070.0]), indexed=468.0),
#  Row(label='78130', features=DenseVector([247.0, 1539.0, 790.0]), indexed=68.0),
#  Row(label='92300', features=DenseVector([248.0, 1559.0, 1070.0]), indexed=797.0),
#  Row(label='56170', features=DenseVector([249.0, 2097.0, 730.0]), indexed=427.0),
#  Row(label='46050', features=DenseVector([250.0, 1976.0, 620.0]), indexed=14.0),
#  Row(label='43390', features=DenseVector([251.0, 1648.0, 530.0]), indexed=239.0),
#  Row(label='61750', features=DenseVector([252.0, 1845.0, 700.0]), indexed=505.0),
#  Row(label='21830', features=DenseVector([253.0, 1907.0, 680.0]), indexed=93.0),
#  Row(label='39800', features=DenseVector([254.0, 1719.0, 1060.0]), indexed=196.0),
#  Row(label='54370', features=DenseVector([255.0, 1925.0, 670.0]), indexed=29.0),
#  Row(label='62470', features=DenseVector([256.0, 1735.0, 400.0]), indexed=510.0),
#  Row(label='82930', features=DenseVector([257.0, 2003.0, 910.0]), indexed=745.0),
#  Row(label='63720', features=DenseVector([258.0, 1231.0, 760.0]), indexed=524.0),
#  Row(label='79180', features=DenseVector([259.0, 2394.0, 540.0]), indexed=714.0),
#  Row(label='38210', features=DenseVector([260.0, 1370.0, 350.0]), indexed=176.0),
#  Row(label='25950', features=DenseVector([261.0, 1426.0, 980.0]), indexed=101.0),
#  Row(label='56610', features=DenseVector([262.0, 1106.0, 860.0]), indexed=435.0),
#  Row(label='73710', features=DenseVector([263.0, 1433.0, 1020.0]), indexed=659.0),
#  Row(label='70400', features=DenseVector([264.0, 2254.0, 1120.0]), indexed=616.0),
#  Row(label='50440', features=DenseVector([265.0, 1397.0, 1020.0]), indexed=341.0),
#  Row(label='66840', features=DenseVector([266.0, 1492.0, 940.0]), indexed=568.0),
#  Row(label='50170', features=DenseVector([267.0, 1660.0, 970.0]), indexed=338.0),
#  Row(label='60140', features=DenseVector([268.0, 2030.0, 830.0]), indexed=485.0),
#  Row(label='37130', features=DenseVector([269.0, 1456.0, 920.0]), indexed=165.0),
#  Row(label='42890', features=DenseVector([270.0, 1777.0, 660.0]), indexed=233.0),
#  Row(label='26220', features=DenseVector([271.0, 1439.0, 780.0]), indexed=102.0),
#  Row(label='50840', features=DenseVector([272.0, 2220.0, 340.0]), indexed=350.0),
#  Row(label='25630', features=DenseVector([273.0, 1571.0, 1190.0]), indexed=99.0),
#  Row(label='60770', features=DenseVector([274.0, 1901.0, 490.0]), indexed=490.0),
#  Row(label='69600', features=DenseVector([275.0, 1967.0, 1090.0]), indexed=55.0),
#  Row(label='41740', features=DenseVector([276.0, 1805.0, 1040.0]), indexed=219.0),
#  Row(label='50130', features=DenseVector([277.0, 2109.0, 1210.0]), indexed=22.0),
#  Row(label='21750', features=DenseVector([278.0, 1869.0, 1030.0]), indexed=92.0),
#  Row(label='80490', features=DenseVector([279.0, 2197.0, 1170.0]), indexed=726.0),
#  Row(label='34020', features=DenseVector([280.0, 1571.0, 730.0]), indexed=133.0),
#  Row(label='60240', features=DenseVector([281.0, 1515.0, 720.0]), indexed=486.0),
#  Row(label='39460', features=DenseVector([282.0, 2073.0, 500.0]), indexed=190.0),
#  Row(label='56440', features=DenseVector([283.0, 1848.0, 1070.0]), indexed=30.0),
#  Row(label='46840', features=DenseVector([284.0, 1646.0, 800.0]), indexed=288.0),
#  Row(label='64820', features=DenseVector([285.0, 2216.0, 1020.0]), indexed=538.0),
#  Row(label='52520', features=DenseVector([286.0, 1215.0, 1070.0]), indexed=383.0),
#  Row(label='45940', features=DenseVector([287.0, 1586.0, 420.0]), indexed=273.0),
#  Row(label='38970', features=DenseVector([288.0, 1799.0, 510.0]), indexed=184.0),
#  Row(label='58610', features=DenseVector([289.0, 1674.0, 1210.0]), indexed=32.0),
#  Row(label='30810', features=DenseVector([290.0, 2364.0, 660.0]), indexed=114.0),
#  Row(label='47730', features=DenseVector([291.0, 1264.0, 360.0]), indexed=301.0),
#  Row(label='64640', features=DenseVector([292.0, 1093.0, 1210.0]), indexed=533.0),
#  Row(label='44860', features=DenseVector([293.0, 1622.0, 560.0]), indexed=258.0),
#  Row(label='55660', features=DenseVector([294.0, 1576.0, 360.0]), indexed=420.0),
#  Row(label='57530', features=DenseVector([295.0, 1803.0, 970.0]), indexed=454.0),
#  Row(label='75200', features=DenseVector([296.0, 1548.0, 480.0]), indexed=675.0),
#  Row(label='37330', features=DenseVector([297.0, 1436.0, 690.0]), indexed=167.0),
#  Row(label='35280', features=DenseVector([298.0, 1352.0, 710.0]), indexed=143.0),
#  Row(label='70610', features=DenseVector([299.0, 1768.0, 780.0]), indexed=619.0),
#  Row(label='49720', features=DenseVector([300.0, 1288.0, 630.0]), indexed=21.0),
#  Row(label='68850', features=DenseVector([301.0, 1885.0, 220.0]), indexed=594.0),
#  Row(label='50740', features=DenseVector([302.0, 1916.0, 1110.0]), indexed=346.0),
#  Row(label='77070', features=DenseVector([303.0, 1648.0, 720.0]), indexed=697.0),
#  Row(label='74730', features=DenseVector([304.0, 1892.0, 560.0]), indexed=672.0),
#  Row(label='76530', features=DenseVector([305.0, 1314.0, 600.0]), indexed=63.0),
#  Row(label='68900', features=DenseVector([306.0, 1681.0, 440.0]), indexed=59
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# 8.0),
#  Row(label='75120', features=DenseVector([592.0, 2186.0, 910.0]), indexed=674.0),
#  Row(label='41600', features=DenseVector([593.0, 1202.0, 330.0]), indexed=216.0),
#  Row(label='20270', features=DenseVector([594.0, 1946.0, 870.0]), indexed=88.0),
#  Row(label='60060', features=DenseVector([595.0, 1931.0, 790.0]), indexed=38.0),
#  Row(label='82270', features=DenseVector([596.0, 1805.0, 1270.0]), indexed=743.0),
#  Row(label='29170', features=DenseVector([597.0, 1125.0, 590.0]), indexed=110.0),
#  Row(label='68420', features=DenseVector([598.0, 1872.0, 1080.0]), indexed=589.0),
#  Row(label='59130', features=DenseVector([599.0, 2016.0, 830.0]), indexed=35.0),
#  Row(label='74330', features=DenseVector([600.0, 1947.0, 910.0]), indexed=667.0),
#  Row(label='77080', features=DenseVector([601.0, 1722.0, 830.0]), indexed=64.0),
#  Row(label='76250', features=DenseVector([602.0, 1489.0, 1380.0]), indexed=687.0),
#  Row(label='59540', features=DenseVector([603.0, 1720.0, 1180.0]), indexed=477.0),
#  Row(label='54690', features=DenseVector([604.0, 1488.0, 770.0]), indexed=412.0),
#  Row(label='84360', features=DenseVector([605.0, 1306.0, 680.0]), indexed=75.0),
#  Row(label='51420', features=DenseVector([606.0, 2065.0, 910.0]), indexed=363.0),
#  Row(label='65120', features=DenseVector([607.0, 1536.0, 540.0]), indexed=542.0),
#  Row(label='49380', features=DenseVector([608.0, 1894.0, 760.0]), indexed=324.0),
#  Row(label='37830', features=DenseVector([609.0, 1945.0, 760.0]), indexed=4.0),
#  Row(label='35980', features=DenseVector([610.0, 1608.0, 730.0]), indexed=151.0),
#  Row(label='69190', features=DenseVector([611.0, 1804.0, 430.0]), indexed=599.0),
#  Row(label='50590', features=DenseVector([612.0, 1839.0, 1000.0]), indexed=342.0),
#  Row(label='60800', features=DenseVector([613.0, 2014.0, 660.0]), indexed=491.0),
#  Row(label='31180', features=DenseVector([614.0, 1229.0, 930.0]), indexed=2.0),
#  Row(label='77790', features=DenseVector([615.0, 1751.0, 760.0]), indexed=704.0),
#  Row(label='47570', features=DenseVector([616.0, 1718.0, 370.0]), indexed=298.0),
#  Row(label='69130', features=DenseVector([617.0, 1701.0, 630.0]), indexed=54.0),
#  Row(label='75970', features=DenseVector([618.0, 1944.0, 360.0]), indexed=684.0),
#  Row(label='68350', features=DenseVector([619.0, 1791.0, 630.0]), indexed=587.0),
#  Row(label='41680', features=DenseVector([620.0, 1789.0, 670.0]), indexed=217.0),
#  Row(label='86560', features=DenseVector([621.0, 2342.0, 690.0]), indexed=765.0),
#  Row(label='81390', features=DenseVector([622.0, 1687.0, 830.0]), indexed=72.0),
#  Row(label='50730', features=DenseVector([623.0, 1635.0, 720.0]), indexed=345.0),
#  Row(label='71290', features=DenseVector([624.0, 1823.0, 520.0]), indexed=628.0),
#  Row(label='70110', features=DenseVector([625.0, 1284.0, 750.0]), indexed=612.0),
#  Row(label='61590', features=DenseVector([626.0, 1680.0, 1070.0]), indexed=501.0),
#  Row(label='69370', features=DenseVector([627.0, 1746.0, 590.0]), indexed=603.0),
#  Row(label='67110', features=DenseVector([628.0, 1888.0, 600.0]), indexed=574.0),
#  Row(label='82020', features=DenseVector([629.0, 2408.0, 380.0]), indexed=740.0),
#  Row(label='62050', features=DenseVector([630.0, 2264.0, 830.0]), indexed=43.0),
#  Row(label='61730', features=DenseVector([631.0, 1836.0, 940.0]), indexed=504.0),
#  Row(label='58660', features=DenseVector([632.0, 1722.0, 560.0]), indexed=33.0),
#  Row(label='53370', features=DenseVector([633.0, 1869.0, 1030.0]), indexed=389.0),
#  Row(label='39700', features=DenseVector([634.0, 1810.0, 730.0]), indexed=194.0),
#  Row(label='53750', features=DenseVector([635.0, 1920.0, 890.0]), indexed=394.0),
#  Row(label='44730', features=DenseVector([636.0, 2338.0, 1140.0]), indexed=257.0),
#  Row(label='49350', features=DenseVector([637.0, 1822.0, 590.0]), indexed=323.0),
#  Row(label='43340', features=DenseVector([638.0, 1911.0, 580.0]), indexed=237.0),
#  Row(label='78090', features=DenseVector([639.0, 2189.0, 310.0]), indexed=66.0),
#  Row(label='54950', features=DenseVector([640.0, 1895.0, 720.0]), indexed=414.0),
#  Row(label='75530', features=DenseVector([641.0, 1749.0, 490.0]), indexed=678.0),
#  Row(label='57330', features=DenseVector([642.0, 1331.0, 1010.0]), indexed=450.0),
#  Row(label='87930', features=DenseVector([643.0, 1841.0, 680.0]), indexed=778.0),
#  Row(label='56850', features=DenseVector([644.0, 1555.0, 1020.0]), indexed=442.0),
#  Row(label='78430', features=DenseVector([645.0, 2121.0, 1050.0]), indexed=710.0),
#  Row(label='63660', features=DenseVector([646.0, 1649.0, 740.0]), indexed=47.0),
#  Row(label='62960', features=DenseVector([647.0, 1670.0, 410.0]), indexed=517.0),
#  Row(label='81870', features=DenseVector([648.0, 1590.0, 770.0]), indexed=73.0),
#  Row(label='54820', features=DenseVector([649.0, 1794.0, 1400.0]), indexed=413.0),
#  Row(label='116320', features=DenseVector([650.0, 2414.0, 860.0]), indexed=84.0),
#  Row(label='57200', features=DenseVector([651.0, 1584.0, 840.0]), indexed=449.0),
#  Row(label='84360', features=DenseVector([652.0, 1817.0, 950.0]), indexed=75.0),
#  Row(label='36530', features=DenseVector([653.0, 2145.0, 940.0]), indexed=160.0),
#  Row(label='81260', features=DenseVector([654.0, 1933.0, 930.0]), indexed=733.0),
#  Row(label='82350', features=DenseVector([655.0, 1387.0, 1060.0]), indexed=74.0),
#  Row(label='80830', features=DenseVector([656.0, 1430.0, 560.0]), indexed=731.0),
#  Row(label='30610', features=DenseVector([657.0, 2065.0, 670.0]), indexed=112.0),
#  Row(label='51310', features=DenseVector([658.0, 1839.0, 540.0]), indexed=360.0),
#  Row(label='72940', features=DenseVector([659.0, 1623.0, 1010.0]), indexed=650.0),
#  Row(label='52450', features=DenseVector([660.0, 1366.0, 1340.0]), indexed=381.0),
#  Row(label='66070', features=DenseVector([661.0, 2020.0, 980.0]), indexed=559.0),
#  Row(label='43190', features=DenseVector([662.0, 1720.0, 630.0]), indexed=11.0),
#  Row(label='40730', features=DenseVector([663.0, 1447.0, 1110.0]), indexed=207.0),
#  Row(label='78530', features=DenseVector([664.0, 2048.0, 700.0]), indexed=712.0),
#  Row(label='94690', features=DenseVector([665.0, 2111.0, 580.0]), indexed=807.0),
#  Row(label='44400', features=DenseVector([666.0, 1299.0, 1050.0]), indexed=12.0),
#  Row(label='73800', features=DenseVector([667.0, 1692.0, 790.0]), indexed=60.0),
#  Row(label='37390', features=DenseVector([668.0, 1760.0, 600.0]), indexed=168.0),
#  Row(label='64120', features=DenseVector([669.0, 1278.0, 440.0]), indexed=531.0),
#  Row(label='66160', features=DenseVector([670.0, 1785.0, 1340.0]), indexed=560.0),
#  Row(label='22310', features=DenseVector([671.0, 1739.0, 1250.0]), indexed=94.0),
#  Row(label='62380', features=DenseVector([672.0, 2010.0, 990.0]), indexed=45.0),
#  Row(label='63850', features=DenseVector([673.0, 1958.0, 290.0]), indexed=527.0),
#  Row(label='36210', features=DenseVector([674.0, 2000.0, 350.0]), indexed=155.0),
#  Row(label='54590', features=DenseVector([675.0, 1677.0, 210.0]), indexed=0.0),
#  Row(label='69610', features=DenseVector([676.0, 2072.0, 810.0]), indexed=56.0),
#  Row(label='65390', features=DenseVector([677.0, 1472.0, 790.0]), indexed=547.0),
#  Row(label='78130', features=DenseVector([678.0, 1896.0, 780.0]), indexed=68.0),
#  Row(label='55710', features=DenseVector([679.0, 2126.0, 730.0]), indexed=421.0),
#  Row(label='69210', features=DenseVector([680.0, 1823.0, 1040.0]), indexed=600.0),
#  Row(label='59940', features=DenseVector([681.0, 1958.0, 760.0]), indexed=481.0),
#  Row(label='72550', features=DenseVector([682.0, 1750.0, 570.0]), indexed=645.0),
#  Row(label='44260', features=DenseVector([683.0, 1446.0, 620.0]), indexed=252.0),
#  Row(label='56910', features=DenseVector([684.0, 2262.0, 310.0]), indexed=445.0),
#  Row(label='82390', features=DenseVector([685.0, 1820.0, 310.0]), indexed=744.0),
#  Row(label='54590', features=DenseVector([686.0, 1332.0, 790.0]), indexed=0.0),
#  Row(label='69990', features=DenseVector([687.0, 1562.0, 490.0]), indexed=609.0),
#  Row(label='72740', features=DenseVector([688.0, 1775.0, 230.0]), indexed=648.0),
#  Row(label='35360', features=DenseVector([689.0, 1401.0, 900.0]), indexed=144.0),
#  Row(label='94370', features=DenseVector([690.0, 1276.0, 640.0]), indexed=805.0),
#  Row(label='43520', features=DenseVector([691.0, 1436.0, 840.0]), indexed=242.0),
#  Row(label='36000', features=DenseVector([692.0, 1569.0, 780.0]), indexed=152.0),
#  Row(label='99480', features=DenseVector([693.0, 1858.0, 480.0]), indexed=814.0),
#  Row(label='83220', features=DenseVector([694.0, 1883.0, 1040.0]), indexed=748.0),
#  Row(label='52940', features=DenseVector([695.0, 1529.0, 870.0]), indexed=386.0),
#  Row(label='93360', features=DenseVector([696.0, 1958.0, 530.0]), indexed=801.0),
#  Row(label='73590', features=DenseVector([697.0, 1455.0, 750.0]), indexed=656.0),
#  Row(label='53840', features=DenseVector([698.0, 1704.0, 840.0]), indexed=395.0),
#  Row(label='47350', features=DenseVector([699.0, 1956.0, 800.0]), indexed=296.0),
#  Row(label='65080', features=DenseVector([700.0, 1928.0, 660.0]), indexed=541.0),
#  Row(label='62050', features=DenseVector([701.0, 2262.0, 560.0]), indexed=43.0),
#  Row(label='30020', features=DenseVector([702.0, 1581.0, 910.0]), indexed=111.0),
#  Row(label='49510', features=DenseVector([703.0, 1729.0, 480.0]), indexed=19.0),
#  Row(label='64320', features=DenseVector([704.0, 2167.0, 700.0]), indexed=532.0),
#  Row(label='35590', features=DenseVector([705.0, 1120.0, 660.0]), indexed=147.0),
#  Row(label='63050', features=DenseVector([706.0, 1924.0, 1170.0]), indexed=518.0),
#  Row(label='65300', features=DenseVector([707.0, 1793.0, 1020.0]), indexed=544.0),
#  Row(label='69560', features=DenseVector([708.0, 2153.0, 580.0]), indexed=606.0),
#  Row(label='41910', features=DenseVector([709.0, 2032.0, 610.0]), indexed=222.0),
#  Row(label='28330', features=DenseVector([710.0, 1497.0, 590.0]), indexed=109.0),
#  Row(label='55980', features=DenseVector([711.0, 1815.0, 190.0]), indexed=424.0),
#  Row(label='61080', features=DenseVector([712.0, 1612.0, 490.0]), indexed=496.0),
#  Row(label='51380', features=DenseVector([713.0, 1844.0, 680.0]), indexed=362.0),
#  Row(label='84410', features=DenseVector([714.0, 1947.0, 670.0]), indexed=756.0),
#  Row(label='60680', features=DenseVector([715.0, 1482.0, 1070.0]), indexed=489.0),
#  Row(label='64690', features=DenseVector([716.0, 2384.0, 1110.0]), indexed=535.0),
#  Row(label='45780', features=DenseVector([717.0, 1154.0, 560.0]), indexed=270.0),
#  Row(label='41800', features=DenseVector([718.0, 1894.0, 1100.0]), indexed=220.0),
#  Row(label='53230', features=DenseVector([719.0, 1743.0, 970.0]), indexed=25.0),
#  Row(label='36160', features=DenseVector([720.0, 2160.0, 930.0]), indexed=153.0),
#  Row(label='40450', features=DenseVector([721.0, 1338.0, 1040.0]), indexed=203.0),
#  Row(label='57910', features=DenseVector([722.0, 2109.0, 1120.0]), indexed=460.0),
#  Row(label='36280', features=DenseVector([723.0, 2173.0, 910.0]), indexed=3.0),
#  Row(label='39190', features=DenseVector([724.0, 1411.0, 440.0]), indexed=187.0),
#  Row(label='62380', features=DenseVector([725.0, 1795.0, 530.0]), indexed=45.0),
#  Row(label='21470', features=DenseVector([726.0, 1734.0, 900.0]), indexed=90.0),
#  Row(label='34610', features=DenseVector([727.0, 1237.0, 740.0]), indexed=138.0),
#  Row(label='88120', features=DenseVector([728.0, 1711.0, 1020.0]), indexed=779.0),
#  Row(label='59190', features=DenseVector([729.0, 1773.0, 970.0]), indexed=36.0),
#  Row(label='36290', features=DenseVector([730.0, 2205.0, 890.0]), indexed=156.0),
#  Row(label='53760', features=DenseVector([731.0, 2086.0, 550.0]), indexed=26.0),
#  Row(label='66300', features=DenseVector([732.0, 2310.0, 520.0]), indexed=564.0),
#  Row(label='93000', features=DenseVector([733.0, 1999.0, 950.0]), indexed=800.0),
#  Row(label='65660', features=DenseVector([734.0, 1999.0, 650.0]), indexed=48.0),
#  Row(label='81930', features=DenseVector([735.0, 2061.0, 860.0]), indexed=739.0),
#  Row(label='60060', features=DenseVector([736.0, 1733.0, 320.0]), indexed=38.0),
#  Row(label='59530', features=DenseVector([737.0, 1309.0, 860.0]), indexed=476.0),
#  Row(label='46380', features=DenseVector([738.0, 1351.0, 900.0]), indexed=282.0),
#  Row(label='76200', features=DenseVector([739.0, 1858.0, 550.0]), indexed=685.0),
#  Row(label='56860', features=DenseVector([740.0, 1645.0, 770.0]), indexed=443.0),
#  Row(label='86620', features=DenseVector([741.0, 1616.0, 710.0]), indexed=766.0),
#  Row(label='49730', features=DenseVector([742.0, 1802.0, 840.0]), indexed=330.0),
#  Row(label='88370', features=DenseVector([743.0, 1858.0, 860.0]), indexed=782.0),
#  Row(label='49160', features=DenseVector([744.0, 1699.0, 870.0]), indexed=17.0),
#  Row(label='77740', features=DenseVector([745.0, 1018.0, 660.0]), indexed=703.0),
#  Row(label='38560', features=DenseVector([746.0, 1728.0, 930.0]), indexed=179.0),
#  Row(label='51990', features=DenseVector([747.0, 1776.0, 1020.0]), indexed=371.0),
#  Row(label='39970', features=DenseVector([748.0, 1819.0, 1190.0]), indexed=198.0),
#  Row(label='46040', features=DenseVector([749.0, 1638.0, 1140.0]), indexed=276.0),
#  Row(label='49500', features=DenseVector([750.0, 1683.0, 490.0]), indexed=326.0),
#  Row(label='76670', features=DenseVector([751.0, 1308.0, 1170.0]), indexed=694.0),
#  Row(label='75800', features=DenseVector([752.0, 1979.0, 480.0]), indexed=62.0),
#  Row(label='81720', features=DenseVector([753.0, 2017.0, 930.0]), indexed=736.0),
#  Row(label='58440', features=DenseVector([754.0, 1749.0, 890.0]), indexed=467.0),
#  Row(label='85720', features=DenseVector([755.0, 1591.0, 680.0]), indexed=764.0),
#  Row(label='70940', features=DenseVector([756.0, 1643.0, 740.0]), indexed=59.0),
#  Row(label='62420', features=DenseVector([757.0, 1506.0, 990.0]), indexed=509.0),
#  Row(label='56880', features=DenseVector([758.0, 1683.0, 680.0]), indexed=444.0),
#  Row(label='101820', features=DenseVector([759.0, 1758.0, 820.0]), indexed=80.0),
#  Row(label='86890', features=DenseVector([760.0, 1993.0, 440.0]), indexed=769.0),
#  Row(label='47300', features=DenseVector([761.0, 1963.0, 900.0]), indexed=294.0),
#  Row(label='31270', features=DenseVector([762.0, 1771.0, 1080.0]), indexed=116.0),
#  Row(label='65410', features=DenseVector([763.0, 1428.0, 830.0]), indexed=548.0),
#  Row(label='54200', features=DenseVector([764.0, 2264.0, 310.0]), indexed=401.0),
#  Row(label='67390', features=DenseVector([765.0, 1378.0, 730.0]), indexed=579.0),
#  Row(label='54530', features=DenseVector([766.0, 1881.0, 740.0]), indexed=408.0),
#  Row(label='79760', features=DenseVector([767.0, 1939.0, 960.0]), indexed=720.0),
#  Row(label='78060', features=DenseVector([768.0, 1345.0, 790.0]), indexed=707.0),
#  Row(label='74080', features=DenseVector([769.0, 1347.0, 700.0]), indexed=61.0),
#  Row(label='52990', features=DenseVector([770.0, 2349.0, 750.0]), indexed=387.0),
#  Row(label='70580', features=DenseVector([771.0, 1540.0, 590.0]), indexed=618.0),
#  Row(label='34310', features=DenseVector([772.0, 1689.0, 570.0]), indexed=136.0),
#  Row(label='74160', features=DenseVector([773.0, 1503.0, 660.0]), indexed=663.0),
#  Row(label='59190', features=DenseVector([774.0, 1815.0, 700.0]), indexed=36.0),
#  Row(label='43370', features=DenseVector([775.0, 1704.0, 1070.0]), indexed=238.0),
#  Row(label='17670', features=DenseVector([776.0, 1877.0, 660.0]), indexed=87.0),
#  Row(label='56710', features=DenseVector([777.0, 1742.0, 840.0]), indexed=31.0),
#  Row(label='59820', features=DenseVector([778.0, 1798.0, 850.0]), indexed=37.0),
#  Row(label='36190', features=DenseVector([779.0, 1246.0, 600.0]), indexed=154.0),
#  Row(label='60440', features=DenseVector([780.0, 1472.0, 710.0]), indexed=39.0),
#  Row(label='75300', features=DenseVector([781.0, 1783.0, 450.0]), indexed=676.0),
#  Row(label='74080', features=DenseVector([782.0, 1871.0, 740.0]), indexed=61.0),
#  Row(label='60440', features=DenseVector([783.0, 1280.0, 1240.0]), indexed=39.0),
#  Row(label='80720', features=DenseVector([784.0, 1785.0, 570.0]), indexed=728.0),
#  Row(label='47060', features=DenseVector([785.0, 2396.0, 580.0]), indexed=291.0),
#  Row(label='86830', features=DenseVector([786.0, 2368.0, 450.0]), indexed=768.0),
#  Row(label='56790', features=DenseVector([787.0, 1877.0, 790.0]), indexed=438.0),
#  Row(label='67090', features=DenseVector([788.0, 1723.0, 1040.0]), indexed=572.0),
#  Row(label='44370', features=DenseVector([789.0, 1747.0, 670.0]), indexed=254.0),
#  Row(label='82970', features=DenseVector([790.0, 1548.0, 370.0]), indexed=747.0),
#  Row(label='56230', features=DenseVector([791.0, 1876.0, 620.0]), indexed=428.0),
#  Row(label='53760', features=DenseVector([792.0, 1791.0, 1010.0]), indexed=26.0),
#  Row(label='55390', features=DenseVector([793.0, 1713.0, 550.0]), indexed=417.0),
#  Row(label='73500', features=DenseVector([794.0, 1672.0, 800.0]), indexed=655.0),
#  Row(label='41050', features=DenseVector([795.0, 1280.0, 610.0]), indexed=210.0),
#  Row(label='67320', features=DenseVector([796.0, 1747.0, 1090.0]), indexed=576.0),
#  Row(label='65890', features=DenseVector([797.0, 1610.0, 700.0]), indexed=49.0),
#  Row(label='56380', features=DenseVector([798.0, 1808.0, 830.0]), indexed=431.0),
#  Row(label='85670', features=DenseVector([799.0, 2420.0, 850.0]), indexed=77.0),
#  Row(label='70830', features=DenseVector([800.0, 1508.0, 1260.0]), indexed=622.0),
#  Row(label='48180', features=DenseVector([801.0, 1715.0, 1030.0]), indexed=308.0),
#  Row(label='51910', features=DenseVector([802.0, 2248.0, 1160.0]), indexed=369.0),
#  Row(label='44320', features=DenseVector([803.0, 1442.0, 880.0]), indexed=253.0),
#  Row(label='58940', features=DenseVector([804.0, 1650.0, 420.0]), indexed=34.0),
#  Row(label='73610', features=DenseVector([805.0, 2078.0, 770.0]), indexed=657.0),
#  Row(label='54060', features=DenseVector([806.0, 1902.0, 910.0]), indexed=28.0),
#  Row(label='85000', features=DenseVector([807.0, 2214.0, 1110.0]), indexed=759.0),
#  Row(label='49030', features=DenseVector([808.0, 1730.0, 510.0]), indexed=316.0),
#  Row(label='63300', features=DenseVector([809.0, 1800.0, 780.0]), indexed=520.0),
#  Row(label='84300', features=DenseVector([810.0, 2008.0, 790.0]), indexed=755.0),
#  Row(label='81390', features=DenseVector([811.0, 1194.0, 1090.0]), indexed=72.0),
#  Row(label='95900', features=DenseVector([812.0, 1635.0, 1270.0]), indexed=808.0),
#  Row(label='71830', features=DenseVector([813.0, 1918.0, 1260.0]), indexed=634.0),
#  Row(label='79310', features=DenseVector([814.0, 2252.0, 330.0]), indexed=718.0),
#  Row(label='87890', features=DenseVector([815.0, 1459.0, 540.0]), indexed=777.0),
#  Row(label='48610', features=DenseVector([816.0, 1746.0, 720.0]), indexed=314.0),
#  Row(label='73160', features=DenseVector([817.0, 1860.0, 670.0]), indexed=653.0),
#  Row(label='36280', features=DenseVector([818.0, 1962.0, 770.0]), indexed=3.0),
#  Row(label='49720', features=DenseVector([819.0, 2160.0, 860.0]), indexed=21.0),
#  Row(label='44400', features=DenseVector([820.0, 2038.0, 410.0]), indexed=12.0),
#  Row(label='47590', features=DenseVector([821.0, 1296.0, 900.0]), indexed=299.0),
#  Row(label='51460', features=DenseVector([822.0, 1604.0, 480.0]), indexed=364.0),
#  Row(label='57750', features=DenseVector([823.0, 1892.0, 540.0]), indexed=456.0),
#  Row(label='66000', features=DenseVector([824.0, 1733.0, 760.0]), indexed=50.0),
#  Row(label='45950', features=DenseVector([825.0, 2133.0, 280.0]), indexed=274.0),
#  Row(label='53900', features=DenseVector([826.0, 1630.0, 1120.0]), indexed=398.0),
#  Row(label='37920', features=DenseVector([827.0, 1928.0, 160.0]), indexed=171.0),
#  Row(label='63100', features=DenseVector([828.0, 2024.0, 620.0]), indexed=519.0),
#  Row(label='36770', features=DenseVector([829.0, 1636.0, 440.0]), indexed=164.0),
#  Row(label='43910', features=DenseVector([830.0, 1452.0, 870.0]), indexed=248.0),
#  Row(label='66390', features=DenseVector([831.0, 2101.0, 900.0]), indexed=52.0),
#  Row(label='59160', features=DenseVector([832.0, 1179.0, 710.0]), indexed=473.0),
#  Row(label='38510', features=DenseVector([833.0, 1606.0, 590.0]), indexed=178.0),
#  Row(label='46220', features=DenseVector([834.0, 1725.0, 910.0]), indexed=279.0),
#  Row(label='41500', features=DenseVector([835.0, 1609.0, 1320.0]), indexed=213.0),
#  Row(label='58160', features=DenseVector([836.0, 2009.0, 1000.0]), indexed=463.0),
#  Row(label='38530', features=DenseVector([837.0, 1462.0, 670.0]), indexed=5.0),
#  Row(label='55880', features=DenseVector([838.0, 2277.0, 610.0]), indexed=423.0),
#  Row(label='70940', features=DenseVector([839.0, 1937.0, 1050.0]), indexed=59.0),
#  Row(label='53940', features=DenseVector([840.0, 1413.0, 480.0]), indexed=27.0),
#  Row(label='43030', features=DenseVector([841.0, 1606.0, 770.0]), indexed=235.0),
#  Row(label='59820', features=DenseVector([842.0, 1843.0, 340.0]), indexed=37.0),
#  Row(label='55500', features=DenseVector([843.0, 1557.0, 580.0]), indexed=418.0),
#  Row(label='49990', features=DenseVector([844.0, 1751.0, 900.0]), indexed=335.0),
#  Row(label='42980', features=DenseVector([845.0, 1727.0, 700.0]), indexed=234.0),
#  Row(label='65970', features=DenseVector([846.0, 1743.0, 860.0]), indexed=556.0),
#  Row(label='59290', features=DenseVector([847.0, 1819.0, 540.0]), indexed=474.0),
#  Row(label='63020', features=DenseVector([848.0, 1745.0, 970.0]), indexed=46.0),
#  Row(label='73810', features=DenseVector([849.0, 1099.0, 1560.0]), indexed=660.0),
#  Row(label='70230', features=DenseVector([850.0, 2492.0, 790.0]), indexed=613.0),
#  Row(label='59950', features=DenseVector([851.0, 2362.0, 1020.0]), indexed=482.0),
#  Row(label='78100', features=DenseVector([852.0, 1558.0, 790.0]), indexed=67.0),
#  Row(label='16370', features=DenseVector([853.0, 1790.0, 880.0]), indexed=86.0),
#  Row(label='92640', features=DenseVector([854.0, 1906.0, 550.0]), indexed=799.0),
#  Row(label='63540', features=DenseVector([855.0, 1789.0, 550.0]), indexed=1.0),
#  Row(label='87220', features=DenseVector([856.0, 1455.0, 950.0]), indexed=773.0),
#  Row(label='41990', features=DenseVector([857.0, 1460.0, 810.0]), indexed=223.0),
#  Row(label='79410', features=DenseVector([858.0, 1982.0, 390.0]), indexed=70.0),
#  Row(label='54380', features=DenseVector([859.0, 1393.0, 860.0]), indexed=405.0),
#  Row(label='58600', features=DenseVector([860.0, 1757.0, 850.0]), indexed=469.0),
#  Row(label='48950', features=DenseVector([861.0, 1510.0, 660.0]), indexed=16.0),
#  Row(label='40670', features=DenseVector([862.0, 2333.0, 830.0]), indexed=205.0),
#  Row(label='52340', features=DenseVector([863.0, 1919.0, 640.0]), indexed=379.0),
#  Row(label='39140', features=DenseVector([864.0, 1397.0, 750.0]), indexed=186.0),
#  Row(label='41090', features=DenseVector([865.0, 2195.0, 1170.0]), indexed=211.0),
#  Row(label='25600', features=DenseVector([866.0, 951.0, 790.0]), indexed=98.0),
#  Row(label='100900', features=DenseVector([867.0, 1854.0, 900.0]), indexed=78.0),
#  Row(label='77080', features=DenseVector([868.0, 1959.0, 370.0]), indexed=64.0),
#  Row(label='105150', features=DenseVector([869.0, 2104.0, 980.0]), indexed=83.0),
#  Row(label='80580', features=DenseVector([870.0, 1732.0, 1170.0]), indexed=727.0),
#  Row(label='46230', features=DenseVector([871.0, 1776.0, 800.0]), indexed=280.0),
#  Row(label='98260', features=DenseVector([872.0, 2158.0, 1100.0]), indexed=813.0),
#  Row(label='75930', features=DenseVector([873.0, 2024.0, 1070.0]), indexed=682.0),
#  Row(label='52050', features=DenseVector([874.0, 1452.0, 830.0]), indexed=372.0),
#  Row(label='87000', features=DenseVector([875.0, 2222.0, 1210.0]), indexed=770.0),
#  Row(label='60270', features=DenseVector([876.0, 2023.0, 540.0]), indexed=487.0),
#  Row(label='88270', features=DenseVector([877.0, 1493.0, 100.0]), indexed=781.0),
#  Row(label='57820', features=DenseVector([878.0, 2138.0, 820.0]), indexed=457.0),
#  Row(label='61210', features=DenseVector([879.0, 1468.0, 1210.0]), indexed=499.0),
#  Row(label='76420', features=DenseVector([880.0, 2131.0, 810.0]), indexed=690.0),
#  Row(label='70980', features=DenseVector([881.0, 1516.0, 780.0]), indexed=624.0),
#  Row(label='76740', features=DenseVector([882.0, 1605.0, 1160.0]), indexed=696.0),
#  Row(label='47920', features=DenseVector([883.0, 2187.0, 590.0]), indexed=303.0),
#  Row(label='52160', features=DenseVector([884.0, 1625.0, 1140.0]), indexed=376.0),
#  Row(label='32740', features=DenseVector([885.0, 1673.0, 690.0]), indexed=122.0),
#  Row(label='72270', features=DenseVector([886.0, 1337.0, 560.0]), indexed=640.0),
#  Row(label='77430', features=DenseVector([887.0, 1986.0, 1150.0]), indexed=701.0),
#  Row(label='92370', features=DenseVector([888.0, 1398.0, 140.0]), indexed=798.0),
#  Row(label='34880', features=DenseVector([889.0, 1734.0, 670.0]), indexed=139.0),
#  Row(label='46580', features=DenseVector([890.0, 1829.0, 650.0]), indexed=15.0),
#  Row(label='70620', features=DenseVector([891.0, 1851.0, 1220.0]), indexed=620.0),
#  Row(label='66390', features=DenseVector([892.0, 1910.0, 1080.0]), indexed=52.0),
#  Row(label='82080', features=DenseVector([893.0, 1663.0, 850.0]), indexed=742.0),
#  Row(label='76440', features=DenseVector([894.0, 1436.0, 1060.0]), indexed=691.0),
#  Row(label='96610', features=DenseVector([895.0, 1560.0, 770.0]), indexed=809.0),
#  Row(label='54340', features=DenseVector([896.0, 1429.0, 1110.0]), indexed=403.0)]

# %%
#Split into training and testing data
(trainingData, testData) = td.randomSplit([0.9, 0.1])
trainingData.collect()
#testData.count()
#testData.collect()
# Out:
# Out[18]: [Row(label='102310', features=DenseVector([409.0, 1587.0, 1310.0]), indexed=81.0),
#  Row(label='102920', features=DenseVector([433.0, 1638.0, 680.0]), indexed=82.0),
#  Row(label='14920', features=DenseVector([32.0, 1508.0, 990.0]), indexed=85.0),
#  Row(label='21300', features=DenseVector([353.0, 1686.0, 850.0]), indexed=89.0),
#  Row(label='21650', features=DenseVector([373.0, 2254.0, 1340.0]), indexed=91.0),
#  Row(label='21750', features=DenseVector([278.0, 1869.0, 1030.0]), indexed=92.0),
#  Row(label='21830', features=DenseVector([253.0, 1907.0, 680.0]), indexed=93.0),
#  Row(label='24410', features=DenseVector([224.0, 1606.0, 1200.0]), indexed=97.0),
#  Row(label='25630', features=DenseVector([273.0, 1571.0, 1190.0]), indexed=99.0),
#  Row(label='25820', features=DenseVector([27.0, 1777.0, 1100.0]), indexed=100.0),
#  Row(label='25950', features=DenseVector([261.0, 1426.0, 980.0]), indexed=101.0),
#  Row(label='26220', features=DenseVector([271.0, 1439.0, 780.0]), indexed=102.0),
#  Row(label='26770', features=DenseVector([77.0, 1520.0, 450.0]), indexed=103.0),
#  Row(label='27310', features=DenseVector([359.0, 1216.0, 460.0]), indexed=104.0),
#  Row(label='27410', features=DenseVector([154.0, 1963.0, 490.0]), indexed=105.0),
#  Row(label='27720', features=DenseVector([396.0, 1829.0, 380.0]), indexed=106.0),
#  Row(label='30810', features=DenseVector([290.0, 2364.0, 660.0]), indexed=114.0),
#  Row(label='31180', features=DenseVector([118.0, 2046.0, 460.0]), indexed=2.0),
#  Row(label='31890', features=DenseVector([318.0, 1484.0, 560.0]), indexed=117.0),
#  Row(label='31940', features=DenseVector([374.0, 2306.0, 820.0]), indexed=118.0),
#  Row(label='32260', features=DenseVector([397.0, 2044.0, 1140.0]), indexed=119.0),
#  Row(label='32330', features=DenseVector([186.0, 1717.0, 230.0]), indexed=120.0),
#  Row(label='32770', features=DenseVector([122.0, 1835.0, 900.0]), indexed=123.0),
#  Row(label='33010', features=DenseVector([446.0, 1869.0, 1000.0]), indexed=124.0),
#  Row(label='33240', features=DenseVector([428.0, 2042.0, 430.0]), indexed=126.0),
#  Row(label='33430', features=DenseVector([69.0, 1941.0, 650.0]), indexed=127.0),
#  Row(label='33460', features=DenseVector([174.0, 2145.0, 490.0]), indexed=128.0),
#  Row(label='33580', features=DenseVector([72.0, 1380.0, 530.0]), indexed=129.0),
#  Row(label='33730', features=DenseVector([216.0, 1909.0, 370.0]), indexed=130.0),
#  Row(label='33740', features=DenseVector([222.0, 1922.0, 550.0]), indexed=131.0),
#  Row(label='33890', features=DenseVector([389.0, 1589.0, 1050.0]), indexed=132.0),
#  Row(label='34020', features=DenseVector([280.0, 1571.0, 730.0]), indexed=133.0),
#  Row(label='34180', features=DenseVector([204.0, 1192.0, 900.0]), indexed=134.0),
#  Row(label='34190', features=DenseVector([361.0, 2095.0, 980.0]), indexed=135.0),
#  Row(label='34410', features=DenseVector([158.0, 1696.0, 350.0]), indexed=137.0),
#  Row(label='35230', features=DenseVector([326.0, 1810.0, 950.0]), indexed=142.0),
#  Row(label='35280', features=DenseVector([298.0, 1352.0, 710.0]), indexed=143.0),
#  Row(label='35510', features=DenseVector([125.0, 1390.0, 370.0]), indexed=146.0),
#  Row(label='35600', features=DenseVector([362.0, 1468.0, 850.0]), indexed=148.0),
#  Row(label='35800', features=DenseVector([45.0, 1194.0, 520.0]), indexed=150.0),
#  Row(label='36330', features=DenseVector([110.0, 1700.0, 920.0]), indexed=157.0),
#  Row(label='36690', features=DenseVector([366.0, 1837.0, 1130.0]), indexed=162.0),
#  Row(label='36740', features=DenseVector([395.0, 1464.0, 600.0]), indexed=163.0),
#  Row(label='37130', features=DenseVector([269.0, 1456.0, 920.0]), indexed=165.0),
#  Row(label='37320', features=DenseVector([155.0, 1663.0, 670.0]), indexed=166.0),
#  Row(label='37330', features=DenseVector([297.0, 1436.0, 690.0]), indexed=167.0),
#  Row(label='37720', features=DenseVector([8.0, 1507.0, 1020.0]), indexed=169.0),
#  Row(label='37810', features=DenseVector([165.0, 2176.0, 700.0]), indexed=170.0),
#  Row(label='37830', features=DenseVector([209.0, 2055.0, 1080.0]), indexed=4.0),
#  Row(label='38070', features=DenseVector([149.0, 1480.0, 830.0]), indexed=173.0),
#  Row(label='38120', features=DenseVector([206.0, 2149.0, 910.0]), indexed=174.0),
#  Row(label='38170', features=DenseVector([18.0, 2045.0, 670.0]), indexed=175.0),
#  Row(label='38210', features=DenseVector([260.0, 1370.0, 350.0]), indexed=176.0),
#  Row(label='38600', features=DenseVector([391.0, 1799.0, 960.0]), indexed=6.0),
#  Row(label='38650', features=DenseVector([168.0, 1606.0, 630.0]), indexed=181.0),
#  Row(label='38660', features=DenseVector([79.0, 2044.0, 960.0]), indexed=182.0),
#  Row(label='38970', features=DenseVector([288.0, 1799.0, 510.0]), indexed=184.0),
#  Row(label='39200', features=DenseVector([378.0, 1699.0, 680.0]), indexed=188.0),
#  Row(label='39420', features=DenseVector([387.0, 1697.0, 1200.0]), indexed=189.0),
#  Row(label='39460', features=DenseVector([282.0, 2073.0, 500.0]), indexed=190.0),
#  Row(label='39650', features=DenseVector([88.0, 1506.0, 850.0]), indexed=193.0),
#  Row(label='39730', features=DenseVector([44.0, 2117.0, 780.0]), indexed=7.0),
#  Row(label='39730', features=DenseVector([190.0, 2000.0, 480.0]), indexed=7.0),
#  Row(label='39740', features=DenseVector([151.0, 1629.0, 770.0]), indexed=195.0),
#  Row(label='39800', features=DenseVector([254.0, 1719.0, 1060.0]), indexed=196.0),
#  Row(label='39820', features=DenseVector([2.0, 1752.0, 210.0]), indexed=197.0),
#  Row(label='40000', features=DenseVector([439.0, 1561.0, 1070.0]), indexed=199.0),
#  Row(label='40190', features=DenseVector([20.0, 2340.0, 980.0]), indexed=200.0),
#  Row(label='40350', features=DenseVector([350.0, 2228.0, 1530.0]), indexed=202.0),
#  Row(label='40490', features=DenseVector([134.0, 2071.0, 900.0]), indexed=204.0),
#  Row(label='40930', features=DenseVector([182.0, 1396.0, 1100.0]), indexed=209.0),
#  Row(label='41080', features=DenseVector([187.0, 1796.0, 1060.0]), indexed=8.0),
#  Row(label='41080', features=DenseVector([329.0, 1954.0, 760.0]), indexed=8.0),
#  Row(label='41190', features=DenseVector([100.0, 1899.0, 1140.0]), indexed=212.0),
#  Row(label='41490', features=DenseVector([308.0, 1654.0, 410.0]), indexed=9.0),
#  Row(label='41490', features=DenseVector([321.0, 1459.0, 930.0]), indexed=9.0),
#  Row(label='41570', features=DenseVector([37.0, 1744.0, 610.0]), indexed=215.0),
#  Row(label='41710', features=DenseVector([444.0, 1570.0, 1080.0]), indexed=218.0),
#  Row(label='41740', features=DenseVector([276.0, 1805.0, 1040.0]), indexed=219.0),
#  Row(label='41880', features=DenseVector([25.0, 1488.0, 840.0]), indexed=221.0),
#  Row(label='42060', features=DenseVector([90.0, 1758.0, 420.0]), indexed=224.0),
#  Row(label='42430', features=DenseVector([70.0, 1576.0, 710.0]), indexed=226.0),
#  Row(label='42530', features=DenseVector([159.0, 932.0, 1090.0]), indexed=227.0),
#  Row(label='42620', features=DenseVector([176.0, 1619.0, 700.0]), indexed=228.0),
#  Row(label='42670', features=DenseVector([84.0, 1884.0, 1410.0]), indexed=229.0),
#  Row(label='42840', features=DenseVector([136.0, 1993.0, 740.0]), indexed=231.0),
#  Row(label='42860', features=DenseVector([188.0, 1985.0, 1180.0]), indexed=10.0),
#  Row(label='43390', features=DenseVector([251.0, 1648.0, 530.0]), indexed=239.0),
#  Row(label='43720', features=DenseVector([337.0, 1583.0, 540.0]), indexed=245.0),
#  Row(label='43860', features=DenseVector([419.0, 1530.0, 1240.0]), indexed=247.0),
#  Row(label='44090', features=DenseVector([175.0, 1832.0, 580.0]), indexed=249.0),
#  Row(label='44150', features=DenseVector([10.0, 1235.0, 1130.0]), indexed=250.0),
#  Row(label='44660', features=DenseVector([335.0, 1973.0, 1440.0]), indexed=255.0),
#  Row(label='44860', features=DenseVector([293.0, 1622.0, 560.0]), indexed=258.0),
#  Row(label='44910', features=DenseVector([171.0, 1599.0, 870.0]), indexed=260.0),
#  Row(label='44960', features=DenseVector([307.0, 1813.0, 520.0]), indexed=261.0),
#  Row(label='45020', features=DenseVector([162.0, 1657.0, 580.0]), indexed=262.0),
#  Row(label='45260', features=DenseVector([6.0, 1733.0, 760.0]), indexed=264.0),
#  Row(label='45460', features=DenseVector([36.0, 2230.0, 700.0]), indexed=265.0),
#  Row(label='45480', features=DenseVector([40.0, 1516.0, 10.0]), indexed=266.0),
#  Row(label='45580', features=DenseVector([334.0, 1957.0, 1280.0]), indexed=267.0),
#  Row(label='45650', features=DenseVector([233.0, 1499.0, 570.0]), indexed=268.0),
#  Row(label='45720', features=DenseVector([89.0, 1468.0, 960.0]), indexed=269.0),
#  Row(label='45820', features=DenseVector([346.0, 2378.0, 810.0]), indexed=271.0),
#  Row(label='45940', features=DenseVector([287.0, 1586.0, 420.0]), indexed=273.0),
#  Row(label='46030', features=DenseVector([406.0, 1893.0, 1180.0]), indexed=275.0),
#  Row(label='46050', features=DenseVector([250.0, 1976.0, 620.0]), indexed=14.0),
#  Row(label='46100', features=DenseVector([62.0, 2391.0, 530.0]), indexed=277.0),
#  Row(label='46140', features=DenseVector([166.0, 1133.0, 580.0]), indexed=278.0),
#  Row(label='46310', features=DenseVector([9.0, 1321.0, 680.0]), indexed=281.0),
#  Row(label='46580', features=DenseVector([123.0, 1669.0, 530.0]), indexed=15.0),
#  Row(label='46620', features=DenseVector([5.0, 2111.0, 450.0]), indexed=283.0),
#  Row(label='46650', features=DenseVector([342.0, 1999.0, 740.0]), indexed=284.0),
#  Row(label='46700', features=DenseVector([338.0, 1750.0, 480.0]), indexed=285.0),
#  Row(label='46830', features=DenseVector([115.0, 2287.0, 1210.0]), indexed=287.0),
#  Row(label='46840', features=DenseVector([284.0, 1646.0, 800.0]), indexed=288.0),
#  Row(label='47230', features=DenseVector([237.0, 1434.0, 670.0]), indexed=293.0),
#  Row(label='47310', features=DenseVector([352.0, 1897.0, 1210.0]), indexed=295.0),
#  Row(label='47460', features=DenseVector([173.0, 1207.0, 670.0]), indexed=297.0),
#  Row(label='47620', features=DenseVector([431.0, 1943.0, 460.0]), indexed=300.0),
#  Row(label='47730', features=DenseVector([291.0, 1264.0, 360.0]), indexed=301.0),
#  Row(label='48030', features=DenseVector([369.0, 1678.0, 920.0]), indexed=304.0),
#  Row(label='48090', features=DenseVector([358.0, 1822.0, 670.0]), indexed=305.0),
#  Row(label='48300', features=DenseVector([179.0, 2032.0, 590.0]), indexed=309.0),
#  Row(label='48550', features=DenseVector([327.0, 1736.0, 870.0]), indexed=311.0),
#  Row(label='48560', features=DenseVector([144.0, 1805.0, 540.0]), indexed=312.0),
#  Row(label='48590', features=DenseVector([141.0, 2374.0, 800.0]), indexed=313.0),
#  Row(label='48670', features=DenseVector([56.0, 1701.0, 740.0]), indexed=315.0),
#  Row(label='48950', features=DenseVector([143.0, 1456.0, 530.0]), indexed=16.0),
#  Row(label='49070', features=DenseVector([207.0, 1853.0, 660.0]), indexed=317.0),
#  Row(label='49080', features=DenseVector([67.0, 2262.0, 570.0]), indexed=318.0),
#  Row(label='49100', features=DenseVector([63.0, 1748.0, 600.0]), indexed=319.0),
#  Row(label='49160', features=DenseVector([232.0, 1661.0, 1410.0]), indexed=17.0),
#  Row(label='49170', features=DenseVector([150.0, 2300.0, 1060.0]), indexed=18.0),
#  Row(label='49210', features=DenseVector([128.0, 2051.0, 750.0]), indexed=320.0),
#  Row(label='49270', features=DenseVector([46.0, 1471.0, 870.0]), indexed=321.0),
#  Row(label='49550', features=DenseVector([41.0, 1725.0, 1250.0]), indexed=328.0),
#  Row(label='49570', features=DenseVector([333.0, 1473.0, 630.0]), indexed=329.0),
#  Row(label='49590', features=DenseVector([448.0, 2123.0, 860.0]), indexed=20.0),
#  Row(label='49720', features=DenseVector([300.0, 1288.0, 630.0]), indexed=21.0),
#  Row(label='49760', features=DenseVector([200.0, 1371.0, 940.0]), indexed=332.0),
#  Row(label='49800', features=DenseVector([169.0, 1487.0, 860.0]), indexed=333.0),
#  Row(label='49980', features=DenseVector([348.0, 2138.0, 580.0]), indexed=334.0),
#  Row(label='50070', features=DenseVector([133.0, 1672.0, 1170.0]), indexed=337.0),
#  Row(label='50130', features=DenseVector([277.0, 2109.0, 1210.0]), indexed=22.0),
#  Row(label='50130', features=DenseVector([345.0, 2390.0, 930.0]), indexed=22.0),
#  Row(label='50170', features=DenseVector([267.0, 1660.0, 970.0]), indexed=338.0),
#  Row(label='50360', features=DenseVector([148.0, 1486.0, 730.0]), indexed=340.0),
#  Row(label='50440', features=DenseVector([265.0, 1397.0, 1020.0]), indexed=341.0),
#  Row(label='50680', features=DenseVector([24.0, 1752.0, 620.0]), indexed=343.0),
#  Row(label='50720', features=DenseVector([382.0, 1467.0, 910.0]), indexed=344.0),
#  Row(label='50740', features=DenseVector([302.0, 1916.0, 1110.0]), indexed=346.0),
#  Row(label='50780', features=DenseVector([161.0, 2078.0, 680.0]), indexed=347.0),
#  Row(label='50810', features=DenseVector([96.0, 2385.0, 500.0]), indexed=348.0),
#  Row(label='50840', features=DenseVector([272.0, 2220.0, 340.0]), indexed=350.0),
#  Row(label='50950', features=DenseVector([105.0, 1587.0, 1000.0]), indexed=353.0),
#  Row(label='51130', features=DenseVector([388.0, 1801.0, 890.0]), indexed=355.0),
#  Row(label='51270', features=DenseVector([330.0, 1948.0, 960.0]), indexed=358.0),
#  Row(label='51280', features=DenseVector([86.0, 1760.0, 280.0]), indexed=359.0),
#  Row(label='51480', features=DenseVector([399.0, 2493.0, 810.0]), indexed=23.0),
#  Row(label='51700', features=DenseVector([111.0, 1382.0, 1260.0]), indexed=366.0),
#  Row(label='51850', features=DenseVector([135.0, 1638.0, 980.0]), indexed=368.0),
#  Row(label='51950', features=DenseVector([239.0, 2247.0, 480.0]), indexed=370.0),
#  Row(label='52060', features=DenseVector([436.0, 1836.0, 990.0]), indexed=373.0),
#  Row(label='52090', features=DenseVector([418.0, 1724.0, 920.0]), indexed=374.0),
#  Row(label='52270', features=DenseVector([210.0, 1872.0, 690.0]), indexed=377.0),
#  Row(label='52280', features=DenseVector([211.0, 1572.0, 510.0]), indexed=378.0),
#  Row(label='52460', features=DenseVector([195.0, 1982.0, 690.0]), indexed=382.0),
#  Row(label='52520', features=DenseVector([286.0, 1215.0, 1070.0]), indexed=383.0),
#  Row(label='52780', features=DenseVector([23.0, 2065.0, 950.0]), indexed=24.0),
#  Row(label='52780', features=DenseVector([234.0, 1649.0, 940.0]), indexed=24.0),
#  Row(label='53270', features=DenseVector([398.0, 1381.0, 730.0]), indexed=388.0),
#  Row(label='53400', features=DenseVector([410.0, 1605.0, 1000.0]), indexed=390.0),
#  Row(label='53500', features=DenseVector([425.0, 1523.0, 1350.0]), indexed=391.0),
#  Row(label='53730', features=DenseVector([4.0, 1748.0, 620.0]), indexed=393.0),
#  Row(label='53870', features=DenseVector([60.0, 2070.0, 460.0]), indexed=396.0),
#  Row(label='54030', features=DenseVector([93.0, 2205.0, 400.0]), indexed=400.0),
#  Row(label='54300', features=DenseVector([160.0, 1534.0, 1230.0]), indexed=402.0),
#  Row(label='54360', features=DenseVector([356.0, 1511.0, 500.0]), indexed=404.0),
#  Row(label='54590', features=DenseVector([426.0, 2133.0, 1000.0]), indexed=0.0),
#  Row(label='54670', features=DenseVector([363.0, 1877.0, 580.0]), indexed=411.0),
#  Row(label='55170', features=DenseVector([39.0, 2204.0, 1010.0]), indexed=416.0),
#  Row(label='55530', features=DenseVector([372.0, 1305.0, 1190.0]), indexed=419.0),
#  Row(label='55660', features=DenseVector([294.0, 1576.0, 360.0]), indexed=420.0),
#  Row(label='55820', features=DenseVector([218.0, 1829.0, 840.0]), indexed=422.0),
#  Row(label='56010', features=DenseVector([113.0, 2248.0, 1330.0]), indexed=426.0),
#  Row(label='56170', features=DenseVector([249.0, 2097.0, 730.0]), indexed=427.0),
#  Row(label='56360', features=DenseVector([94.0, 1655.0, 760.0]), indexed=430.0),
#  Row(label='56400', features=DenseVector([311.0, 1889.0, 610.0]), indexed=432.0),
#  Row(label='56440', features=DenseVector([283.0, 1848.0, 1070.0]), indexed=30.0),
#  Row(label='56450', features=DenseVector([404.0, 1896.0, 750.0]), indexed=433.0),
#  Row(label='56610', features=DenseVector([262.0, 1106.0, 860.0]), indexed=435.0),
#  Row(label='56650', features=DenseVector([71.0, 2019.0, 850.0]), indexed=436.0),
#  Row(label='56710', features=DenseVector([119.0, 1798.0, 860.0]), indexed=31.0),
#  Row(label='56810', features=DenseVector([328.0, 2157.0, 730.0]), indexed=439.0),
#  Row(label='57140', features=DenseVector([443.0, 1766.0, 1290.0]), indexed=447.0),
#  Row(label='57160', features=DenseVector([360.0, 1799.0, 950.0]), indexed=448.0),
#  Row(label='57450', features=DenseVector([427.0, 1375.0, 1220.0]), indexed=451.0),
#  Row(label='57480', features=DenseVector([131.0, 1595.0, 910.0]), indexed=452.0),
#  Row(label='57500', features=DenseVector([331.0, 1273.0, 860.0]), indexed=453.0),
#  Row(label='57530', features=DenseVector([295.0, 1803.0, 970.0]), indexed=454.0),
#  Row(label='57620', features=DenseVector([12.0, 2098.0, 720.0]), indexed=455.0),
#  Row(label='57830', features=DenseVector([52.0, 1880.0, 1300.0]), indexed=458.0),
#  Row(label='57860', features=DenseVector([83.0, 1723.0, 330.0]), indexed=459.0),
#  Row(label='58090', features=DenseVector([180.0, 1941.0, 1350.0]), indexed=462.0),
#  Row(label='58260', features=DenseVector([205.0, 1857.0, 1020.0]), indexed=464.0),
#  Row(label='58380', features=DenseVector([421.0, 1404.0, 430.0]), indexed=465.0),
#  Row(label='58540', features=DenseVector([246.0, 2003.0, 1070.0]), indexed=468.0),
#  Row(label='58610', features=DenseVector([289.0, 1674.0, 1210.0]), indexed=32.0),
#  Row(label='58610', features=DenseVector([415.0, 1670.0, 950.0]), indexed=32.0),
#  Row(label='58660', features=DenseVector([65.0, 1821.0, 590.0]), indexed=33.0),
#  Row(label='58670', features=DenseVector([315.0, 2131.0, 340.0]), indexed=470.0),
#  Row(label='58920', features=DenseVector([147.0, 1750.0, 130.0]), indexed=471.0),
#  Row(label='59380', features=DenseVector([145.0, 1770.0, 620.0]), indexed=475.0),
#  Row(label='59760', features=DenseVector([411.0, 1704.0, 1130.0]), indexed=478.0),
#  Row(label='59800', features=DenseVector([368.0, 1774.0, 940.0]), indexed=479.0),
#  Row(label='59970', features=DenseVector([400.0, 2254.0, 1000.0]), indexed=483.0),
#  Row(label='59980', features=DenseVector([49.0, 1776.0, 1260.0]), indexed=484.0),
#  Row(label='60140', features=DenseVector([268.0, 2030.0, 830.0]), indexed=485.0),
#  Row(label='60240', features=DenseVector([281.0, 1515.0, 720.0]), indexed=486.0),
#  Row(label='60460', features=DenseVector([33.0, 1608.0, 880.0]), indexed=488.0),
#  Row(label='60470', features=DenseVector([13.0, 2064.0, 1050.0]), indexed=40.0),
#  Row(label='60530', features=DenseVector([28.0, 1648.0, 980.0]), indexed=41.0),
#  Row(label='60530', features=DenseVector([380.0, 2026.0, 700.0]), indexed=41.0),
#  Row(label='60770', features=DenseVector([274.0, 1901.0, 490.0]), indexed=490.0),
#  Row(label='60960', features=DenseVector([97.0, 2235.0, 1120.0]), indexed=493.0),
#  Row(label='61040', features=DenseVector([435.0, 1635.0, 840.0]), indexed=495.0),
#  Row(label='61150', features=DenseVector([127.0, 2241.0, 500.0]), indexed=497.0),
#  Row(label='61180', features=DenseVector([98.0, 2171.0, 1160.0]), indexed=498.0),
#  Row(label='61460', features=DenseVector([355.0, 1707.0, 1160.0]), indexed=500.0),
#  Row(label='61660', features=DenseVector([208.0, 1677.0, 480.0]), indexed=502.0),
#  Row(label='61670', features=DenseVector([319.0, 1586.0, 630.0]), indexed=503.0),
#  Row(label='61750', features=DenseVector([252.0, 1845.0, 700.0]), indexed=505.0),
#  Row(label='61970', features=DenseVector([434.0, 1503.0, 950.0]), indexed=506.0),
#  Row(label='62180', features=DenseVector([354.0, 1709.0, 1340.0]), indexed=44.0),
#  Row(label='62270', features=DenseVector([199.0, 1808.0, 460.0]), indexed=507.0),
#  Row(label='62280', features=DenseVector([138.0, 1905.0, 810.0]), indexed=508.0),
#  Row(label='62470', features=DenseVector([256.0, 1735.0, 400.0]), indexed=510.0),
#  Row(label='62530', features=DenseVector([48.0, 1982.0, 910.0]), indexed=511.0),
#  Row(label='62710', features=DenseVector([324.0, 2147.0, 430.0]), indexed=512.0),
#  Row(label='62800', features=DenseVector([221.0, 1742.0, 310.0]), indexed=514.0),
#  Row(label='62870', features=DenseVector([38.0, 1411.0, 1080.0]), indexed=515.0),
#  Row(label='62950', features=DenseVector([112.0, 1787.0, 800.0]), indexed=516.0),
#  Row(label='63540', features=DenseVector([19.0, 1731.0, 1030.0]), indexed=1.0),
#  Row(label='63540', features=DenseVector([365.0, 1369.0, 650.0]), indexed=1.0),
#  Row(label='63660', features=DenseVector([99.0, 2147.0, 820.0]), indexed=47.0),
#  Row(label='63720', features=DenseVector([258.0, 1231.0, 760.0]), indexed=524.0),
#  Row(label='63730', features=DenseVector([152.0, 1986.0, 70.0]), indexed=525.0),
#  Row(label='63830', features=DenseVector([223.0, 1527.0, 380.0]), indexed=526.0),
#  Row(label='64090', features=DenseVector([55.0, 1898.0, 980.0]), indexed=530.0),
#  Row(label='64640', features=DenseVector([292.0, 1093.0, 1210.0]), indexed=533.0),
#  Row(label='64670', features=DenseVector([184.0, 2053.0, 950.0]), indexed=534.0),
#  Row(label='64820', features=DenseVector([285.0, 2216.0, 1020.0]), indexed=538.0),
#  Row(label='64950', features=DenseVector([236.0, 2110.0, 1200.0]), indexed=539.0),
#  Row(label='65180', features=DenseVector([106.0, 1434.0, 690.0]), indexed=543.0),
#  Row(label='65310', features=DenseVector([417.0, 1733.0, 1120.0]), indexed=545.0),
#  Row(label='65350', features=DenseVector([91.0, 1912.0, 830.0]), indexed=546.0),
#  Row(label='65500', features=DenseVector([371.0, 1322.0, 610.0]), indexed=549.0),
#  Row(label='65560', features=DenseVector([78.0, 1475.0, 1390.0]), indexed=550.0),
#  Row(label='65660', features=DenseVector([80.0, 1761.0, 600.0]), indexed=48.0),
#  Row(label='65890', features=DenseVector([244.0, 2397.0, 610.0]), indexed=49.0),
#  Row(label='65920', features=DenseVector([64.0, 1561.0, 860.0]), indexed=555.0),
#  Row(label='66020', features=DenseVector([438.0, 1820.0, 520.0]), indexed=557.0),
#  Row(label='66170', features=DenseVector([322.0, 1429.0, 470.0]), indexed=561.0),
#  Row(label='66210', features=DenseVector([57.0, 2060.0, 1240.0]), indexed=562.0),
#  Row(label='66270', features=DenseVector([217.0, 1899.0, 840.0]), indexed=563.0),
#  Row(label='66360', features=DenseVector([15.0, 1756.0, 770.0]), indexed=565.0),
#  Row(label='66490', features=DenseVector([1.0, 1961.0, 530.0]), indexed=566.0),
#  Row(label='66510', features=DenseVector([47.0, 2087.0, 690.0]), indexed=567.0),
#  Row(label='66840', features=DenseVector([266.0, 1492.0, 940.0]), indexed=568.0),
#  Row(label='67000', features=DenseVector([54.0, 2240.0, 530.0]), indexed=569.0),
#  Row(label='67030', features=DenseVector([197.0, 1791.0, 1240.0]), indexed=570.0),
#  Row(label='67080', features=DenseVector([92.0, 2617.0, 600.0]), indexed=571.0),
#  Row(label='67360', features=DenseVector([194.0, 2115.0, 790.0]), indexed=577.0),
#  Row(label='67370', features=DenseVector([73.0, 1073.0, 630.0]), indexed=578.0),
#  Row(label='67640', features=DenseVector([43.0, 2001.0, 730.0]), indexed=583.0),
#  Row(label='67710', features=DenseVector([193.0, 1770.0, 1070.0]), indexed=584.0),
#  Row(label='68230', features=DenseVector([227.0, 2227.0, 1220.0]), indexed=585.0),
#  Row(label='68260', features=DenseVector([416.0, 1732.0, 840.0]), indexed=586.0),
#  Row(label='68390', features=DenseVector([376.0, 1683.0, 890.0]), indexed=588.0),
#  Row(label='68430', features=DenseVector([219.0, 1737.0, 890.0]), indexed=590.0),
#  Row(label='68450', features=DenseVector([189.0, 1569.0, 710.0]), indexed=591.0),
#  Row(label='68590', features=DenseVector([241.0, 1609.0, 1150.0]), indexed=592.0),
#  Row(label='68850', features=DenseVector([301.0, 1885.0, 220.0]), indexed=594.0),
#  Row(label='68890', features=DenseVector([22.0, 1746.0, 690.0]), indexed=53.0),
#  Row(label='68890', features=DenseVector([203.0, 1579.0, 770.0]), indexed=53.0),
#  Row(label='68900', features=DenseVector([306.0, 1681.0, 440.0]), indexed=595.0),
#  Row(label='69030', features=DenseVector([442.0, 1491.0, 430.0]), indexed=596.0),
#  Row(label='69310', features=DenseVector([107.0, 2031.0, 810.0]), indexed=601.0),
#  Row(label='69450', features=DenseVector([177.0, 1848.0, 670.0]), indexed=605.0),
#  Row(label='69570', features=DenseVector([437.0, 2101.0, 520.0]), indexed=607.0),
#  Row(label='69600', features=DenseVector([163.0, 1723.0, 680.0]), indexed=55.0),
#  Row(label='69600', features=DenseVector([275.0, 1967.0, 1090.0]), indexed=55.0),
#  Row(label='69910', features=DenseVector([170.0, 1765.0, 490.0]), indexed=608.0),
#  Row(label='69940', features=DenseVector([192.0, 2148.0, 1140.0]), indexed=57.0),
#  Row(label='69940', features=DenseVector([243.0, 1861.0, 370.0]), indexed=57.0),
#  Row(label='70020', features=DenseVector([225.0, 1962.0, 800.0]), indexed=610.0),
#  Row(label='70050', features=DenseVector([26.0, 2073.0, 820.0]), indexed=611.0),
#  Row(label='70400', features=DenseVector([264.0, 2254.0, 1120.0]), indexed=616.0),
#  Row(label='70610', features=DenseVector([299.0, 1768.0, 780.0]), indexed=619.0),
#  Row(label='70770', features=DenseVector([59.0, 2104.0, 1080.0]), indexed=621.0),
#  Row(label='70810', features=DenseVector([212.0, 1807.0, 1030.0]), indexed=58.0),
#  Row(label='70930', features=DenseVector([183.0, 2339.0, 950.0]), indexed=623.0),
#  Row(label='71120', features=DenseVector([156.0, 1734.0, 380.0]), indexed=625.0),
#  Row(label='71280', features=DenseVector([11.0, 1439.0, 1090.0]), indexed=627.0),
#  Row(label='71300', features=DenseVector([61
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# 6040', features=DenseVector([749.0, 1638.0, 1140.0]), indexed=276.0),
#  Row(label='46050', features=DenseVector([542.0, 1936.0, 1320.0]), indexed=14.0),
#  Row(label='46220', features=DenseVector([834.0, 1725.0, 910.0]), indexed=279.0),
#  Row(label='46230', features=DenseVector([871.0, 1776.0, 800.0]), indexed=280.0),
#  Row(label='46380', features=DenseVector([738.0, 1351.0, 900.0]), indexed=282.0),
#  Row(label='46580', features=DenseVector([890.0, 1829.0, 650.0]), indexed=15.0),
#  Row(label='46760', features=DenseVector([514.0, 2208.0, 1090.0]), indexed=286.0),
#  Row(label='46920', features=DenseVector([479.0, 2108.0, 730.0]), indexed=289.0),
#  Row(label='46970', features=DenseVector([502.0, 1906.0, 450.0]), indexed=290.0),
#  Row(label='47060', features=DenseVector([785.0, 2396.0, 580.0]), indexed=291.0),
#  Row(label='47300', features=DenseVector([761.0, 1963.0, 900.0]), indexed=294.0),
#  Row(label='47350', features=DenseVector([699.0, 1956.0, 800.0]), indexed=296.0),
#  Row(label='47570', features=DenseVector([616.0, 1718.0, 370.0]), indexed=298.0),
#  Row(label='47590', features=DenseVector([821.0, 1296.0, 900.0]), indexed=299.0),
#  Row(label='47800', features=DenseVector([525.0, 1384.0, 730.0]), indexed=302.0),
#  Row(label='47920', features=DenseVector([883.0, 2187.0, 590.0]), indexed=303.0),
#  Row(label='48180', features=DenseVector([801.0, 1715.0, 1030.0]), indexed=308.0),
#  Row(label='48540', features=DenseVector([569.0, 2146.0, 1030.0]), indexed=310.0),
#  Row(label='48610', features=DenseVector([816.0, 1746.0, 720.0]), indexed=314.0),
#  Row(label='48950', features=DenseVector([861.0, 1510.0, 660.0]), indexed=16.0),
#  Row(label='49030', features=DenseVector([808.0, 1730.0, 510.0]), indexed=316.0),
#  Row(label='49160', features=DenseVector([744.0, 1699.0, 870.0]), indexed=17.0),
#  Row(label='49170', features=DenseVector([563.0, 2092.0, 580.0]), indexed=18.0),
#  Row(label='49350', features=DenseVector([637.0, 1822.0, 590.0]), indexed=323.0),
#  Row(label='49380', features=DenseVector([608.0, 1894.0, 760.0]), indexed=324.0),
#  Row(label='49510', features=DenseVector([703.0, 1729.0, 480.0]), indexed=19.0),
#  Row(label='49590', features=DenseVector([566.0, 1386.0, 980.0]), indexed=20.0),
#  Row(label='49720', features=DenseVector([819.0, 2160.0, 860.0]), indexed=21.0),
#  Row(label='49750', features=DenseVector([496.0, 1342.0, 760.0]), indexed=331.0),
#  Row(label='49990', features=DenseVector([844.0, 1751.0, 900.0]), indexed=335.0),
#  Row(label='50060', features=DenseVector([578.0, 1886.0, 660.0]), indexed=336.0),
#  Row(label='50250', features=DenseVector([534.0, 1633.0, 1270.0]), indexed=339.0),
#  Row(label='50590', features=DenseVector([612.0, 1839.0, 1000.0]), indexed=342.0),
#  Row(label='50730', features=DenseVector([623.0, 1635.0, 720.0]), indexed=345.0),
#  Row(label='50820', features=DenseVector([500.0, 1601.0, 460.0]), indexed=349.0),
#  Row(label='50940', features=DenseVector([515.0, 1523.0, 1140.0]), indexed=352.0),
#  Row(label='51310', features=DenseVector([658.0, 1839.0, 540.0]), indexed=360.0),
#  Row(label='51320', features=DenseVector([484.0, 2204.0, 930.0]), indexed=361.0),
#  Row(label='51380', features=DenseVector([713.0, 1844.0, 680.0]), indexed=362.0),
#  Row(label='51420', features=DenseVector([606.0, 2065.0, 910.0]), indexed=363.0),
#  Row(label='51480', features=DenseVector([577.0, 1372.0, 620.0]), indexed=23.0),
#  Row(label='51760', features=DenseVector([510.0, 2058.0, 700.0]), indexed=367.0),
#  Row(label='51910', features=DenseVector([802.0, 2248.0, 1160.0]), indexed=369.0),
#  Row(label='51990', features=DenseVector([747.0, 1776.0, 1020.0]), indexed=371.0),
#  Row(label='52050', features=DenseVector([874.0, 1452.0, 830.0]), indexed=372.0),
#  Row(label='52130', features=DenseVector([574.0, 1794.0, 550.0]), indexed=375.0),
#  Row(label='52160', features=DenseVector([884.0, 1625.0, 1140.0]), indexed=376.0),
#  Row(label='52340', features=DenseVector([863.0, 1919.0, 640.0]), indexed=379.0),
#  Row(label='52400', features=DenseVector([487.0, 2111.0, 680.0]), indexed=380.0),
#  Row(label='52540', features=DenseVector([550.0, 1050.0, 850.0]), indexed=384.0),
#  Row(label='52610', features=DenseVector([493.0, 1770.0, 800.0]), indexed=385.0),
#  Row(label='52940', features=DenseVector([695.0, 1529.0, 870.0]), indexed=386.0),
#  Row(label='52990', features=DenseVector([770.0, 2349.0, 750.0]), indexed=387.0),
#  Row(label='53230', features=DenseVector([719.0, 1743.0, 970.0]), indexed=25.0),
#  Row(label='53370', features=DenseVector([633.0, 1869.0, 1030.0]), indexed=389.0),
#  Row(label='53550', features=DenseVector([483.0, 2046.0, 380.0]), indexed=392.0),
#  Row(label='53750', features=DenseVector([635.0, 1920.0, 890.0]), indexed=394.0),
#  Row(label='53760', features=DenseVector([731.0, 2086.0, 550.0]), indexed=26.0),
#  Row(label='53760', features=DenseVector([792.0, 1791.0, 1010.0]), indexed=26.0),
#  Row(label='53890', features=DenseVector([492.0, 1695.0, 890.0]), indexed=397.0),
#  Row(label='53900', features=DenseVector([826.0, 1630.0, 1120.0]), indexed=398.0),
#  Row(label='53940', features=DenseVector([840.0, 1413.0, 480.0]), indexed=27.0),
#  Row(label='54060', features=DenseVector([591.0, 1437.0, 1330.0]), indexed=28.0),
#  Row(label='54060', features=DenseVector([806.0, 1902.0, 910.0]), indexed=28.0),
#  Row(label='54200', features=DenseVector([764.0, 2264.0, 310.0]), indexed=401.0),
#  Row(label='54340', features=DenseVector([896.0, 1429.0, 1110.0]), indexed=403.0),
#  Row(label='54370', features=DenseVector([571.0, 1461.0, 1070.0]), indexed=29.0),
#  Row(label='54380', features=DenseVector([859.0, 1393.0, 860.0]), indexed=405.0),
#  Row(label='54410', features=DenseVector([582.0, 1716.0, 630.0]), indexed=406.0),
#  Row(label='54450', features=DenseVector([533.0, 1981.0, 720.0]), indexed=407.0),
#  Row(label='54530', features=DenseVector([766.0, 1881.0, 740.0]), indexed=408.0),
#  Row(label='54590', features=DenseVector([675.0, 1677.0, 210.0]), indexed=0.0),
#  Row(label='54610', features=DenseVector([554.0, 1390.0, 1220.0]), indexed=409.0),
#  Row(label='54650', features=DenseVector([575.0, 2131.0, 1140.0]), indexed=410.0),
#  Row(label='54690', features=DenseVector([604.0, 1488.0, 770.0]), indexed=412.0),
#  Row(label='54820', features=DenseVector([649.0, 1794.0, 1400.0]), indexed=413.0),
#  Row(label='54950', features=DenseVector([640.0, 1895.0, 720.0]), indexed=414.0),
#  Row(label='55160', features=DenseVector([505.0, 1607.0, 370.0]), indexed=415.0),
#  Row(label='55390', features=DenseVector([793.0, 1713.0, 550.0]), indexed=417.0),
#  Row(label='55500', features=DenseVector([843.0, 1557.0, 580.0]), indexed=418.0),
#  Row(label='55710', features=DenseVector([679.0, 2126.0, 730.0]), indexed=421.0),
#  Row(label='55880', features=DenseVector([838.0, 2277.0, 610.0]), indexed=423.0),
#  Row(label='55980', features=DenseVector([711.0, 1815.0, 190.0]), indexed=424.0),
#  Row(label='55990', features=DenseVector([480.0, 1121.0, 940.0]), indexed=425.0),
#  Row(label='56230', features=DenseVector([791.0, 1876.0, 620.0]), indexed=428.0),
#  Row(label='56260', features=DenseVector([586.0, 1476.0, 720.0]), indexed=429.0),
#  Row(label='56380', features=DenseVector([798.0, 1808.0, 830.0]), indexed=431.0),
#  Row(label='56440', features=DenseVector([516.0, 2084.0, 820.0]), indexed=30.0),
#  Row(label='56480', features=DenseVector([466.0, 2065.0, 750.0]), indexed=434.0),
#  Row(label='56660', features=DenseVector([456.0, 1598.0, 690.0]), indexed=437.0),
#  Row(label='56710', features=DenseVector([777.0, 1742.0, 840.0]), indexed=31.0),
#  Row(label='56790', features=DenseVector([787.0, 1877.0, 790.0]), indexed=438.0),
#  Row(label='56820', features=DenseVector([498.0, 1087.0, 680.0]), indexed=440.0),
#  Row(label='56830', features=DenseVector([477.0, 1462.0, 560.0]), indexed=441.0),
#  Row(label='56850', features=DenseVector([644.0, 1555.0, 1020.0]), indexed=442.0),
#  Row(label='56860', features=DenseVector([740.0, 1645.0, 770.0]), indexed=443.0),
#  Row(label='56880', features=DenseVector([758.0, 1683.0, 680.0]), indexed=444.0),
#  Row(label='56910', features=DenseVector([684.0, 2262.0, 310.0]), indexed=445.0),
#  Row(label='57090', features=DenseVector([465.0, 1737.0, 770.0]), indexed=446.0),
#  Row(label='57200', features=DenseVector([651.0, 1584.0, 840.0]), indexed=449.0),
#  Row(label='57330', features=DenseVector([642.0, 1331.0, 1010.0]), indexed=450.0),
#  Row(label='57750', features=DenseVector([823.0, 1892.0, 540.0]), indexed=456.0),
#  Row(label='57820', features=DenseVector([878.0, 2138.0, 820.0]), indexed=457.0),
#  Row(label='57910', features=DenseVector([722.0, 2109.0, 1120.0]), indexed=460.0),
#  Row(label='58070', features=DenseVector([509.0, 1787.0, 800.0]), indexed=461.0),
#  Row(label='58160', features=DenseVector([836.0, 2009.0, 1000.0]), indexed=463.0),
#  Row(label='58390', features=DenseVector([545.0, 1519.0, 920.0]), indexed=466.0),
#  Row(label='58440', features=DenseVector([754.0, 1749.0, 890.0]), indexed=467.0),
#  Row(label='58660', features=DenseVector([632.0, 1722.0, 560.0]), indexed=33.0),
#  Row(label='58940', features=DenseVector([472.0, 1417.0, 1230.0]), indexed=34.0),
#  Row(label='58940', features=DenseVector([804.0, 1650.0, 420.0]), indexed=34.0),
#  Row(label='59070', features=DenseVector([543.0, 1845.0, 760.0]), indexed=472.0),
#  Row(label='59130', features=DenseVector([599.0, 2016.0, 830.0]), indexed=35.0),
#  Row(label='59160', features=DenseVector([832.0, 1179.0, 710.0]), indexed=473.0),
#  Row(label='59190', features=DenseVector([729.0, 1773.0, 970.0]), indexed=36.0),
#  Row(label='59290', features=DenseVector([847.0, 1819.0, 540.0]), indexed=474.0),
#  Row(label='59530', features=DenseVector([737.0, 1309.0, 860.0]), indexed=476.0),
#  Row(label='59540', features=DenseVector([603.0, 1720.0, 1180.0]), indexed=477.0),
#  Row(label='59820', features=DenseVector([778.0, 1798.0, 850.0]), indexed=37.0),
#  Row(label='59820', features=DenseVector([842.0, 1843.0, 340.0]), indexed=37.0),
#  Row(label='59920', features=DenseVector([532.0, 1517.0, 790.0]), indexed=480.0),
#  Row(label='59950', features=DenseVector([851.0, 2362.0, 1020.0]), indexed=482.0),
#  Row(label='60060', features=DenseVector([595.0, 1931.0, 790.0]), indexed=38.0),
#  Row(label='60060', features=DenseVector([736.0, 1733.0, 320.0]), indexed=38.0),
#  Row(label='60270', features=DenseVector([876.0, 2023.0, 540.0]), indexed=487.0),
#  Row(label='60440', features=DenseVector([780.0, 1472.0, 710.0]), indexed=39.0),
#  Row(label='60440', features=DenseVector([783.0, 1280.0, 1240.0]), indexed=39.0),
#  Row(label='60680', features=DenseVector([715.0, 1482.0, 1070.0]), indexed=489.0),
#  Row(label='60800', features=DenseVector([613.0, 2014.0, 660.0]), indexed=491.0),
#  Row(label='61000', features=DenseVector([538.0, 1920.0, 600.0]), indexed=42.0),
#  Row(label='61080', features=DenseVector([712.0, 1612.0, 490.0]), indexed=496.0),
#  Row(label='61210', features=DenseVector([879.0, 1468.0, 1210.0]), indexed=499.0),
#  Row(label='61590', features=DenseVector([626.0, 1680.0, 1070.0]), indexed=501.0),
#  Row(label='61730', features=DenseVector([631.0, 1836.0, 940.0]), indexed=504.0),
#  Row(label='62050', features=DenseVector([630.0, 2264.0, 830.0]), indexed=43.0),
#  Row(label='62050', features=DenseVector([701.0, 2262.0, 560.0]), indexed=43.0),
#  Row(label='62380', features=DenseVector([672.0, 2010.0, 990.0]), indexed=45.0),
#  Row(label='62380', features=DenseVector([725.0, 1795.0, 530.0]), indexed=45.0),
#  Row(label='62420', features=DenseVector([757.0, 1506.0, 990.0]), indexed=509.0),
#  Row(label='62960', features=DenseVector([647.0, 1670.0, 410.0]), indexed=517.0),
#  Row(label='63020', features=DenseVector([848.0, 1745.0, 970.0]), indexed=46.0),
#  Row(label='63050', features=DenseVector([706.0, 1924.0, 1170.0]), indexed=518.0),
#  Row(label='63100', features=DenseVector([828.0, 2024.0, 620.0]), indexed=519.0),
#  Row(label='63300', features=DenseVector([809.0, 1800.0, 780.0]), indexed=520.0),
#  Row(label='63510', features=DenseVector([551.0, 2465.0, 720.0]), indexed=521.0),
#  Row(label='63540', features=DenseVector([855.0, 1789.0, 550.0]), indexed=1.0),
#  Row(label='63600', features=DenseVector([519.0, 1817.0, 850.0]), indexed=523.0),
#  Row(label='63660', features=DenseVector([646.0, 1649.0, 740.0]), indexed=47.0),
#  Row(label='63850', features=DenseVector([673.0, 1958.0, 290.0]), indexed=527.0),
#  Row(label='63950', features=DenseVector([564.0, 1440.0, 500.0]), indexed=528.0),
#  Row(label='64010', features=DenseVector([507.0, 2142.0, 950.0]), indexed=529.0),
#  Row(label='64120', features=DenseVector([669.0, 1278.0, 440.0]), indexed=531.0),
#  Row(label='64320', features=DenseVector([704.0, 2167.0, 700.0]), indexed=532.0),
#  Row(label='64690', features=DenseVector([716.0, 2384.0, 1110.0]), indexed=535.0),
#  Row(label='64780', features=DenseVector([539.0, 1968.0, 210.0]), indexed=537.0),
#  Row(label='64990', features=DenseVector([482.0, 2002.0, 1050.0]), indexed=540.0),
#  Row(label='65080', features=DenseVector([700.0, 1928.0, 660.0]), indexed=541.0),
#  Row(label='65120', features=DenseVector([607.0, 1536.0, 540.0]), indexed=542.0),
#  Row(label='65300', features=DenseVector([707.0, 1793.0, 1020.0]), indexed=544.0),
#  Row(label='65390', features=DenseVector([677.0, 1472.0, 790.0]), indexed=547.0),
#  Row(label='65410', features=DenseVector([763.0, 1428.0, 830.0]), indexed=548.0),
#  Row(label='65750', features=DenseVector([512.0, 1490.0, 330.0]), indexed=552.0),
#  Row(label='65890', features=DenseVector([797.0, 1610.0, 700.0]), indexed=49.0),
#  Row(label='66050', features=DenseVector([486.0, 1719.0, 580.0]), indexed=51.0),
#  Row(label='66050', features=DenseVector([511.0, 2022.0, 1050.0]), indexed=51.0),
#  Row(label='66070', features=DenseVector([661.0, 2020.0, 980.0]), indexed=559.0),
#  Row(label='66160', features=DenseVector([670.0, 1785.0, 1340.0]), indexed=560.0),
#  Row(label='66300', features=DenseVector([732.0, 2310.0, 520.0]), indexed=564.0),
#  Row(label='66390', features=DenseVector([831.0, 2101.0, 900.0]), indexed=52.0),
#  Row(label='66390', features=DenseVector([892.0, 1910.0, 1080.0]), indexed=52.0),
#  Row(label='67090', features=DenseVector([788.0, 1723.0, 1040.0]), indexed=572.0),
#  Row(label='67100', features=DenseVector([489.0, 1466.0, 730.0]), indexed=573.0),
#  Row(label='67110', features=DenseVector([628.0, 1888.0, 600.0]), indexed=574.0),
#  Row(label='67290', features=DenseVector([567.0, 1703.0, 1000.0]), indexed=575.0),
#  Row(label='67320', features=DenseVector([796.0, 1747.0, 1090.0]), indexed=576.0),
#  Row(label='67390', features=DenseVector([765.0, 1378.0, 730.0]), indexed=579.0),
#  Row(label='67610', features=DenseVector([452.0, 2137.0, 670.0]), indexed=582.0),
#  Row(label='68350', features=DenseVector([619.0, 1791.0, 630.0]), indexed=587.0),
#  Row(label='68420', features=DenseVector([598.0, 1872.0, 1080.0]), indexed=589.0),
#  Row(label='69050', features=DenseVector([476.0, 1764.0, 1060.0]), indexed=597.0),
#  Row(label='69090', features=DenseVector([453.0, 1291.0, 930.0]), indexed=598.0),
#  Row(label='69190', features=DenseVector([611.0, 1804.0, 430.0]), indexed=599.0),
#  Row(label='69210', features=DenseVector([680.0, 1823.0, 1040.0]), indexed=600.0),
#  Row(label='69320', features=DenseVector([576.0, 1747.0, 750.0]), indexed=602.0),
#  Row(label='69370', features=DenseVector([627.0, 1746.0, 590.0]), indexed=603.0),
#  Row(label='69390', features=DenseVector([583.0, 2053.0, 730.0]), indexed=604.0),
#  Row(label='69610', features=DenseVector([524.0, 1968.0, 340.0]), indexed=56.0),
#  Row(label='69990', features=DenseVector([687.0, 1562.0, 490.0]), indexed=609.0),
#  Row(label='70110', features=DenseVector([625.0, 1284.0, 750.0]), indexed=612.0),
#  Row(label='70230', features=DenseVector([850.0, 2492.0, 790.0]), indexed=613.0),
#  Row(label='70290', features=DenseVector([559.0, 1472.0, 810.0]), indexed=614.0),
#  Row(label='70310', features=DenseVector([529.0, 2064.0, 940.0]), indexed=615.0),
#  Row(label='70580', features=DenseVector([771.0, 1540.0, 590.0]), indexed=618.0),
#  Row(label='70620', features=DenseVector([891.0, 1851.0, 1220.0]), indexed=620.0),
#  Row(label='70810', features=DenseVector([565.0, 1743.0, 1200.0]), indexed=58.0),
#  Row(label='70830', features=DenseVector([800.0, 1508.0, 1260.0]), indexed=622.0),
#  Row(label='70940', features=DenseVector([756.0, 1643.0, 740.0]), indexed=59.0),
#  Row(label='70940', features=DenseVector([839.0, 1937.0, 1050.0]), indexed=59.0),
#  Row(label='70980', features=DenseVector([881.0, 1516.0, 780.0]), indexed=624.0),
#  Row(label='71240', features=DenseVector([471.0, 1919.0, 960.0]), indexed=626.0),
#  Row(label='71290', features=DenseVector([624.0, 1823.0, 520.0]), indexed=628.0),
#  Row(label='71830', features=DenseVector([813.0, 1918.0, 1260.0]), indexed=634.0),
#  Row(label='72000', features=DenseVector([548.0, 1353.0, 1370.0]), indexed=635.0),
#  Row(label='72020', features=DenseVector([506.0, 1846.0, 760.0]), indexed=636.0),
#  Row(label='72270', features=DenseVector([886.0, 1337.0, 560.0]), indexed=640.0),
#  Row(label='72410', features=DenseVector([570.0, 1822.0, 420.0]), indexed=643.0),
#  Row(label='72550', features=DenseVector([682.0, 1750.0, 570.0]), indexed=645.0),
#  Row(label='72740', features=DenseVector([688.0, 1775.0, 230.0]), indexed=648.0),
#  Row(label='72940', features=DenseVector([659.0, 1623.0, 1010.0]), indexed=650.0),
#  Row(label='73160', features=DenseVector([817.0, 1860.0, 670.0]), indexed=653.0),
#  Row(label='73500', features=DenseVector([794.0, 1672.0, 800.0]), indexed=655.0),
#  Row(label='73590', features=DenseVector([697.0, 1455.0, 750.0]), indexed=656.0),
#  Row(label='73610', features=DenseVector([805.0, 2078.0, 770.0]), indexed=657.0),
#  Row(label='73800', features=DenseVector([667.0, 1692.0, 790.0]), indexed=60.0),
#  Row(label='73810', features=DenseVector([849.0, 1099.0, 1560.0]), indexed=660.0),
#  Row(label='74080', features=DenseVector([769.0, 1347.0, 700.0]), indexed=61.0),
#  Row(label='74160', features=DenseVector([773.0, 1503.0, 660.0]), indexed=663.0),
#  Row(label='74330', features=DenseVector([600.0, 1947.0, 910.0]), indexed=667.0),
#  Row(label='74550', features=DenseVector([464.0, 1411.0, 460.0]), indexed=669.0),
#  Row(label='75120', features=DenseVector([592.0, 2186.0, 910.0]), indexed=674.0),
#  Row(label='75300', features=DenseVector([781.0, 1783.0, 450.0]), indexed=676.0),
#  Row(label='75530', features=DenseVector([641.0, 1749.0, 490.0]), indexed=678.0),
#  Row(label='75800', features=DenseVector([752.0, 1979.0, 480.0]), indexed=62.0),
#  Row(label='75880', features=DenseVector([451.0, 1759.0, 880.0]), indexed=681.0),
#  Row(label='75930', features=DenseVector([873.0, 2024.0, 1070.0]), indexed=682.0),
#  Row(label='76250', features=DenseVector([602.0, 1489.0, 1380.0]), indexed=687.0),
#  Row(label='76440', features=DenseVector([894.0, 1436.0, 1060.0]), indexed=691.0),
#  Row(label='76470', features=DenseVector([587.0, 1930.0, 740.0]), indexed=692.0),
#  Row(label='76670', features=DenseVector([751.0, 1308.0, 1170.0]), indexed=694.0),
#  Row(label='77080', features=DenseVector([601.0, 1722.0, 830.0]), indexed=64.0),
#  Row(label='77080', features=DenseVector([868.0, 1959.0, 370.0]), indexed=64.0),
#  Row(label='77430', features=DenseVector([887.0, 1986.0, 1150.0]), indexed=701.0),
#  Row(label='77570', features=DenseVector([531.0, 1777.0, 800.0]), indexed=702.0),
#  Row(label='77740', features=DenseVector([745.0, 1018.0, 660.0]), indexed=703.0),
#  Row(label='77790', features=DenseVector([615.0, 1751.0, 760.0]), indexed=704.0),
#  Row(label='77960', features=DenseVector([470.0, 2436.0, 680.0]), indexed=705.0),
#  Row(label='78020', features=DenseVector([503.0, 2284.0, 310.0]), indexed=706.0),
#  Row(label='78060', features=DenseVector([768.0, 1345.0, 790.0]), indexed=707.0),
#  Row(label='78090', features=DenseVector([639.0, 2189.0, 310.0]), indexed=66.0),
#  Row(label='78100', features=DenseVector([852.0, 1558.0, 790.0]), indexed=67.0),
#  Row(label='78430', features=DenseVector([645.0, 2121.0, 1050.0]), indexed=710.0),
#  Row(label='78530', features=DenseVector([664.0, 2048.0, 700.0]), indexed=712.0),
#  Row(label='78870', features=DenseVector([528.0, 1869.0, 710.0]), indexed=69.0),
#  Row(label='78950', features=DenseVector([473.0, 1690.0, 800.0]), indexed=713.0),
#  Row(label='79220', features=DenseVector([450.0, 2015.0, 1160.0]), indexed=716.0),
#  Row(label='79310', features=DenseVector([814.0, 2252.0, 330.0]), indexed=718.0),
#  Row(label='79410', features=DenseVector([858.0, 1982.0, 390.0]), indexed=70.0),
#  Row(label='79760', features=DenseVector([767.0, 1939.0, 960.0]), indexed=720.0),
#  Row(label='79780', features=DenseVector([580.0, 2246.0, 410.0]), indexed=71.0),
#  Row(label='80370', features=DenseVector([546.0, 1420.0, 880.0]), indexed=724.0),
#  Row(label='80580', features=DenseVector([870.0, 1732.0, 1170.0]), indexed=727.0),
#  Row(label='80720', features=DenseVector([784.0, 1785.0, 570.0]), indexed=728.0),
#  Row(label='80830', features=DenseVector([656.0, 1430.0, 560.0]), indexed=731.0),
#  Row(label='81370', features=DenseVector([468.0, 1783.0, 730.0]), indexed=734.0),
#  Row(label='81390', features=DenseVector([622.0, 1687.0, 830.0]), indexed=72.0),
#  Row(label='81390', features=DenseVector([811.0, 1194.0, 1090.0]), indexed=72.0),
#  Row(label='81720', features=DenseVector([753.0, 2017.0, 930.0]), indexed=736.0),
#  Row(label='81870', features=DenseVector([648.0, 1590.0, 770.0]), indexed=73.0),
#  Row(label='81930', features=DenseVector([735.0, 2061.0, 860.0]), indexed=739.0),
#  Row(label='82020', features=DenseVector([629.0, 2408.0, 380.0]), indexed=740.0),
#  Row(label='82080', features=DenseVector([893.0, 1663.0, 850.0]), indexed=742.0),
#  Row(label='82270', features=DenseVector([596.0, 1805.0, 1270.0]), indexed=743.0),
#  Row(label='82350', features=DenseVector([655.0, 1387.0, 1060.0]), indexed=74.0),
#  Row(label='82390', features=DenseVector([685.0, 1820.0, 310.0]), indexed=744.0),
#  Row(label='82970', features=DenseVector([790.0, 1548.0, 370.0]), indexed=747.0),
#  Row(label='83220', features=DenseVector([694.0, 1883.0, 1040.0]), indexed=748.0),
#  Row(label='83720', features=DenseVector([501.0, 1660.0, 1070.0]), indexed=752.0),
#  Row(label='84040', features=DenseVector([549.0, 1481.0, 410.0]), indexed=754.0),
#  Row(label='84300', features=DenseVector([810.0, 2008.0, 790.0]), indexed=755.0),
#  Row(label='84360', features=DenseVector([605.0, 1306.0, 680.0]), indexed=75.0),
#  Row(label='84360', features=DenseVector([652.0, 1817.0, 950.0]), indexed=75.0),
#  Row(label='84410', features=DenseVector([714.0, 1947.0, 670.0]), indexed=756.0),
#  Row(label='85000', features=DenseVector([807.0, 2214.0, 1110.0]), indexed=759.0),
#  Row(label='85160', features=DenseVector([573.0, 1375.0, 940.0]), indexed=761.0),
#  Row(label='85670', features=DenseVector([799.0, 2420.0, 850.0]), indexed=77.0),
#  Row(label='85720', features=DenseVector([755.0, 1591.0, 680.0]), indexed=764.0),
#  Row(label='86560', features=DenseVector([621.0, 2342.0, 690.0]), indexed=765.0),
#  Row(label='86620', features=DenseVector([741.0, 1616.0, 710.0]), indexed=766.0),
#  Row(label='86830', features=DenseVector([786.0, 2368.0, 450.0]), indexed=768.0),
#  Row(label='86890', features=DenseVector([760.0, 1993.0, 440.0]), indexed=769.0),
#  Row(label='87160', features=DenseVector([561.0, 1650.0, 540.0]), indexed=771.0),
#  Row(label='87220', features=DenseVector([856.0, 1455.0, 950.0]), indexed=773.0),
#  Row(label='87330', features=DenseVector([555.0, 2185.0, 840.0]), indexed=774.0),
#  Row(label='87410', features=DenseVector([467.0, 2667.0, 660.0]), indexed=776.0),
#  Row(label='87890', features=DenseVector([815.0, 1459.0, 540.0]), indexed=777.0),
#  Row(label='87930', features=DenseVector([643.0, 1841.0, 680.0]), indexed=778.0),
#  Row(label='88120', features=DenseVector([728.0, 1711.0, 1020.0]), indexed=779.0),
#  Row(label='88210', features=DenseVector([560.0, 1512.0, 1070.0]), indexed=780.0),
#  Row(label='88270', features=DenseVector([877.0, 1493.0, 100.0]), indexed=781.0),
#  Row(label='88410', features=DenseVector([556.0, 2072.0, 560.0]), indexed=783.0),
#  Row(label='89760', features=DenseVector([557.0, 1138.0, 820.0]), indexed=789.0),
#  Row(label='90070', features=DenseVector([589.0, 2174.0, 770.0]), indexed=790.0),
#  Row(label='92370', features=DenseVector([888.0, 1398.0, 140.0]), indexed=798.0),
#  Row(label='92640', features=DenseVector([854.0, 1906.0, 550.0]), indexed=799.0),
#  Row(label='93000', features=DenseVector([733.0, 1999.0, 950.0]), indexed=800.0),
#  Row(label='93360', features=DenseVector([696.0, 1958.0, 530.0]), indexed=801.0),
#  Row(label='93530', features=DenseVector([478.0, 1480.0, 860.0]), indexed=802.0),
#  Row(label='94370', features=DenseVector([690.0, 1276.0, 640.0]), indexed=805.0),
#  Row(label='94460', features=DenseVector([572.0, 2184.0, 830.0]), indexed=806.0),
#  Row(label='94690', features=DenseVector([665.0, 2111.0, 580.0]), indexed=807.0),
#  Row(label='95900', features=DenseVector([812.0, 1635.0, 1270.0]), indexed=808.0),
#  Row(label='96610', features=DenseVector([895.0, 1560.0, 770.0]), indexed=809.0),
#  Row(label='97360', features=DenseVector([469.0, 1279.0, 670.0]), indexed=812.0),
#  Row(label='98260', features=DenseVector([872.0, 2158.0, 1100.0]), indexed=813.0),
#  Row(label='99480', features=DenseVector([693.0, 1858.0, 480.0]), indexed=814.0)]

# %%
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.linalg import Vectors, VectorUDT
#from pyspark.ml.linalg import Vectors as MLLibVectors
#from pyspark.ml.linalg import VectorUDT
#from pyspark.sql.functions import udf

# %%
#Create the model
dtClassifer = DecisionTreeClassifier(maxDepth=2, labelCol="indexed")
dtModel = dtClassifer.fit(trainingData)
dtModel.numNodes
dtModel.depth
# Out:
# Out[20]: 2

# %%
#Predict on the test data
predictions = dtModel.transform(trainingData)

# %%
predictions.select("prediction","indexed","label","features").collect()
# Out:
# Out[22]: [Row(prediction=1.0, indexed=81.0, label='102310', features=DenseVector([409.0, 1587.0, 1310.0])),
#  Row(prediction=1.0, indexed=82.0, label='102920', features=DenseVector([433.0, 1638.0, 680.0])),
#  Row(prediction=1.0, indexed=85.0, label='14920', features=DenseVector([32.0, 1508.0, 990.0])),
#  Row(prediction=1.0, indexed=89.0, label='21300', features=DenseVector([353.0, 1686.0, 850.0])),
#  Row(prediction=71.0, indexed=91.0, label='21650', features=DenseVector([373.0, 2254.0, 1340.0])),
#  Row(prediction=1.0, indexed=92.0, label='21750', features=DenseVector([278.0, 1869.0, 1030.0])),
#  Row(prediction=1.0, indexed=93.0, label='21830', features=DenseVector([253.0, 1907.0, 680.0])),
#  Row(prediction=1.0, indexed=97.0, label='24410', features=DenseVector([224.0, 1606.0, 1200.0])),
#  Row(prediction=1.0, indexed=99.0, label='25630', features=DenseVector([273.0, 1571.0, 1190.0])),
#  Row(prediction=1.0, indexed=100.0, label='25820', features=DenseVector([27.0, 1777.0, 1100.0])),
#  Row(prediction=1.0, indexed=101.0, label='25950', features=DenseVector([261.0, 1426.0, 980.0])),
#  Row(prediction=1.0, indexed=102.0, label='26220', features=DenseVector([271.0, 1439.0, 780.0])),
#  Row(prediction=1.0, indexed=103.0, label='26770', features=DenseVector([77.0, 1520.0, 450.0])),
#  Row(prediction=1.0, indexed=104.0, label='27310', features=DenseVector([359.0, 1216.0, 460.0])),
#  Row(prediction=1.0, indexed=105.0, label='27410', features=DenseVector([154.0, 1963.0, 490.0])),
#  Row(prediction=1.0, indexed=106.0, label='27720', features=DenseVector([396.0, 1829.0, 380.0])),
#  Row(prediction=71.0, indexed=114.0, label='30810', features=DenseVector([290.0, 2364.0, 660.0])),
#  Row(prediction=1.0, indexed=2.0, label='31180', features=DenseVector([118.0, 2046.0, 460.0])),
#  Row(prediction=1.0, indexed=117.0, label='31890', features=DenseVector([318.0, 1484.0, 560.0])),
#  Row(prediction=71.0, indexed=118.0, label='31940', features=DenseVector([374.0, 2306.0, 820.0])),
#  Row(prediction=1.0, indexed=119.0, label='32260', features=DenseVector([397.0, 2044.0, 1140.0])),
#  Row(prediction=1.0, indexed=120.0, label='32330', features=DenseVector([186.0, 1717.0, 230.0])),
#  Row(prediction=1.0, indexed=123.0, label='32770', features=DenseVector([122.0, 1835.0, 900.0])),
#  Row(prediction=1.0, indexed=124.0, label='33010', features=DenseVector([446.0, 1869.0, 1000.0])),
#  Row(prediction=1.0, indexed=126.0, label='33240', features=DenseVector([428.0, 2042.0, 430.0])),
#  Row(prediction=1.0, indexed=127.0, label='33430', features=DenseVector([69.0, 1941.0, 650.0])),
#  Row(prediction=1.0, indexed=128.0, label='33460', features=DenseVector([174.0, 2145.0, 490.0])),
#  Row(prediction=1.0, indexed=129.0, label='33580', features=DenseVector([72.0, 1380.0, 530.0])),
#  Row(prediction=1.0, indexed=130.0, label='33730', features=DenseVector([216.0, 1909.0, 370.0])),
#  Row(prediction=1.0, indexed=131.0, label='33740', features=DenseVector([222.0, 1922.0, 550.0])),
#  Row(prediction=1.0, indexed=132.0, label='33890', features=DenseVector([389.0, 1589.0, 1050.0])),
#  Row(prediction=1.0, indexed=133.0, label='34020', features=DenseVector([280.0, 1571.0, 730.0])),
#  Row(prediction=1.0, indexed=134.0, label='34180', features=DenseVector([204.0, 1192.0, 900.0])),
#  Row(prediction=1.0, indexed=135.0, label='34190', features=DenseVector([361.0, 2095.0, 980.0])),
#  Row(prediction=1.0, indexed=137.0, label='34410', features=DenseVector([158.0, 1696.0, 350.0])),
#  Row(prediction=1.0, indexed=142.0, label='35230', features=DenseVector([326.0, 1810.0, 950.0])),
#  Row(prediction=1.0, indexed=143.0, label='35280', features=DenseVector([298.0, 1352.0, 710.0])),
#  Row(prediction=1.0, indexed=146.0, label='35510', features=DenseVector([125.0, 1390.0, 370.0])),
#  Row(prediction=1.0, indexed=148.0, label='35600', features=DenseVector([362.0, 1468.0, 850.0])),
#  Row(prediction=1.0, indexed=150.0, label='35800', features=DenseVector([45.0, 1194.0, 520.0])),
#  Row(prediction=1.0, indexed=157.0, label='36330', features=DenseVector([110.0, 1700.0, 920.0])),
#  Row(prediction=1.0, indexed=162.0, label='36690', features=DenseVector([366.0, 1837.0, 1130.0])),
#  Row(prediction=1.0, indexed=163.0, label='36740', features=DenseVector([395.0, 1464.0, 600.0])),
#  Row(prediction=1.0, indexed=165.0, label='37130', features=DenseVector([269.0, 1456.0, 920.0])),
#  Row(prediction=1.0, indexed=166.0, label='37320', features=DenseVector([155.0, 1663.0, 670.0])),
#  Row(prediction=1.0, indexed=167.0, label='37330', features=DenseVector([297.0, 1436.0, 690.0])),
#  Row(prediction=1.0, indexed=169.0, label='37720', features=DenseVector([8.0, 1507.0, 1020.0])),
#  Row(prediction=1.0, indexed=170.0, label='37810', features=DenseVector([165.0, 2176.0, 700.0])),
#  Row(prediction=1.0, indexed=4.0, label='37830', features=DenseVector([209.0, 2055.0, 1080.0])),
#  Row(prediction=1.0, indexed=173.0, label='38070', features=DenseVector([149.0, 1480.0, 830.0])),
#  Row(prediction=1.0, indexed=174.0, label='38120', features=DenseVector([206.0, 2149.0, 910.0])),
#  Row(prediction=1.0, indexed=175.0, label='38170', features=DenseVector([18.0, 2045.0, 670.0])),
#  Row(prediction=1.0, indexed=176.0, label='38210', features=DenseVector([260.0, 1370.0, 350.0])),
#  Row(prediction=1.0, indexed=6.0, label='38600', features=DenseVector([391.0, 1799.0, 960.0])),
#  Row(prediction=1.0, indexed=181.0, label='38650', features=DenseVector([168.0, 1606.0, 630.0])),
#  Row(prediction=1.0, indexed=182.0, label='38660', features=DenseVector([79.0, 2044.0, 960.0])),
#  Row(prediction=1.0, indexed=184.0, label='38970', features=DenseVector([288.0, 1799.0, 510.0])),
#  Row(prediction=1.0, indexed=188.0, label='39200', features=DenseVector([378.0, 1699.0, 680.0])),
#  Row(prediction=1.0, indexed=189.0, label='39420', features=DenseVector([387.0, 1697.0, 1200.0])),
#  Row(prediction=1.0, indexed=190.0, label='39460', features=DenseVector([282.0, 2073.0, 500.0])),
#  Row(prediction=1.0, indexed=193.0, label='39650', features=DenseVector([88.0, 1506.0, 850.0])),
#  Row(prediction=1.0, indexed=7.0, label='39730', features=DenseVector([44.0, 2117.0, 780.0])),
#  Row(prediction=1.0, indexed=7.0, label='39730', features=DenseVector([190.0, 2000.0, 480.0])),
#  Row(prediction=1.0, indexed=195.0, label='39740', features=DenseVector([151.0, 1629.0, 770.0])),
#  Row(prediction=1.0, indexed=196.0, label='39800', features=DenseVector([254.0, 1719.0, 1060.0])),
#  Row(prediction=1.0, indexed=197.0, label='39820', features=DenseVector([2.0, 1752.0, 210.0])),
#  Row(prediction=1.0, indexed=199.0, label='40000', features=DenseVector([439.0, 1561.0, 1070.0])),
#  Row(prediction=71.0, indexed=200.0, label='40190', features=DenseVector([20.0, 2340.0, 980.0])),
#  Row(prediction=71.0, indexed=202.0, label='40350', features=DenseVector([350.0, 2228.0, 1530.0])),
#  Row(prediction=1.0, indexed=204.0, label='40490', features=DenseVector([134.0, 2071.0, 900.0])),
#  Row(prediction=1.0, indexed=209.0, label='40930', features=DenseVector([182.0, 1396.0, 1100.0])),
#  Row(prediction=1.0, indexed=8.0, label='41080', features=DenseVector([187.0, 1796.0, 1060.0])),
#  Row(prediction=1.0, indexed=8.0, label='41080', features=DenseVector([329.0, 1954.0, 760.0])),
#  Row(prediction=1.0, indexed=212.0, label='41190', features=DenseVector([100.0, 1899.0, 1140.0])),
#  Row(prediction=1.0, indexed=9.0, label='41490', features=DenseVector([308.0, 1654.0, 410.0])),
#  Row(prediction=1.0, indexed=9.0, label='41490', features=DenseVector([321.0, 1459.0, 930.0])),
#  Row(prediction=1.0, indexed=215.0, label='41570', features=DenseVector([37.0, 1744.0, 610.0])),
#  Row(prediction=1.0, indexed=218.0, label='41710', features=DenseVector([444.0, 1570.0, 1080.0])),
#  Row(prediction=1.0, indexed=219.0, label='41740', features=DenseVector([276.0, 1805.0, 1040.0])),
#  Row(prediction=1.0, indexed=221.0, label='41880', features=DenseVector([25.0, 1488.0, 840.0])),
#  Row(prediction=1.0, indexed=224.0, label='42060', features=DenseVector([90.0, 1758.0, 420.0])),
#  Row(prediction=1.0, indexed=226.0, label='42430', features=DenseVector([70.0, 1576.0, 710.0])),
#  Row(prediction=1.0, indexed=227.0, label='42530', features=DenseVector([159.0, 932.0, 1090.0])),
#  Row(prediction=1.0, indexed=228.0, label='42620', features=DenseVector([176.0, 1619.0, 700.0])),
#  Row(prediction=1.0, indexed=229.0, label='42670', features=DenseVector([84.0, 1884.0, 1410.0])),
#  Row(prediction=1.0, indexed=231.0, label='42840', features=DenseVector([136.0, 1993.0, 740.0])),
#  Row(prediction=1.0, indexed=10.0, label='42860', features=DenseVector([188.0, 1985.0, 1180.0])),
#  Row(prediction=1.0, indexed=239.0, label='43390', features=DenseVector([251.0, 1648.0, 530.0])),
#  Row(prediction=1.0, indexed=245.0, label='43720', features=DenseVector([337.0, 1583.0, 540.0])),
#  Row(prediction=1.0, indexed=247.0, label='43860', features=DenseVector([419.0, 1530.0, 1240.0])),
#  Row(prediction=1.0, indexed=249.0, label='44090', features=DenseVector([175.0, 1832.0, 580.0])),
#  Row(prediction=1.0, indexed=250.0, label='44150', features=DenseVector([10.0, 1235.0, 1130.0])),
#  Row(prediction=1.0, indexed=255.0, label='44660', features=DenseVector([335.0, 1973.0, 1440.0])),
#  Row(prediction=1.0, indexed=258.0, label='44860', features=DenseVector([293.0, 1622.0, 560.0])),
#  Row(prediction=1.0, indexed=260.0, label='44910', features=DenseVector([171.0, 1599.0, 870.0])),
#  Row(prediction=1.0, indexed=261.0, label='44960', features=DenseVector([307.0, 1813.0, 520.0])),
#  Row(prediction=1.0, indexed=262.0, label='45020', features=DenseVector([162.0, 1657.0, 580.0])),
#  Row(prediction=1.0, indexed=264.0, label='45260', features=DenseVector([6.0, 1733.0, 760.0])),
#  Row(prediction=71.0, indexed=265.0, label='45460', features=DenseVector([36.0, 2230.0, 700.0])),
#  Row(prediction=1.0, indexed=266.0, label='45480', features=DenseVector([40.0, 1516.0, 10.0])),
#  Row(prediction=1.0, indexed=267.0, label='45580', features=DenseVector([334.0, 1957.0, 1280.0])),
#  Row(prediction=1.0, indexed=268.0, label='45650', features=DenseVector([233.0, 1499.0, 570.0])),
#  Row(prediction=1.0, indexed=269.0, label='45720', features=DenseVector([89.0, 1468.0, 960.0])),
#  Row(prediction=71.0, indexed=271.0, label='45820', features=DenseVector([346.0, 2378.0, 810.0])),
#  Row(prediction=1.0, indexed=273.0, label='45940', features=DenseVector([287.0, 1586.0, 420.0])),
#  Row(prediction=1.0, indexed=275.0, label='46030', features=DenseVector([406.0, 1893.0, 1180.0])),
#  Row(prediction=1.0, indexed=14.0, label='46050', features=DenseVector([250.0, 1976.0, 620.0])),
#  Row(prediction=71.0, indexed=277.0, label='46100', features=DenseVector([62.0, 2391.0, 530.0])),
#  Row(prediction=1.0, indexed=278.0, label='46140', features=DenseVector([166.0, 1133.0, 580.0])),
#  Row(prediction=1.0, indexed=281.0, label='46310', features=DenseVector([9.0, 1321.0, 680.0])),
#  Row(prediction=1.0, indexed=15.0, label='46580', features=DenseVector([123.0, 1669.0, 530.0])),
#  Row(prediction=1.0, indexed=283.0, label='46620', features=DenseVector([5.0, 2111.0, 450.0])),
#  Row(prediction=1.0, indexed=284.0, label='46650', features=DenseVector([342.0, 1999.0, 740.0])),
#  Row(prediction=1.0, indexed=285.0, label='46700', features=DenseVector([338.0, 1750.0, 480.0])),
#  Row(prediction=71.0, indexed=287.0, label='46830', features=DenseVector([115.0, 2287.0, 1210.0])),
#  Row(prediction=1.0, indexed=288.0, label='46840', features=DenseVector([284.0, 1646.0, 800.0])),
#  Row(prediction=1.0, indexed=293.0, label='47230', features=DenseVector([237.0, 1434.0, 670.0])),
#  Row(prediction=1.0, indexed=295.0, label='47310', features=DenseVector([352.0, 1897.0, 1210.0])),
#  Row(prediction=1.0, indexed=297.0, label='47460', features=DenseVector([173.0, 1207.0, 670.0])),
#  Row(prediction=1.0, indexed=300.0, label='47620', features=DenseVector([431.0, 1943.0, 460.0])),
#  Row(prediction=1.0, indexed=301.0, label='47730', features=DenseVector([291.0, 1264.0, 360.0])),
#  Row(prediction=1.0, indexed=304.0, label='48030', features=DenseVector([369.0, 1678.0, 920.0])),
#  Row(prediction=1.0, indexed=305.0, label='48090', features=DenseVector([358.0, 1822.0, 670.0])),
#  Row(prediction=1.0, indexed=309.0, label='48300', features=DenseVector([179.0, 2032.0, 590.0])),
#  Row(prediction=1.0, indexed=311.0, label='48550', features=DenseVector([327.0, 1736.0, 870.0])),
#  Row(prediction=1.0, indexed=312.0, label='48560', features=DenseVector([144.0, 1805.0, 540.0])),
#  Row(prediction=71.0, indexed=313.0, label='48590', features=DenseVector([141.0, 2374.0, 800.0])),
#  Row(prediction=1.0, indexed=315.0, label='48670', features=DenseVector([56.0, 1701.0, 740.0])),
#  Row(prediction=1.0, indexed=16.0, label='48950', features=DenseVector([143.0, 1456.0, 530.0])),
#  Row(prediction=1.0, indexed=317.0, label='49070', features=DenseVector([207.0, 1853.0, 660.0])),
#  Row(prediction=71.0, indexed=318.0, label='49080', features=DenseVector([67.0, 2262.0, 570.0])),
#  Row(prediction=1.0, indexed=319.0, label='49100', features=DenseVector([63.0, 1748.0, 600.0])),
#  Row(prediction=1.0, indexed=17.0, label='49160', features=DenseVector([232.0, 1661.0, 1410.0])),
#  Row(prediction=71.0, indexed=18.0, label='49170', features=DenseVector([150.0, 2300.0, 1060.0])),
#  Row(prediction=1.0, indexed=320.0, label='49210', features=DenseVector([128.0, 2051.0, 750.0])),
#  Row(prediction=1.0, indexed=321.0, label='49270', features=DenseVector([46.0, 1471.0, 870.0])),
#  Row(prediction=1.0, indexed=328.0, label='49550', features=DenseVector([41.0, 1725.0, 1250.0])),
#  Row(prediction=1.0, indexed=329.0, label='49570', features=DenseVector([333.0, 1473.0, 630.0])),
#  Row(prediction=1.0, indexed=20.0, label='49590', features=DenseVector([448.0, 2123.0, 860.0])),
#  Row(prediction=1.0, indexed=21.0, label='49720', features=DenseVector([300.0, 1288.0, 630.0])),
#  Row(prediction=1.0, indexed=332.0, label='49760', features=DenseVector([200.0, 1371.0, 940.0])),
#  Row(prediction=1.0, indexed=333.0, label='49800', features=DenseVector([169.0, 1487.0, 860.0])),
#  Row(prediction=1.0, indexed=334.0, label='49980', features=DenseVector([348.0, 2138.0, 580.0])),
#  Row(prediction=1.0, indexed=337.0, label='50070', features=DenseVector([133.0, 1672.0, 1170.0])),
#  Row(prediction=1.0, indexed=22.0, label='50130', features=DenseVector([277.0, 2109.0, 1210.0])),
#  Row(prediction=71.0, indexed=22.0, label='50130', features=DenseVector([345.0, 2390.0, 930.0])),
#  Row(prediction=1.0, indexed=338.0, label='50170', features=DenseVector([267.0, 1660.0, 970.0])),
#  Row(prediction=1.0, indexed=340.0, label='50360', features=DenseVector([148.0, 1486.0, 730.0])),
#  Row(prediction=1.0, indexed=341.0, label='50440', features=DenseVector([265.0, 1397.0, 1020.0])),
#  Row(prediction=1.0, indexed=343.0, label='50680', features=DenseVector([24.0, 1752.0, 620.0])),
#  Row(prediction=1.0, indexed=344.0, label='50720', features=DenseVector([382.0, 1467.0, 910.0])),
#  Row(prediction=1.0, indexed=346.0, label='50740', features=DenseVector([302.0, 1916.0, 1110.0])),
#  Row(prediction=1.0, indexed=347.0, label='50780', features=DenseVector([161.0, 2078.0, 680.0])),
#  Row(prediction=71.0, indexed=348.0, label='50810', features=DenseVector([96.0, 2385.0, 500.0])),
#  Row(prediction=71.0, indexed=350.0, label='50840', features=DenseVector([272.0, 2220.0, 340.0])),
#  Row(prediction=1.0, indexed=353.0, label='50950', features=DenseVector([105.0, 1587.0, 1000.0])),
#  Row(prediction=1.0, indexed=355.0, label='51130', features=DenseVector([388.0, 1801.0, 890.0])),
#  Row(prediction=1.0, indexed=358.0, label='51270', features=DenseVector([330.0, 1948.0, 960.0])),
#  Row(prediction=1.0, indexed=359.0, label='51280', features=DenseVector([86.0, 1760.0, 280.0])),
#  Row(prediction=71.0, indexed=23.0, label='51480', features=DenseVector([399.0, 2493.0, 810.0])),
#  Row(prediction=1.0, indexed=366.0, label='51700', features=DenseVector([111.0, 1382.0, 1260.0])),
#  Row(prediction=1.0, indexed=368.0, label='51850', features=DenseVector([135.0, 1638.0, 980.0])),
#  Row(prediction=71.0, indexed=370.0, label='51950', features=DenseVector([239.0, 2247.0, 480.0])),
#  Row(prediction=1.0, indexed=373.0, label='52060', features=DenseVector([436.0, 1836.0, 990.0])),
#  Row(prediction=1.0, indexed=374.0, label='52090', features=DenseVector([418.0, 1724.0, 920.0])),
#  Row(prediction=1.0, indexed=377.0, label='52270', features=DenseVector([210.0, 1872.0, 690.0])),
#  Row(prediction=1.0, indexed=378.0, label='52280', features=DenseVector([211.0, 1572.0, 510.0])),
#  Row(prediction=1.0, indexed=382.0, label='52460', features=DenseVector([195.0, 1982.0, 690.0])),
#  Row(prediction=1.0, indexed=383.0, label='52520', features=DenseVector([286.0, 1215.0, 1070.0])),
#  Row(prediction=1.0, indexed=24.0, label='52780', features=DenseVector([23.0, 2065.0, 950.0])),
#  Row(prediction=1.0, indexed=24.0, label='52780', features=DenseVector([234.0, 1649.0, 940.0])),
#  Row(prediction=1.0, indexed=388.0, label='53270', features=DenseVector([398.0, 1381.0, 730.0])),
#  Row(prediction=1.0, indexed=390.0, label='53400', features=DenseVector([410.0, 1605.0, 1000.0])),
#  Row(prediction=1.0, indexed=391.0, label='53500', features=DenseVector([425.0, 1523.0, 1350.0])),
#  Row(prediction=1.0, indexed=393.0, label='53730', features=DenseVector([4.0, 1748.0, 620.0])),
#  Row(prediction=1.0, indexed=396.0, label='53870', features=DenseVector([60.0, 2070.0, 460.0])),
#  Row(prediction=71.0, indexed=400.0, label='54030', features=DenseVector([93.0, 2205.0, 400.0])),
#  Row(prediction=1.0, indexed=402.0, label='54300', features=DenseVector([160.0, 1534.0, 1230.0])),
#  Row(prediction=1.0, indexed=404.0, label='54360', features=DenseVector([356.0, 1511.0, 500.0])),
#  Row(prediction=1.0, indexed=0.0, label='54590', features=DenseVector([426.0, 2133.0, 1000.0])),
#  Row(prediction=1.0, indexed=411.0, label='54670', features=DenseVector([363.0, 1877.0, 580.0])),
#  Row(prediction=71.0, indexed=416.0, label='55170', features=DenseVector([39.0, 2204.0, 1010.0])),
#  Row(prediction=1.0, indexed=419.0, label='55530', features=DenseVector([372.0, 1305.0, 1190.0])),
#  Row(prediction=1.0, indexed=420.0, label='55660', features=DenseVector([294.0, 1576.0, 360.0])),
#  Row(prediction=1.0, indexed=422.0, label='55820', features=DenseVector([218.0, 1829.0, 840.0])),
#  Row(prediction=71.0, indexed=426.0, label='56010', features=DenseVector([113.0, 2248.0, 1330.0])),
#  Row(prediction=1.0, indexed=427.0, label='56170', features=DenseVector([249.0, 2097.0, 730.0])),
#  Row(prediction=1.0, indexed=430.0, label='56360', features=DenseVector([94.0, 1655.0, 760.0])),
#  Row(prediction=1.0, indexed=432.0, label='56400', features=DenseVector([311.0, 1889.0, 610.0])),
#  Row(prediction=1.0, indexed=30.0, label='56440', features=DenseVector([283.0, 1848.0, 1070.0])),
#  Row(prediction=1.0, indexed=433.0, label='56450', features=DenseVector([404.0, 1896.0, 750.0])),
#  Row(prediction=1.0, indexed=435.0, label='56610', features=DenseVector([262.0, 1106.0, 860.0])),
#  Row(prediction=1.0, indexed=436.0, label='56650', features=DenseVector([71.0, 2019.0, 850.0])),
#  Row(prediction=1.0, indexed=31.0, label='56710', features=DenseVector([119.0, 1798.0, 860.0])),
#  Row(prediction=1.0, indexed=439.0, label='56810', features=DenseVector([328.0, 2157.0, 730.0])),
#  Row(prediction=1.0, indexed=447.0, label='57140', features=DenseVector([443.0, 1766.0, 1290.0])),
#  Row(prediction=1.0, indexed=448.0, label='57160', features=DenseVector([360.0, 1799.0, 950.0])),
#  Row(prediction=1.0, indexed=451.0, label='57450', features=DenseVector([427.0, 1375.0, 1220.0])),
#  Row(prediction=1.0, indexed=452.0, label='57480', features=DenseVector([131.0, 1595.0, 910.0])),
#  Row(prediction=1.0, indexed=453.0, label='57500', features=DenseVector([331.0, 1273.0, 860.0])),
#  Row(prediction=1.0, indexed=454.0, label='57530', features=DenseVector([295.0, 1803.0, 970.0])),
#  Row(prediction=1.0, indexed=455.0, label='57620', features=DenseVector([12.0, 2098.0, 720.0])),
#  Row(prediction=1.0, indexed=458.0, label='57830', features=DenseVector([52.0, 1880.0, 1300.0])),
#  Row(prediction=1.0, indexed=459.0, label='57860', features=DenseVector([83.0, 1723.0, 330.0])),
#  Row(prediction=1.0, indexed=462.0, label='58090', features=DenseVector([180.0, 1941.0, 1350.0])),
#  Row(prediction=1.0, indexed=464.0, label='58260', features=DenseVector([205.0, 1857.0, 1020.0])),
#  Row(prediction=1.0, indexed=465.0, label='58380', features=DenseVector([421.0, 1404.0, 430.0])),
#  Row(prediction=1.0, indexed=468.0, label='58540', features=DenseVector([246.0, 2003.0, 1070.0])),
#  Row(prediction=1.0, indexed=32.0, label='58610', features=DenseVector([289.0, 1674.0, 1210.0])),
#  Row(prediction=1.0, indexed=32.0, label='58610', features=DenseVector([415.0, 1670.0, 950.0])),
#  Row(prediction=1.0, indexed=33.0, label='58660', features=DenseVector([65.0, 1821.0, 590.0])),
#  Row(prediction=1.0, indexed=470.0, label='58670', features=DenseVector([315.0, 2131.0, 340.0])),
#  Row(prediction=1.0, indexed=471.0, label='58920', features=DenseVector([147.0, 1750.0, 130.0])),
#  Row(prediction=1.0, indexed=475.0, label='59380', features=DenseVector([145.0, 1770.0, 620.0])),
#  Row(prediction=1.0, indexed=478.0, label='59760', features=DenseVector([411.0, 1704.0, 1130.0])),
#  Row(prediction=1.0, indexed=479.0, label='59800', features=DenseVector([368.0, 1774.0, 940.0])),
#  Row(prediction=71.0, indexed=483.0, label='59970', features=DenseVector([400.0, 2254.0, 1000.0])),
#  Row(prediction=1.0, indexed=484.0, label='59980', features=DenseVector([49.0, 1776.0, 1260.0])),
#  Row(prediction=1.0, indexed=485.0, label='60140', features=DenseVector([268.0, 2030.0, 830.0])),
#  Row(prediction=1.0, indexed=486.0, label='60240', features=DenseVector([281.0, 1515.0, 720.0])),
#  Row(prediction=1.0, indexed=488.0, label='60460', features=DenseVector([33.0, 1608.0, 880.0])),
#  Row(prediction=1.0, indexed=40.0, label='60470', features=DenseVector([13.0, 2064.0, 1050.0])),
#  Row(prediction=1.0, indexed=41.0, label='60530', features=DenseVector([28.0, 1648.0, 980.0])),
#  Row(prediction=1.0, indexed=41.0, label='60530', features=DenseVector([380.0, 2026.0, 700.0])),
#  Row(prediction=1.0, indexed=490.0, label='60770', features=DenseVector([274.0, 1901.0, 490.0])),
#  Row(prediction=71.0, indexed=493.0, label='60960', features=DenseVector([97.0, 2235.0, 1120.0])),
#  Row(prediction=1.0, indexed=495.0, label='61040', features=DenseVector([435.0, 1635.0, 840.0])),
#  Row(prediction=71.0, indexed=497.0, label='61150', features=DenseVector([127.0, 2241.0, 500.0])),
#  Row(prediction=1.0, indexed=498.0, label='61180', features=DenseVector([98.0, 2171.0, 1160.0])),
#  Row(prediction=1.0, indexed=500.0, label='61460', features=DenseVector([355.0, 1707.0, 1160.0])),
#  Row(prediction=1.0, indexed=502.0, label='61660', features=DenseVector([208.0, 1677.0, 480.0])),
#  Row(prediction=1.0, indexed=503.0, label='61670', features=DenseVector([319.0, 1586.0, 630.0])),
#  Row(prediction=1.0, indexed=505.0, label='61750', features=DenseVector([252.0, 1845.0, 700.0])),
#  Row(prediction=1.0, indexed=506.0, label='61970', features=DenseVector([434.0, 1503.0, 950.0])),
#  Row(prediction=1.0, indexed=44.0, label='62180', features=DenseVector([354.0, 1709.0, 1340.0])),
#  Row(prediction=1.0, indexed=507.0, label='62270', features=DenseVector([199.0, 1808.0, 460.0])),
#  Row(prediction=1.0, indexed=508.0, label='62280', features=DenseVector([138.0, 1905.0, 810.0])),
#  Row(prediction=1.0, indexed=510.0, label='62470', features=DenseVector([256.0, 1735.0, 400.0])),
#  Row(prediction=1.0, indexed=511.0, label='62530', features=DenseVector([48.0, 1982.0, 910.0])),
#  Row(prediction=1.0, indexed=512.0, label='62710', features=DenseVector([324.0, 2147.0, 430.0])),
#  Row(prediction=1.0, indexed=514.0, label='62800', features=DenseVector([221.0, 1742.0, 310.0])),
#  Row(prediction=1.0, indexed=515.0, label='62870', features=DenseVector([38.0, 1411.0, 1080.0])),
#  Row(prediction=1.0, indexed=516.0, label='62950', features=DenseVector([112.0, 1787.0, 800.0])),
#  Row(prediction=1.0, indexed=1.0, label='63540', features=DenseVector([19.0, 1731.0, 1030.0])),
#  Row(prediction=1.0, indexed=1.0, label='63540', features=DenseVector([365.0, 1369.0, 650.0])),
#  Row(prediction=1.0, indexed=47.0, label='63660', features=DenseVector([99.0, 2147.0, 820.0])),
#  Row(prediction=1.0, indexed=524.0, label='63720', features=DenseVector([258.0, 1231.0, 760.0])),
#  Row(prediction=1.0, indexed=525.0, label='63730', features=DenseVector([152.0, 1986.0, 70.0])),
#  Row(prediction=1.0, indexed=526.0, label='63830', features=DenseVector([223.0, 1527.0, 380.0])),
#  Row(prediction=1.0, indexed=530.0, label='64090', features=DenseVector([55.0, 1898.0, 980.0])),
#  Row(prediction=1.0, indexed=533.0, label='64640', features=DenseVector([292.0, 1093.0, 1210.0])),
#  Row(prediction=1.0, indexed=534.0, label='64670', features=DenseVector([184.0, 2053.0, 950.0])),
#  Row(prediction=71.0, indexed=538.0, label='64820', features=DenseVector([285.0, 2216.0, 1020.0])),
#  Row(prediction=1.0, indexed=539.0, label='64950', features=DenseVector([236.0, 2110.0, 1200.0])),
#  Row(prediction=1.0, indexed=543.0, label='65180', features=DenseVector([106.0, 1434.0, 690.0])),
#  Row(prediction=1.0, indexe
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# ion=1.0, indexed=385.0, label='52610', features=DenseVector([493.0, 1770.0, 800.0])),
#  Row(prediction=3.0, indexed=386.0, label='52940', features=DenseVector([695.0, 1529.0, 870.0])),
#  Row(prediction=43.0, indexed=387.0, label='52990', features=DenseVector([770.0, 2349.0, 750.0])),
#  Row(prediction=3.0, indexed=25.0, label='53230', features=DenseVector([719.0, 1743.0, 970.0])),
#  Row(prediction=3.0, indexed=389.0, label='53370', features=DenseVector([633.0, 1869.0, 1030.0])),
#  Row(prediction=1.0, indexed=392.0, label='53550', features=DenseVector([483.0, 2046.0, 380.0])),
#  Row(prediction=3.0, indexed=394.0, label='53750', features=DenseVector([635.0, 1920.0, 890.0])),
#  Row(prediction=3.0, indexed=26.0, label='53760', features=DenseVector([731.0, 2086.0, 550.0])),
#  Row(prediction=3.0, indexed=26.0, label='53760', features=DenseVector([792.0, 1791.0, 1010.0])),
#  Row(prediction=1.0, indexed=397.0, label='53890', features=DenseVector([492.0, 1695.0, 890.0])),
#  Row(prediction=3.0, indexed=398.0, label='53900', features=DenseVector([826.0, 1630.0, 1120.0])),
#  Row(prediction=3.0, indexed=27.0, label='53940', features=DenseVector([840.0, 1413.0, 480.0])),
#  Row(prediction=3.0, indexed=28.0, label='54060', features=DenseVector([591.0, 1437.0, 1330.0])),
#  Row(prediction=3.0, indexed=28.0, label='54060', features=DenseVector([806.0, 1902.0, 910.0])),
#  Row(prediction=43.0, indexed=401.0, label='54200', features=DenseVector([764.0, 2264.0, 310.0])),
#  Row(prediction=3.0, indexed=403.0, label='54340', features=DenseVector([896.0, 1429.0, 1110.0])),
#  Row(prediction=1.0, indexed=29.0, label='54370', features=DenseVector([571.0, 1461.0, 1070.0])),
#  Row(prediction=3.0, indexed=405.0, label='54380', features=DenseVector([859.0, 1393.0, 860.0])),
#  Row(prediction=1.0, indexed=406.0, label='54410', features=DenseVector([582.0, 1716.0, 630.0])),
#  Row(prediction=1.0, indexed=407.0, label='54450', features=DenseVector([533.0, 1981.0, 720.0])),
#  Row(prediction=3.0, indexed=408.0, label='54530', features=DenseVector([766.0, 1881.0, 740.0])),
#  Row(prediction=3.0, indexed=0.0, label='54590', features=DenseVector([675.0, 1677.0, 210.0])),
#  Row(prediction=1.0, indexed=409.0, label='54610', features=DenseVector([554.0, 1390.0, 1220.0])),
#  Row(prediction=1.0, indexed=410.0, label='54650', features=DenseVector([575.0, 2131.0, 1140.0])),
#  Row(prediction=3.0, indexed=412.0, label='54690', features=DenseVector([604.0, 1488.0, 770.0])),
#  Row(prediction=3.0, indexed=413.0, label='54820', features=DenseVector([649.0, 1794.0, 1400.0])),
#  Row(prediction=3.0, indexed=414.0, label='54950', features=DenseVector([640.0, 1895.0, 720.0])),
#  Row(prediction=1.0, indexed=415.0, label='55160', features=DenseVector([505.0, 1607.0, 370.0])),
#  Row(prediction=3.0, indexed=417.0, label='55390', features=DenseVector([793.0, 1713.0, 550.0])),
#  Row(prediction=3.0, indexed=418.0, label='55500', features=DenseVector([843.0, 1557.0, 580.0])),
#  Row(prediction=3.0, indexed=421.0, label='55710', features=DenseVector([679.0, 2126.0, 730.0])),
#  Row(prediction=43.0, indexed=423.0, label='55880', features=DenseVector([838.0, 2277.0, 610.0])),
#  Row(prediction=3.0, indexed=424.0, label='55980', features=DenseVector([711.0, 1815.0, 190.0])),
#  Row(prediction=1.0, indexed=425.0, label='55990', features=DenseVector([480.0, 1121.0, 940.0])),
#  Row(prediction=3.0, indexed=428.0, label='56230', features=DenseVector([791.0, 1876.0, 620.0])),
#  Row(prediction=1.0, indexed=429.0, label='56260', features=DenseVector([586.0, 1476.0, 720.0])),
#  Row(prediction=3.0, indexed=431.0, label='56380', features=DenseVector([798.0, 1808.0, 830.0])),
#  Row(prediction=1.0, indexed=30.0, label='56440', features=DenseVector([516.0, 2084.0, 820.0])),
#  Row(prediction=1.0, indexed=434.0, label='56480', features=DenseVector([466.0, 2065.0, 750.0])),
#  Row(prediction=1.0, indexed=437.0, label='56660', features=DenseVector([456.0, 1598.0, 690.0])),
#  Row(prediction=3.0, indexed=31.0, label='56710', features=DenseVector([777.0, 1742.0, 840.0])),
#  Row(prediction=3.0, indexed=438.0, label='56790', features=DenseVector([787.0, 1877.0, 790.0])),
#  Row(prediction=1.0, indexed=440.0, label='56820', features=DenseVector([498.0, 1087.0, 680.0])),
#  Row(prediction=1.0, indexed=441.0, label='56830', features=DenseVector([477.0, 1462.0, 560.0])),
#  Row(prediction=3.0, indexed=442.0, label='56850', features=DenseVector([644.0, 1555.0, 1020.0])),
#  Row(prediction=3.0, indexed=443.0, label='56860', features=DenseVector([740.0, 1645.0, 770.0])),
#  Row(prediction=3.0, indexed=444.0, label='56880', features=DenseVector([758.0, 1683.0, 680.0])),
#  Row(prediction=43.0, indexed=445.0, label='56910', features=DenseVector([684.0, 2262.0, 310.0])),
#  Row(prediction=1.0, indexed=446.0, label='57090', features=DenseVector([465.0, 1737.0, 770.0])),
#  Row(prediction=3.0, indexed=449.0, label='57200', features=DenseVector([651.0, 1584.0, 840.0])),
#  Row(prediction=3.0, indexed=450.0, label='57330', features=DenseVector([642.0, 1331.0, 1010.0])),
#  Row(prediction=3.0, indexed=456.0, label='57750', features=DenseVector([823.0, 1892.0, 540.0])),
#  Row(prediction=3.0, indexed=457.0, label='57820', features=DenseVector([878.0, 2138.0, 820.0])),
#  Row(prediction=3.0, indexed=460.0, label='57910', features=DenseVector([722.0, 2109.0, 1120.0])),
#  Row(prediction=1.0, indexed=461.0, label='58070', features=DenseVector([509.0, 1787.0, 800.0])),
#  Row(prediction=3.0, indexed=463.0, label='58160', features=DenseVector([836.0, 2009.0, 1000.0])),
#  Row(prediction=1.0, indexed=466.0, label='58390', features=DenseVector([545.0, 1519.0, 920.0])),
#  Row(prediction=3.0, indexed=467.0, label='58440', features=DenseVector([754.0, 1749.0, 890.0])),
#  Row(prediction=3.0, indexed=33.0, label='58660', features=DenseVector([632.0, 1722.0, 560.0])),
#  Row(prediction=1.0, indexed=34.0, label='58940', features=DenseVector([472.0, 1417.0, 1230.0])),
#  Row(prediction=3.0, indexed=34.0, label='58940', features=DenseVector([804.0, 1650.0, 420.0])),
#  Row(prediction=1.0, indexed=472.0, label='59070', features=DenseVector([543.0, 1845.0, 760.0])),
#  Row(prediction=3.0, indexed=35.0, label='59130', features=DenseVector([599.0, 2016.0, 830.0])),
#  Row(prediction=3.0, indexed=473.0, label='59160', features=DenseVector([832.0, 1179.0, 710.0])),
#  Row(prediction=3.0, indexed=36.0, label='59190', features=DenseVector([729.0, 1773.0, 970.0])),
#  Row(prediction=3.0, indexed=474.0, label='59290', features=DenseVector([847.0, 1819.0, 540.0])),
#  Row(prediction=3.0, indexed=476.0, label='59530', features=DenseVector([737.0, 1309.0, 860.0])),
#  Row(prediction=3.0, indexed=477.0, label='59540', features=DenseVector([603.0, 1720.0, 1180.0])),
#  Row(prediction=3.0, indexed=37.0, label='59820', features=DenseVector([778.0, 1798.0, 850.0])),
#  Row(prediction=3.0, indexed=37.0, label='59820', features=DenseVector([842.0, 1843.0, 340.0])),
#  Row(prediction=1.0, indexed=480.0, label='59920', features=DenseVector([532.0, 1517.0, 790.0])),
#  Row(prediction=43.0, indexed=482.0, label='59950', features=DenseVector([851.0, 2362.0, 1020.0])),
#  Row(prediction=3.0, indexed=38.0, label='60060', features=DenseVector([595.0, 1931.0, 790.0])),
#  Row(prediction=3.0, indexed=38.0, label='60060', features=DenseVector([736.0, 1733.0, 320.0])),
#  Row(prediction=3.0, indexed=487.0, label='60270', features=DenseVector([876.0, 2023.0, 540.0])),
#  Row(prediction=3.0, indexed=39.0, label='60440', features=DenseVector([780.0, 1472.0, 710.0])),
#  Row(prediction=3.0, indexed=39.0, label='60440', features=DenseVector([783.0, 1280.0, 1240.0])),
#  Row(prediction=3.0, indexed=489.0, label='60680', features=DenseVector([715.0, 1482.0, 1070.0])),
#  Row(prediction=3.0, indexed=491.0, label='60800', features=DenseVector([613.0, 2014.0, 660.0])),
#  Row(prediction=1.0, indexed=42.0, label='61000', features=DenseVector([538.0, 1920.0, 600.0])),
#  Row(prediction=3.0, indexed=496.0, label='61080', features=DenseVector([712.0, 1612.0, 490.0])),
#  Row(prediction=3.0, indexed=499.0, label='61210', features=DenseVector([879.0, 1468.0, 1210.0])),
#  Row(prediction=3.0, indexed=501.0, label='61590', features=DenseVector([626.0, 1680.0, 1070.0])),
#  Row(prediction=3.0, indexed=504.0, label='61730', features=DenseVector([631.0, 1836.0, 940.0])),
#  Row(prediction=43.0, indexed=43.0, label='62050', features=DenseVector([630.0, 2264.0, 830.0])),
#  Row(prediction=43.0, indexed=43.0, label='62050', features=DenseVector([701.0, 2262.0, 560.0])),
#  Row(prediction=3.0, indexed=45.0, label='62380', features=DenseVector([672.0, 2010.0, 990.0])),
#  Row(prediction=3.0, indexed=45.0, label='62380', features=DenseVector([725.0, 1795.0, 530.0])),
#  Row(prediction=3.0, indexed=509.0, label='62420', features=DenseVector([757.0, 1506.0, 990.0])),
#  Row(prediction=3.0, indexed=517.0, label='62960', features=DenseVector([647.0, 1670.0, 410.0])),
#  Row(prediction=3.0, indexed=46.0, label='63020', features=DenseVector([848.0, 1745.0, 970.0])),
#  Row(prediction=3.0, indexed=518.0, label='63050', features=DenseVector([706.0, 1924.0, 1170.0])),
#  Row(prediction=3.0, indexed=519.0, label='63100', features=DenseVector([828.0, 2024.0, 620.0])),
#  Row(prediction=3.0, indexed=520.0, label='63300', features=DenseVector([809.0, 1800.0, 780.0])),
#  Row(prediction=71.0, indexed=521.0, label='63510', features=DenseVector([551.0, 2465.0, 720.0])),
#  Row(prediction=3.0, indexed=1.0, label='63540', features=DenseVector([855.0, 1789.0, 550.0])),
#  Row(prediction=1.0, indexed=523.0, label='63600', features=DenseVector([519.0, 1817.0, 850.0])),
#  Row(prediction=3.0, indexed=47.0, label='63660', features=DenseVector([646.0, 1649.0, 740.0])),
#  Row(prediction=3.0, indexed=527.0, label='63850', features=DenseVector([673.0, 1958.0, 290.0])),
#  Row(prediction=1.0, indexed=528.0, label='63950', features=DenseVector([564.0, 1440.0, 500.0])),
#  Row(prediction=1.0, indexed=529.0, label='64010', features=DenseVector([507.0, 2142.0, 950.0])),
#  Row(prediction=3.0, indexed=531.0, label='64120', features=DenseVector([669.0, 1278.0, 440.0])),
#  Row(prediction=3.0, indexed=532.0, label='64320', features=DenseVector([704.0, 2167.0, 700.0])),
#  Row(prediction=43.0, indexed=535.0, label='64690', features=DenseVector([716.0, 2384.0, 1110.0])),
#  Row(prediction=1.0, indexed=537.0, label='64780', features=DenseVector([539.0, 1968.0, 210.0])),
#  Row(prediction=1.0, indexed=540.0, label='64990', features=DenseVector([482.0, 2002.0, 1050.0])),
#  Row(prediction=3.0, indexed=541.0, label='65080', features=DenseVector([700.0, 1928.0, 660.0])),
#  Row(prediction=3.0, indexed=542.0, label='65120', features=DenseVector([607.0, 1536.0, 540.0])),
#  Row(prediction=3.0, indexed=544.0, label='65300', features=DenseVector([707.0, 1793.0, 1020.0])),
#  Row(prediction=3.0, indexed=547.0, label='65390', features=DenseVector([677.0, 1472.0, 790.0])),
#  Row(prediction=3.0, indexed=548.0, label='65410', features=DenseVector([763.0, 1428.0, 830.0])),
#  Row(prediction=1.0, indexed=552.0, label='65750', features=DenseVector([512.0, 1490.0, 330.0])),
#  Row(prediction=3.0, indexed=49.0, label='65890', features=DenseVector([797.0, 1610.0, 700.0])),
#  Row(prediction=1.0, indexed=51.0, label='66050', features=DenseVector([486.0, 1719.0, 580.0])),
#  Row(prediction=1.0, indexed=51.0, label='66050', features=DenseVector([511.0, 2022.0, 1050.0])),
#  Row(prediction=3.0, indexed=559.0, label='66070', features=DenseVector([661.0, 2020.0, 980.0])),
#  Row(prediction=3.0, indexed=560.0, label='66160', features=DenseVector([670.0, 1785.0, 1340.0])),
#  Row(prediction=43.0, indexed=564.0, label='66300', features=DenseVector([732.0, 2310.0, 520.0])),
#  Row(prediction=3.0, indexed=52.0, label='66390', features=DenseVector([831.0, 2101.0, 900.0])),
#  Row(prediction=3.0, indexed=52.0, label='66390', features=DenseVector([892.0, 1910.0, 1080.0])),
#  Row(prediction=3.0, indexed=572.0, label='67090', features=DenseVector([788.0, 1723.0, 1040.0])),
#  Row(prediction=1.0, indexed=573.0, label='67100', features=DenseVector([489.0, 1466.0, 730.0])),
#  Row(prediction=3.0, indexed=574.0, label='67110', features=DenseVector([628.0, 1888.0, 600.0])),
#  Row(prediction=1.0, indexed=575.0, label='67290', features=DenseVector([567.0, 1703.0, 1000.0])),
#  Row(prediction=3.0, indexed=576.0, label='67320', features=DenseVector([796.0, 1747.0, 1090.0])),
#  Row(prediction=3.0, indexed=579.0, label='67390', features=DenseVector([765.0, 1378.0, 730.0])),
#  Row(prediction=1.0, indexed=582.0, label='67610', features=DenseVector([452.0, 2137.0, 670.0])),
#  Row(prediction=3.0, indexed=587.0, label='68350', features=DenseVector([619.0, 1791.0, 630.0])),
#  Row(prediction=3.0, indexed=589.0, label='68420', features=DenseVector([598.0, 1872.0, 1080.0])),
#  Row(prediction=1.0, indexed=597.0, label='69050', features=DenseVector([476.0, 1764.0, 1060.0])),
#  Row(prediction=1.0, indexed=598.0, label='69090', features=DenseVector([453.0, 1291.0, 930.0])),
#  Row(prediction=3.0, indexed=599.0, label='69190', features=DenseVector([611.0, 1804.0, 430.0])),
#  Row(prediction=3.0, indexed=600.0, label='69210', features=DenseVector([680.0, 1823.0, 1040.0])),
#  Row(prediction=1.0, indexed=602.0, label='69320', features=DenseVector([576.0, 1747.0, 750.0])),
#  Row(prediction=3.0, indexed=603.0, label='69370', features=DenseVector([627.0, 1746.0, 590.0])),
#  Row(prediction=1.0, indexed=604.0, label='69390', features=DenseVector([583.0, 2053.0, 730.0])),
#  Row(prediction=1.0, indexed=56.0, label='69610', features=DenseVector([524.0, 1968.0, 340.0])),
#  Row(prediction=3.0, indexed=609.0, label='69990', features=DenseVector([687.0, 1562.0, 490.0])),
#  Row(prediction=3.0, indexed=612.0, label='70110', features=DenseVector([625.0, 1284.0, 750.0])),
#  Row(prediction=43.0, indexed=613.0, label='70230', features=DenseVector([850.0, 2492.0, 790.0])),
#  Row(prediction=1.0, indexed=614.0, label='70290', features=DenseVector([559.0, 1472.0, 810.0])),
#  Row(prediction=1.0, indexed=615.0, label='70310', features=DenseVector([529.0, 2064.0, 940.0])),
#  Row(prediction=3.0, indexed=618.0, label='70580', features=DenseVector([771.0, 1540.0, 590.0])),
#  Row(prediction=3.0, indexed=620.0, label='70620', features=DenseVector([891.0, 1851.0, 1220.0])),
#  Row(prediction=1.0, indexed=58.0, label='70810', features=DenseVector([565.0, 1743.0, 1200.0])),
#  Row(prediction=3.0, indexed=622.0, label='70830', features=DenseVector([800.0, 1508.0, 1260.0])),
#  Row(prediction=3.0, indexed=59.0, label='70940', features=DenseVector([756.0, 1643.0, 740.0])),
#  Row(prediction=3.0, indexed=59.0, label='70940', features=DenseVector([839.0, 1937.0, 1050.0])),
#  Row(prediction=3.0, indexed=624.0, label='70980', features=DenseVector([881.0, 1516.0, 780.0])),
#  Row(prediction=1.0, indexed=626.0, label='71240', features=DenseVector([471.0, 1919.0, 960.0])),
#  Row(prediction=3.0, indexed=628.0, label='71290', features=DenseVector([624.0, 1823.0, 520.0])),
#  Row(prediction=3.0, indexed=634.0, label='71830', features=DenseVector([813.0, 1918.0, 1260.0])),
#  Row(prediction=1.0, indexed=635.0, label='72000', features=DenseVector([548.0, 1353.0, 1370.0])),
#  Row(prediction=1.0, indexed=636.0, label='72020', features=DenseVector([506.0, 1846.0, 760.0])),
#  Row(prediction=3.0, indexed=640.0, label='72270', features=DenseVector([886.0, 1337.0, 560.0])),
#  Row(prediction=1.0, indexed=643.0, label='72410', features=DenseVector([570.0, 1822.0, 420.0])),
#  Row(prediction=3.0, indexed=645.0, label='72550', features=DenseVector([682.0, 1750.0, 570.0])),
#  Row(prediction=3.0, indexed=648.0, label='72740', features=DenseVector([688.0, 1775.0, 230.0])),
#  Row(prediction=3.0, indexed=650.0, label='72940', features=DenseVector([659.0, 1623.0, 1010.0])),
#  Row(prediction=3.0, indexed=653.0, label='73160', features=DenseVector([817.0, 1860.0, 670.0])),
#  Row(prediction=3.0, indexed=655.0, label='73500', features=DenseVector([794.0, 1672.0, 800.0])),
#  Row(prediction=3.0, indexed=656.0, label='73590', features=DenseVector([697.0, 1455.0, 750.0])),
#  Row(prediction=3.0, indexed=657.0, label='73610', features=DenseVector([805.0, 2078.0, 770.0])),
#  Row(prediction=3.0, indexed=60.0, label='73800', features=DenseVector([667.0, 1692.0, 790.0])),
#  Row(prediction=3.0, indexed=660.0, label='73810', features=DenseVector([849.0, 1099.0, 1560.0])),
#  Row(prediction=3.0, indexed=61.0, label='74080', features=DenseVector([769.0, 1347.0, 700.0])),
#  Row(prediction=3.0, indexed=663.0, label='74160', features=DenseVector([773.0, 1503.0, 660.0])),
#  Row(prediction=3.0, indexed=667.0, label='74330', features=DenseVector([600.0, 1947.0, 910.0])),
#  Row(prediction=1.0, indexed=669.0, label='74550', features=DenseVector([464.0, 1411.0, 460.0])),
#  Row(prediction=3.0, indexed=674.0, label='75120', features=DenseVector([592.0, 2186.0, 910.0])),
#  Row(prediction=3.0, indexed=676.0, label='75300', features=DenseVector([781.0, 1783.0, 450.0])),
#  Row(prediction=3.0, indexed=678.0, label='75530', features=DenseVector([641.0, 1749.0, 490.0])),
#  Row(prediction=3.0, indexed=62.0, label='75800', features=DenseVector([752.0, 1979.0, 480.0])),
#  Row(prediction=1.0, indexed=681.0, label='75880', features=DenseVector([451.0, 1759.0, 880.0])),
#  Row(prediction=3.0, indexed=682.0, label='75930', features=DenseVector([873.0, 2024.0, 1070.0])),
#  Row(prediction=3.0, indexed=687.0, label='76250', features=DenseVector([602.0, 1489.0, 1380.0])),
#  Row(prediction=3.0, indexed=691.0, label='76440', features=DenseVector([894.0, 1436.0, 1060.0])),
#  Row(prediction=1.0, indexed=692.0, label='76470', features=DenseVector([587.0, 1930.0, 740.0])),
#  Row(prediction=3.0, indexed=694.0, label='76670', features=DenseVector([751.0, 1308.0, 1170.0])),
#  Row(prediction=3.0, indexed=64.0, label='77080', features=DenseVector([601.0, 1722.0, 830.0])),
#  Row(prediction=3.0, indexed=64.0, label='77080', features=DenseVector([868.0, 1959.0, 370.0])),
#  Row(prediction=3.0, indexed=701.0, label='77430', features=DenseVector([887.0, 1986.0, 1150.0])),
#  Row(prediction=1.0, indexed=702.0, label='77570', features=DenseVector([531.0, 1777.0, 800.0])),
#  Row(prediction=3.0, indexed=703.0, label='77740', features=DenseVector([745.0, 1018.0, 660.0])),
#  Row(prediction=3.0, indexed=704.0, label='77790', features=DenseVector([615.0, 1751.0, 760.0])),
#  Row(prediction=71.0, indexed=705.0, label='77960', features=DenseVector([470.0, 2436.0, 680.0])),
#  Row(prediction=71.0, indexed=706.0, label='78020', features=DenseVector([503.0, 2284.0, 310.0])),
#  Row(prediction=3.0, indexed=707.0, label='78060', features=DenseVector([768.0, 1345.0, 790.0])),
#  Row(prediction=3.0, indexed=66.0, label='78090', features=DenseVector([639.0, 2189.0, 310.0])),
#  Row(prediction=3.0, indexed=67.0, label='78100', features=DenseVector([852.0, 1558.0, 790.0])),
#  Row(prediction=3.0, indexed=710.0, label='78430', features=DenseVector([645.0, 2121.0, 1050.0])),
#  Row(prediction=3.0, indexed=712.0, label='78530', features=DenseVector([664.0, 2048.0, 700.0])),
#  Row(prediction=1.0, indexed=69.0, label='78870', features=DenseVector([528.0, 1869.0, 710.0])),
#  Row(prediction=1.0, indexed=713.0, label='78950', features=DenseVector([473.0, 1690.0, 800.0])),
#  Row(prediction=1.0, indexed=716.0, label='79220', features=DenseVector([450.0, 2015.0, 1160.0])),
#  Row(prediction=43.0, indexed=718.0, label='79310', features=DenseVector([814.0, 2252.0, 330.0])),
#  Row(prediction=3.0, indexed=70.0, label='79410', features=DenseVector([858.0, 1982.0, 390.0])),
#  Row(prediction=3.0, indexed=720.0, label='79760', features=DenseVector([767.0, 1939.0, 960.0])),
#  Row(prediction=71.0, indexed=71.0, label='79780', features=DenseVector([580.0, 2246.0, 410.0])),
#  Row(prediction=1.0, indexed=724.0, label='80370', features=DenseVector([546.0, 1420.0, 880.0])),
#  Row(prediction=3.0, indexed=727.0, label='80580', features=DenseVector([870.0, 1732.0, 1170.0])),
#  Row(prediction=3.0, indexed=728.0, label='80720', features=DenseVector([784.0, 1785.0, 570.0])),
#  Row(prediction=3.0, indexed=731.0, label='80830', features=DenseVector([656.0, 1430.0, 560.0])),
#  Row(prediction=1.0, indexed=734.0, label='81370', features=DenseVector([468.0, 1783.0, 730.0])),
#  Row(prediction=3.0, indexed=72.0, label='81390', features=DenseVector([622.0, 1687.0, 830.0])),
#  Row(prediction=3.0, indexed=72.0, label='81390', features=DenseVector([811.0, 1194.0, 1090.0])),
#  Row(prediction=3.0, indexed=736.0, label='81720', features=DenseVector([753.0, 2017.0, 930.0])),
#  Row(prediction=3.0, indexed=73.0, label='81870', features=DenseVector([648.0, 1590.0, 770.0])),
#  Row(prediction=3.0, indexed=739.0, label='81930', features=DenseVector([735.0, 2061.0, 860.0])),
#  Row(prediction=43.0, indexed=740.0, label='82020', features=DenseVector([629.0, 2408.0, 380.0])),
#  Row(prediction=3.0, indexed=742.0, label='82080', features=DenseVector([893.0, 1663.0, 850.0])),
#  Row(prediction=3.0, indexed=743.0, label='82270', features=DenseVector([596.0, 1805.0, 1270.0])),
#  Row(prediction=3.0, indexed=74.0, label='82350', features=DenseVector([655.0, 1387.0, 1060.0])),
#  Row(prediction=3.0, indexed=744.0, label='82390', features=DenseVector([685.0, 1820.0, 310.0])),
#  Row(prediction=3.0, indexed=747.0, label='82970', features=DenseVector([790.0, 1548.0, 370.0])),
#  Row(prediction=3.0, indexed=748.0, label='83220', features=DenseVector([694.0, 1883.0, 1040.0])),
#  Row(prediction=1.0, indexed=752.0, label='83720', features=DenseVector([501.0, 1660.0, 1070.0])),
#  Row(prediction=1.0, indexed=754.0, label='84040', features=DenseVector([549.0, 1481.0, 410.0])),
#  Row(prediction=3.0, indexed=755.0, label='84300', features=DenseVector([810.0, 2008.0, 790.0])),
#  Row(prediction=3.0, indexed=75.0, label='84360', features=DenseVector([605.0, 1306.0, 680.0])),
#  Row(prediction=3.0, indexed=75.0, label='84360', features=DenseVector([652.0, 1817.0, 950.0])),
#  Row(prediction=3.0, indexed=756.0, label='84410', features=DenseVector([714.0, 1947.0, 670.0])),
#  Row(prediction=43.0, indexed=759.0, label='85000', features=DenseVector([807.0, 2214.0, 1110.0])),
#  Row(prediction=1.0, indexed=761.0, label='85160', features=DenseVector([573.0, 1375.0, 940.0])),
#  Row(prediction=43.0, indexed=77.0, label='85670', features=DenseVector([799.0, 2420.0, 850.0])),
#  Row(prediction=3.0, indexed=764.0, label='85720', features=DenseVector([755.0, 1591.0, 680.0])),
#  Row(prediction=43.0, indexed=765.0, label='86560', features=DenseVector([621.0, 2342.0, 690.0])),
#  Row(prediction=3.0, indexed=766.0, label='86620', features=DenseVector([741.0, 1616.0, 710.0])),
#  Row(prediction=43.0, indexed=768.0, label='86830', features=DenseVector([786.0, 2368.0, 450.0])),
#  Row(prediction=3.0, indexed=769.0, label='86890', features=DenseVector([760.0, 1993.0, 440.0])),
#  Row(prediction=1.0, indexed=771.0, label='87160', features=DenseVector([561.0, 1650.0, 540.0])),
#  Row(prediction=3.0, indexed=773.0, label='87220', features=DenseVector([856.0, 1455.0, 950.0])),
#  Row(prediction=1.0, indexed=774.0, label='87330', features=DenseVector([555.0, 2185.0, 840.0])),
#  Row(prediction=71.0, indexed=776.0, label='87410', features=DenseVector([467.0, 2667.0, 660.0])),
#  Row(prediction=3.0, indexed=777.0, label='87890', features=DenseVector([815.0, 1459.0, 540.0])),
#  Row(prediction=3.0, indexed=778.0, label='87930', features=DenseVector([643.0, 1841.0, 680.0])),
#  Row(prediction=3.0, indexed=779.0, label='88120', features=DenseVector([728.0, 1711.0, 1020.0])),
#  Row(prediction=1.0, indexed=780.0, label='88210', features=DenseVector([560.0, 1512.0, 1070.0])),
#  Row(prediction=3.0, indexed=781.0, label='88270', features=DenseVector([877.0, 1493.0, 100.0])),
#  Row(prediction=1.0, indexed=783.0, label='88410', features=DenseVector([556.0, 2072.0, 560.0])),
#  Row(prediction=1.0, indexed=789.0, label='89760', features=DenseVector([557.0, 1138.0, 820.0])),
#  Row(prediction=1.0, indexed=790.0, label='90070', features=DenseVector([589.0, 2174.0, 770.0])),
#  Row(prediction=3.0, indexed=798.0, label='92370', features=DenseVector([888.0, 1398.0, 140.0])),
#  Row(prediction=3.0, indexed=799.0, label='92640', features=DenseVector([854.0, 1906.0, 550.0])),
#  Row(prediction=3.0, indexed=800.0, label='93000', features=DenseVector([733.0, 1999.0, 950.0])),
#  Row(prediction=3.0, indexed=801.0, label='93360', features=DenseVector([696.0, 1958.0, 530.0])),
#  Row(prediction=1.0, indexed=802.0, label='93530', features=DenseVector([478.0, 1480.0, 860.0])),
#  Row(prediction=3.0, indexed=805.0, label='94370', features=DenseVector([690.0, 1276.0, 640.0])),
#  Row(prediction=1.0, indexed=806.0, label='94460', features=DenseVector([572.0, 2184.0, 830.0])),
#  Row(prediction=3.0, indexed=807.0, label='94690', features=DenseVector([665.0, 2111.0, 580.0])),
#  Row(prediction=3.0, indexed=808.0, label='95900', features=DenseVector([812.0, 1635.0, 1270.0])),
#  Row(prediction=3.0, indexed=809.0, label='96610', features=DenseVector([895.0, 1560.0, 770.0])),
#  Row(prediction=1.0, indexed=812.0, label='97360', features=DenseVector([469.0, 1279.0, 670.0])),
#  Row(prediction=3.0, indexed=813.0, label='98260', features=DenseVector([872.0, 2158.0, 1100.0])),
#  Row(prediction=3.0, indexed=814.0, label='99480', features=DenseVector([693.0, 1858.0, 480.0]))]

# %%
evaluator = MulticlassClassificationEvaluator(predictionCol="prediction",labelCol="indexed")
evaluator.evaluate(predictions)
# Out:
# Out[23]: 0.000675613424847584

# %%
#Draw a confusion matrix
labelList=predictions.select("indexed","label").distinct().toPandas()
predictions.groupBy("indexed","prediction").count().show()
# Out:
# +-------+----------+-----+
# |indexed|prediction|count|
# +-------+----------+-----+
# |  304.0|       1.0|    1|
# |  448.0|       1.0|    1|
# |  594.0|       1.0|    1|
# |  695.0|       1.0|    1|
# |   10.0|       1.0|    2|
# |  637.0|       1.0|    1|
# |  796.0|       1.0|    1|
# |  341.0|       1.0|    1|
# |  390.0|       1.0|    1|
# |  435.0|       1.0|    1|
# |   24.0|       1.0|    2|
# |    6.0|       1.0|    2|
# |  231.0|       1.0|    1|
# |  567.0|       1.0|    1|
# |  128.0|       1.0|    1|
# |  659.0|       1.0|    1|
# |  129.0|       1.0|    1|
# |  202.0|      71.0|    1|
# |  301.0|       1.0|    1|
# |  452.0|       1.0|    1|
# +-------+----------+-----+
# only showing top 20 rows
